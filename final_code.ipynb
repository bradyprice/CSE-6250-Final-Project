# %% [markdown]
# <a href="https://colab.research.google.com/github/bradyprice/CSE-6250-Final-Project/blob/main/final_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive

# View current working directory
print("Current Working Directory:", os.getcwd())

# Mount Google Drive
drive.mount('/content/gdrive')

# Change working directory to your file position
path = "/content/gdrive/My Drive/CSE_6250_BD4H_Final_Project"
os.chdir(path)

print("Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /content
# Mounted at /content/gdrive
# Working Directory: /content/gdrive/My Drive/CSE_6250_BD4H_Final_Project

# %% [markdown]
# You will need to install the sparse_dot_topn package

# %%
# !pip install sparse_dot_topn
# Out:
# Collecting sparse_dot_topn
#   Downloading sparse_dot_topn-1.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from sparse_dot_topn) (2.0.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from sparse_dot_topn) (1.14.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from sparse_dot_topn) (5.9.5)
# Downloading sparse_dot_topn-1.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.7/266.7 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: sparse_dot_topn
# Successfully installed sparse_dot_topn-1.1.5

# %% [markdown]
# This part here was working to get the context part of SurfCon with the NPMI matrix to work. We wanted to get this section to work before we expanded on the model.

# %% [markdown]
# ## Context Part of SurfCon

# %%
import numpy as np
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix, csr_matrix
from sparse_dot_topn import awesome_cossim_topn  # Install using: pip install sparse-dot-topn
from scipy.sparse import dok_matrix, csr_matrix

### 1️⃣ Load Mapping Files ###
def load_term_id_to_string(file_paths, include_concepts=True):
    """ Load multiple term ID to string mappings and merge them into a single dictionary. """
    term_id_map = {}
    concept_id_map = {}  # For concept mappings

    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            for line in f:
                try:
                    term_id, term_str = line.strip().split("\t")

                    # If it's a concept mapping file, store separately
                    if include_concepts and "concept" in file_path.lower():
                        concept_id_map[term_id] = term_str
                    else:
                        term_id_map[term_id] = term_str
                except ValueError:
                    continue  # Skip malformed lines

    return term_id_map, concept_id_map


def load_singleton_frequencies(file_path, concept_to_term_map, term_id_map, chunk_size=1000):
    """ Load singleton frequencies in chunks and map concept IDs to term strings """
    singleton_freq = {}

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for i, line in enumerate(f):
            concept_id, count = line.strip().split("\t")
            count = int(count)

            # Get term IDs associated with this concept
            term_ids = concept_to_term_map.get(concept_id, [f"UNK_{concept_id}"])

            # Convert term IDs to actual term names
            terms = [term_id_map.get(term_id, f"UNK_{term_id}") for term_id in term_ids]

            # Store frequencies for all mapped terms
            for term in terms:
                singleton_freq[term] = singleton_freq.get(term, 0) + count

            if (i + 1) % chunk_size == 0:
                print(f"Processed {i + 1} lines")


    return singleton_freq


def load_cofreq_counts(file_path, concept_to_term_map, term_id_map, output_file="temp_cofreq.txt", chunk_size=1000):
    """ Process cofrequency counts in a memory-efficient way for up to chunk_size entries. """
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f, open(output_file, 'w', encoding='utf-8') as out_f:
        for i, line in enumerate(f):
            concept1_id, concept2_id, count = line.strip().split("\t")
            count = int(count)

            # Convert concept IDs into actual term names
            terms1 = [term_id_map.get(t, f"UNK_{t}") for t in concept_to_term_map.get(concept1_id, [concept1_id])]
            terms2 = [term_id_map.get(t, f"UNK_{t}") for t in concept_to_term_map.get(concept2_id, [concept2_id])]

            # Write mapped term pairs to file
            for term1 in terms1:
                for term2 in terms2:
                    if term1 != term2:  # Avoid self-pairs
                        out_f.write(f"{term1}\t{term2}\t{count}\n")

            if (i + 1) % chunk_size == 0:  # Process in chunks
                print(f"Processed {i + 1} lines")
                # Optionally, write intermediate results to disk here to manage memory

    return output_file  # Return the file path


import numpy as np
from scipy.sparse import dok_matrix, csr_matrix

def compute_npmi(cofreq_file, singleton_freq, total_count, term_index, matrix_size, k=1, output_pmi="temp_pmi.npz", chunk_size=100000, max_rows=1000000):
    """
    Compute Normalized PMI (NPMI) using at most `max_rows` rows from co-occurrence file.
    Uses `dok_matrix` for fast updates, then converts to `csr_matrix`.
    """
    print(f"Initializing sparse PMI matrix (limiting to {max_rows} rows)...")
    pmi_matrix = dok_matrix((matrix_size, matrix_size), dtype=np.float32)

    print(f"Processing up to {max_rows} rows from co-occurrence file in chunks...")
    batch_data = []

    with open(cofreq_file, 'r', encoding='utf-8', errors='ignore') as f:
        for i, line in enumerate(f):
            if i >= max_rows:  # 🚀 Stop after 1 million rows
                break

            term1, term2, co_count = line.strip().split("\t")
            co_count = int(co_count)

            if term1 not in term_index or term2 not in term_index:
                continue  # Skip unknown terms

            i_idx, j_idx = term_index[term1], term_index[term2]
            p_x = singleton_freq.get(term1, 1) / total_count
            p_y = singleton_freq.get(term2, 1) / total_count
            p_xy = co_count / total_count

            # Compute PMI
            pmi = np.log2((p_xy + k) / (p_x * p_y + k))
            npmi = pmi / -np.log2(p_xy + k) if p_xy > 0 else 0

            batch_data.append((i_idx, j_idx, npmi))

            if len(batch_data) >= chunk_size:
                for row, col, value in batch_data:
                    pmi_matrix[row, col] = value
                    pmi_matrix[col, row] = value  # PMI is symmetric
                batch_data = []  # Reset batch

            if (i + 1) % chunk_size == 0:
                print(f"Processed {i + 1} lines...")

    # Final batch processing
    for row, col, value in batch_data:
        pmi_matrix[row, col] = value
        pmi_matrix[col, row] = value

    print("Converting PMI matrix to CSR format...")
    csr_pmi = pmi_matrix.tocsr()

    print("Saving PMI matrix to disk...")
    np.savez(output_pmi, data=csr_pmi.data, indices=csr_pmi.indices, indptr=csr_pmi.indptr, shape=csr_pmi.shape)

    print("PMI computation complete!")
    return output_pmi  # Return file path instead of keeping it in memory


def find_synonyms_fast(pmi_file, term_index, target_word, top_n=5):
    """ Efficient synonym retrieval using a stored PMI matrix. """
    if target_word not in term_index:
        print(f"Word '{target_word}' not found in vocabulary.")
        return []

    # Load sparse PMI matrix from file
    loaded = np.load(pmi_file)
    pmi_matrix = csr_matrix((loaded["data"], loaded["indices"], loaded["indptr"]), shape=loaded["shape"])

    words = list(term_index.keys())
    target_idx = term_index[target_word]

    # Compute sparse cosine similarity
    similarities = cosine_similarity(pmi_matrix[target_idx], pmi_matrix)[0]
    sorted_indices = np.argsort(similarities)[::-1]  # Descending order

    return [(words[i], similarities[i]) for i in sorted_indices if words[i] != target_word][:top_n]

### 5️⃣ Filter Synonyms Using Concept ID ###
def filter_synonyms_by_concept(synonyms, concept_id_map, target_word):
    """ Ensure synonyms belong to the same concept cluster. """
    target_concept = concept_id_map.get(target_word, None)
    if not target_concept:
        return synonyms  # No concept info available

    return [(word, score) for word, score in synonyms if concept_id_map.get(word) == target_concept]

def load_concept_to_term_map(file_path):
    """ Load concept-to-term mappings where multiple terms can map to the same concept. """
    concept_to_term_map = defaultdict(list)

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            try:
                term_id, concept_id = line.strip().split("\t")
                concept_to_term_map[concept_id].append(term_id)  # Store all terms for a concept
            except ValueError:
                continue  # Skip malformed lines

    return concept_to_term_map


if __name__ == "__main__":
    # File Paths
    mapping_files = [
        "1_term_ID_to_string.txt",
        "2a_concept_ID_to_string.txt"
    ]
    concept_map_file = "3_term_ID_to_concept_ID.txt"
    singleton_file = "singlets_concepts_perBin_1d.txt"
    cofreq_file = "cofreqs_concepts_perBin_1d.txt"

    # Load mappings
    term_id_map, _ = load_term_id_to_string(mapping_files)
    concept_to_term_map = load_concept_to_term_map(concept_map_file)

    # Load Data (Only First 100 Lines)
    singleton_freq = load_singleton_frequencies(singleton_file, concept_to_term_map, term_id_map)
    cofreq_output_file = load_cofreq_counts(cofreq_file, concept_to_term_map, term_id_map)

    total_count = sum(singleton_freq.values())

    # Compute PMI (Streaming, Small Dataset)
    term_index = {term: i for i, term in enumerate(singleton_freq.keys())}
    matrix_size = len(term_index)

    pmi_output_file = compute_npmi(cofreq_output_file, singleton_freq, total_count, term_index, matrix_size, max_rows=1000000)


    # Find synonyms
    target_word = "leukemia"
    synonyms = find_synonyms_fast(pmi_output_file, term_index, target_word)

    # Output results
    print(f"Top synonyms for '{target_word}':")
    for word, score in synonyms:
        print(f"{word}: {score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed 3577000 lines
# Processed 3578000 lines
# Processed 3579000 lines
# Processed 3580000 lines
# Processed 3581000 lines
# Processed 3582000 lines
# Processed 3583000 lines
# Processed 3584000 lines
# Processed 3585000 lines
# Processed 3586000 lines
# Processed 3587000 lines
# Processed 3588000 lines
# Processed 3589000 lines
# Processed 3590000 lines
# Processed 3591000 lines
# Processed 3592000 lines
# Processed 3593000 lines
# Processed 3594000 lines
# Processed 3595000 lines
# Processed 3596000 lines
# Processed 3597000 lines
# Processed 3598000 lines
# Processed 3599000 lines
# Processed 3600000 lines
# Processed 3601000 lines
# Processed 3602000 lines
# Processed 3603000 lines
# Processed 3604000 lines
# Processed 3605000 lines
# Processed 3606000 lines
# Processed 3607000 lines
# Processed 3608000 lines
# Processed 3609000 lines
# Processed 3610000 lines
# Processed 3611000 lines
# Processed 3612000 lines
# Processed 3613000 lines
# Processed 3614000 lines
# Processed 3615000 lines
# Processed 3616000 lines
# Processed 3617000 lines
# Processed 3618000 lines
# Processed 3619000 lines
# Processed 3620000 lines
# Processed 3621000 lines
# Processed 3622000 lines
# Processed 3623000 lines
# Processed 3624000 lines
# Processed 3625000 lines
# Processed 3626000 lines
# Processed 3627000 lines
# Processed 3628000 lines
# Processed 3629000 lines
# Processed 3630000 lines
# Processed 3631000 lines
# Processed 3632000 lines
# Processed 3633000 lines
# Processed 3634000 lines
# Processed 3635000 lines
# Processed 3636000 lines
# Processed 3637000 lines
# Processed 3638000 lines
# Processed 3639000 lines
# Processed 3640000 lines
# Processed 3641000 lines
# Processed 3642000 lines
# Processed 3643000 lines
# Processed 3644000 lines
# Processed 3645000 lines
# Processed 3646000 lines
# Processed 3647000 lines
# Processed 3648000 lines
# Processed 3649000 lines
# Processed 3650000 lines
# Processed 3651000 lines
# Processed 3652000 lines
# Processed 3653000 lines
# Processed 3654000 lines
# Processed 3655000 lines
# Processed 3656000 lines
# Processed 3657000 lines
# Processed 3658000 lines
# Processed 3659000 lines
# Processed 3660000 lines
# Processed 3661000 lines
# Processed 3662000 lines
# Processed 3663000 lines
# Processed 3664000 lines
# Processed 3665000 lines
# Processed 3666000 lines
# Processed 3667000 lines
# Processed 3668000 lines
# Processed 3669000 lines
# Processed 3670000 lines
# Processed 3671000 lines
# Processed 3672000 lines
# Processed 3673000 lines
# Processed 3674000 lines
# Processed 3675000 lines
# Processed 3676000 lines
# Processed 3677000 lines
# Processed 3678000 lines
# Processed 3679000 lines
# Processed 3680000 lines
# Processed 3681000 lines
# Processed 3682000 lines
# Processed 3683000 lines
# Processed 3684000 lines
# Processed 3685000 lines
# Processed 3686000 lines
# Processed 3687000 lines
# Processed 3688000 lines
# Processed 3689000 lines
# Processed 3690000 lines
# Processed 3691000 lines
# Processed 3692000 lines
# Processed 3693000 lines
# Processed 3694000 lines
# Processed 3695000 lines
# Processed 3696000 lines
# Processed 3697000 lines
# Processed 3698000 lines
# Processed 3699000 lines
# Processed 3700000 lines
# Processed 3701000 lines
# Processed 3702000 lines
# Processed 3703000 lines
# Processed 3704000 lines
# Processed 3705000 lines
# Processed 3706000 lines
# Processed 3707000 lines
# Processed 3708000 lines
# Processed 3709000 lines
# Processed 3710000 lines
# Processed 3711000 lines
# Processed 3712000 lines
# Processed 3713000 lines
# Processed 3714000 lines
# Processed 3715000 lines
# Processed 3716000 lines
# Processed 3717000 lines
# Processed 3718000 lines
# Processed 3719000 lines
# Processed 3720000 lines
# Processed 3721000 lines
# Processed 3722000 lines
# Processed 3723000 lines
# Processed 3724000 lines
# Processed 3725000 lines
# Processed 3726000 lines
# Processed 3727000 lines
# Processed 3728000 lines
# Processed 3729000 lines
# Processed 3730000 lines
# Processed 3731000 lines
# Processed 3732000 lines
# Processed 3733000 lines
# Processed 3734000 lines
# Processed 3735000 lines
# Processed 3736000 lines
# Processed 3737000 lines
# Processed 3738000 lines
# Processed 3739000 lines
# Processed 3740000 lines
# Processed 3741000 lines
# Processed 3742000 lines
# Processed 3743000 lines
# Processed 3744000 lines
# Processed 3745000 lines
# Processed 3746000 lines
# Processed 3747000 lines
# Processed 3748000 lines
# Processed 3749000 lines
# Processed 3750000 lines
# Processed 3751000 lines
# Processed 3752000 lines
# Processed 3753000 lines
# Processed 3754000 lines
# Processed 3755000 lines
# Processed 3756000 lines
# Processed 3757000 lines
# Processed 3758000 lines
# Processed 3759000 lines
# Processed 3760000 lines
# Processed 3761000 lines
# Processed 3762000 lines
# Processed 3763000 lines
# Processed 3764000 lines
# Processed 3765000 lines
# Processed 3766000 lines
# Processed 3767000 lines
# Processed 3768000 lines
# Processed 3769000 lines
# Processed 3770000 lines
# Processed 3771000 lines
# Processed 3772000 lines
# Processed 3773000 lines
# Processed 3774000 lines
# Processed 3775000 lines
# Processed 3776000 lines
# Processed 3777000 lines
# Processed 3778000 lines
# Processed 3779000 lines
# Processed 3780000 lines
# Processed 3781000 lines
# Processed 3782000 lines
# Processed 3783000 lines
# Processed 3784000 lines
# Processed 3785000 lines
# Processed 3786000 lines
# Processed 3787000 lines
# Processed 3788000 lines
# Processed 3789000 lines
# Processed 3790000 lines
# Processed 3791000 lines
# Processed 3792000 lines
# Processed 3793000 lines
# Processed 3794000 lines
# Processed 3795000 lines
# Processed 3796000 lines
# Processed 3797000 lines
# Processed 3798000 lines
# Processed 3799000 lines
# Processed 3800000 lines
# Processed 3801000 lines
# Processed 3802000 lines
# Processed 3803000 lines
# Processed 3804000 lines
# Processed 3805000 lines
# Processed 3806000 lines
# Processed 3807000 lines
# Processed 3808000 lines
# Processed 3809000 lines
# Processed 3810000 lines
# Processed 3811000 lines
# Processed 3812000 lines
# Processed 3813000 lines
# Processed 3814000 lines
# Processed 3815000 lines
# Processed 3816000 lines
# Processed 3817000 lines
# Processed 3818000 lines
# Processed 3819000 lines
# Processed 3820000 lines
# Processed 3821000 lines
# Processed 3822000 lines
# Processed 3823000 lines
# Processed 3824000 lines
# Processed 3825000 lines
# Processed 3826000 lines
# Processed 3827000 lines
# Processed 3828000 lines
# Processed 3829000 lines
# Processed 3830000 lines
# Processed 3831000 lines
# Processed 3832000 lines
# Processed 3833000 lines
# Processed 3834000 lines
# Processed 3835000 lines
# Processed 3836000 lines
# Processed 3837000 lines
# Processed 3838000 lines
# Processed 3839000 lines
# Processed 3840000 lines
# Processed 3841000 lines
# Processed 3842000 lines
# Processed 3843000 lines
# Processed 3844000 lines
# Processed 3845000 lines
# Processed 3846000 lines
# Processed 3847000 lines
# Processed 3848000 lines
# Processed 3849000 lines
# Processed 3850000 lines
# Processed 3851000 lines
# Processed 3852000 lines
# Processed 3853000 lines
# Processed 3854000 lines
# Processed 3855000 lines
# Processed 3856000 lines
# Processed 3857000 lines
# Processed 3858000 lines
# Processed 3859000 lines
# Processed 3860000 lines
# Processed 3861000 lines
# Processed 3862000 lines
# Processed 3863000 lines
# Processed 3864000 lines
# Processed 3865000 lines
# Processed 3866000 lines
# Processed 3867000 lines
# Processed 3868000 lines
# Processed 3869000 lines
# Processed 3870000 lines
# Processed 3871000 lines
# Processed 3872000 lines
# Processed 3873000 lines
# Processed 3874000 lines
# Processed 3875000 lines
# Processed 3876000 lines
# Processed 3877000 lines
# Processed 3878000 lines
# Processed 3879000 lines
# Processed 3880000 lines
# Processed 3881000 lines
# Processed 3882000 lines
# Processed 3883000 lines
# Processed 3884000 lines
# Processed 3885000 lines
# Processed 3886000 lines
# Processed 3887000 lines
# Processed 3888000 lines
# Processed 3889000 lines
# Processed 3890000 lines
# Processed 3891000 lines
# Processed 3892000 lines
# Processed 3893000 lines
# Processed 3894000 lines
# Processed 3895000 lines
# Processed 3896000 lines
# Processed 3897000 lines
# Processed 3898000 lines
# Processed 3899000 lines
# Processed 3900000 lines
# Processed 3901000 lines
# Processed 3902000 lines
# Processed 3903000 lines
# Processed 3904000 lines
# Processed 3905000 lines
# Processed 3906000 lines
# Processed 3907000 lines
# Processed 3908000 lines
# Processed 3909000 lines
# Processed 3910000 lines
# Processed 3911000 lines
# Processed 3912000 lines
# Processed 3913000 lines
# Processed 3914000 lines
# Processed 3915000 lines
# Processed 3916000 lines
# Processed 3917000 lines
# Processed 3918000 lines
# Processed 3919000 lines
# Processed 3920000 lines
# Processed 3921000 lines
# Processed 3922000 lines
# Processed 3923000 lines
# Processed 3924000 lines
# Processed 3925000 lines
# Processed 3926000 lines
# Processed 3927000 lines
# Processed 3928000 lines
# Processed 3929000 lines
# Processed 3930000 lines
# Processed 3931000 lines
# Processed 3932000 lines
# Processed 3933000 lines
# Processed 3934000 lines
# Processed 3935000 lines
# Processed 3936000 lines
# Processed 3937000 lines
# Processed 3938000 lines
# Processed 3939000 lines
# Processed 3940000 lines
# Processed 3941000 lines
# Processed 3942000 lines
# Processed 3943000 lines
# Processed 3944000 lines
# Processed 3945000 lines
# Processed 3946000 lines
# Processed 3947000 lines
# Processed 3948000 lines
# Processed 3949000 lines
# Processed 3950000 lines
# Processed 3951000 lines
# Processed 3952000 lines
# Processed 3953000 lines
# Processed 3954000 lines
# Processed 3955000 lines
# Processed 3956000 lines
# Processed 3957000 lines
# Processed 3958000 lines
# Processed 3959000 lines
# Processed 3960000 lines
# Processed 3961000 lines
# Processed 3962000 lines
# Processed 3963000 lines
# Processed 3964000 lines
# Processed 3965000 lines
# Processed 3966000 lines
# Processed 3967000 lines
# Processed 3968000 lines
# Processed 3969000 lines
# Processed 3970000 lines
# Processed 3971000 lines
# Processed 3972000 lines
# Processed 3973000 lines
# Processed 3974000 lines
# Processed 3975000 lines
# Processed 3976000 lines
# Processed 3977000 lines
# Processed 3978000 lines
# Processed 3979000 lines
# Processed 3980000 lines
# Processed 3981000 lines
# Processed 3982000 lines
# Processed 3983000 lines
# Processed 3984000 lines
# Processed 3985000 lines
# Processed 3986000 lines
# Processed 3987000 lines
# Processed 3988000 lines
# Processed 3989000 lines
# Processed 3990000 lines
# Processed 3991000 lines
# Processed 3992000 lines
# Processed 3993000 lines
# Processed 3994000 lines
# Processed 3995000 lines
# Processed 3996000 lines
# Processed 3997000 lines
# Processed 3998000 lines
# Processed 3999000 lines
# Processed 4000000 lines
# Processed 4001000 lines
# Processed 4002000 lines
# Processed 4003000 lines
# Processed 4004000 lines
# Processed 4005000 lines
# Processed 4006000 lines
# Processed 4007000 lines
# Processed 4008000 lines
# Processed 4009000 lines
# Processed 4010000 lines
# Processed 4011000 lines
# Processed 4012000 lines
# Processed 4013000 lines
# Processed 4014000 lines
# Processed 4015000 lines
# Processed 4016000 lines
# Processed 4017000 lines
# Processed 4018000 lines
# Processed 4019000 lines
# Processed 4020000 lines
# Processed 4021000 lines
# Processed 4022000 lines
# Processed 4023000 lines
# Processed 4024000 lines
# Processed 4025000 lines
# Processed 4026000 lines
# Processed 4027000 lines
# Processed 4028000 lines
# Processed 4029000 lines
# Processed 4030000 lines
# Processed 4031000 lines
# Processed 4032000 lines
# Processed 4033000 lines
# Processed 4034000 lines
# Processed 4035000 lines
# Processed 4036000 lines
# Processed 4037000 lines
# Processed 4038000 lines
# Processed 4039000 lines
# Processed 4040000 lines
# Processed 4041000 lines
# Processed 4042000 lines
# Processed 4043000 lines
# Processed 4044000 lines
# Processed 4045000 lines
# Processed 4046000 lines
# Processed 4047000 lines
# Processed 4048000 lines
# Processed 4049000 lines
# Processed 4050000 lines
# Processed 4051000 lines
# Processed 4052000 lines
# Processed 4053000 lines
# Processed 4054000 lines
# Processed 4055000 lines
# Processed 4056000 lines
# Processed 4057000 lines
# Processed 4058000 lines
# Processed 4059000 lines
# Processed 4060000 lines
# Processed 4061000 lines
# Processed 4062000 lines
# Processed 4063000 lines
# Processed 4064000 lines
# Processed 4065000 lines
# Processed 4066000 lines
# Processed 4067000 lines
# Processed 4068000 lines
# Processed 4069000 lines
# Processed 4070000 lines
# Processed 4071000 lines
# Processed 4072000 lines
# Processed 4073000 lines
# Processed 4074000 lines
# Processed 4075000 lines
# Processed 4076000 lines
# Processed 4077000 lines
# Processed 4078000 lines
# Processed 4079000 lines
# Processed 4080000 lines
# Processed 4081000 lines
# Processed 4082000 lines
# Processed 4083000 lines
# Processed 4084000 lines
# Processed 4085000 lines
# Processed 4086000 lines
# Processed 4087000 lines
# Processed 4088000 lines
# Processed 4089000 lines
# Processed 4090000 lines
# Processed 4091000 lines
# Processed 4092000 lines
# Processed 4093000 lines
# Processed 4094000 lines
# Processed 4095000 lines
# Processed 4096000 lines
# Processed 4097000 lines
# Processed 4098000 lines
# Processed 4099000 lines
# Processed 4100000 lines
# Processed 4101000 lines
# Processed 4102000 lines
# Processed 4103000 lines
# Processed 4104000 lines
# Processed 4105000 lines
# Processed 4106000 lines
# Processed 4107000 lines
# Processed 4108000 lines
# Processed 4109000 lines
# Processed 4110000 lines
# Processed 4111000 lines
# Processed 4112000 lines
# Processed 4113000 lines
# Processed 4114000 lines
# Processed 4115000 lines
# Processed 4116000 lines
# Processed 4117000 lines
# Processed 4118000 lines
# Processed 4119000 lines
# Processed 4120000 lines
# Processed 4121000 lines
# Processed 4122000 lines
# Processed 4123000 lines
# Processed 4124000 lines
# Processed 4125000 lines
# Processed 4126000 lines
# Processed 4127000 lines
# Processed 4128000 lines
# Processed 4129000 lines
# Processed 4130000 lines
# Processed 4131000 lines
# Processed 4132000 lines
# Processed 4133000 lines
# Processed 4134000 lines
# Processed 4135000 lines
# Processed 4136000 lines
# Processed 4137000 lines
# Processed 4138000 lines
# Processed 4139000 lines
# Processed 4140000 lines
# Processed 4141000 lines
# Processed 4142000 lines
# Processed 4143000 lines
# Processed 4144000 lines
# Processed 4145000 lines
# Processed 4146000 lines
# Processed 4147000 lines
# Processed 4148000 lines
# Processed 4149000 lines
# Processed 4150000 lines
# Processed 4151000 lines
# Processed 4152000 lines
# Processed 4153000 lines
# Processed 4154000 lines
# Processed 4155000 lines
# Processed 4156000 lines
# Processed 4157000 lines
# Processed 4158000 lines
# Processed 4159000 lines
# Processed 4160000 lines
# Processed 4161000 lines
# Processed 4162000 lines
# Processed 4163000 lines
# Processed 4164000 lines
# Processed 4165000 lines
# Processed 4166000 lines
# Processed 4167000 lines
# Processed 4168000 lines
# Processed 4169000 lines
# Processed 4170000 lines
# Processed 4171000 lines
# Processed 4172000 lines
# Processed 4173000 lines
# Processed 4174000 lines
# Processed 4175000 lines
# Processed 4176000 lines
# Processed 4177000 lines
# Processed 4178000 lines
# Processed 4179000 lines
# Processed 4180000 lines
# Processed 4181000 lines
# Processed 4182000 lines
# Processed 4183000 lines
# Processed 4184000 lines
# Processed 4185000 lines
# Processed 4186000 lines
# Processed 4187000 lines
# Processed 4188000 lines
# Processed 4189000 lines
# Processed 4190000 lines
# Processed 4191000 lines
# Processed 4192000 lines
# Processed 4193000 lines
# Processed 4194000 lines
# Processed 4195000 lines
# Processed 4196000 lines
# Processed 4197000 lines
# Processed 4198000 lines
# Processed 4199000 lines
# Processed 4200000 lines
# Processed 4201000 lines
# Processed 4202000 lines
# Processed 4203000 lines
# Processed 4204000 lines
# Processed 4205000 lines
# Processed 4206000 lines
# Processed 4207000 lines
# Processed 4208000 lines
# Processed 4209000 lines
# Processed 4210000 lines
# Processed 4211000 lines
# Processed 4212000 lines
# Processed 4213000 lines
# Processed 4214000 lines
# Processed 4215000 lines
# Processed 4216000 lines
# Processed 4217000 lines
# Processed 4218000 lines
# Processed 4219000 lines
# Processed 4220000 lines
# Processed 4221000 lines
# Processed 4222000 lines
# Processed 4223000 lines
# Processed 4224000 lines
# Processed 4225000 lines
# Processed 4226000 lines
# Processed 4227000 lines
# Processed 4228000 lines
# Processed 4229000 lines
# Processed 4230000 lines
# Processed 4231000 lines
# Processed 4232000 lines
# Processed 4233000 lines
# Processed 4234000 lines
# Processed 4235000 lines
# Processed 4236000 lines
# Processed 4237000 lines
# Processed 4238000 lines
# Processed 4239000 lines
# Processed 4240000 lines
# Processed 4241000 lines
# Processed 4242000 lines
# Processed 4243000 lines
# Processed 4244000 lines
# Processed 4245000 lines
# Processed 4246000 lines
# Processed 4247000 lines
# Processed 4248000 lines
# Processed 4249000 lines
# Processed 4250000 lines
# Processed 4251000 lines
# Processed 4252000 lines
# Processed 4253000 lines
# Processed 4254000 lines
# Processed 4255000 lines
# Processed 4256000 lines
# Processed 4257000 lines
# Processed 4258000 lines
# Processed 4259000 lines
# Processed 4260000 lines
# Processed 4261000 lines
# Processed 4262000 lines
# Processed 4263000 lines
# Processed 4264000 lines
# Processed 4265000 lines
# Processed 4266000 lines
# Processed 4267000 lines
# Processed 4268000 lines
# Processed 4269000 lines
# Processed 4270000 lines
# Processed 4271000 lines
# Processed 4272000 lines
# Processed 4273000 lines
# Processed 4274000 lines
# Processed 4275000 lines
# Processed 4276000 lines
# Processed 4277000 lines
# Processed 4278000 lines
# Processed 4279000 lines
# Processed 4280000 lines
# Processed 4281000 lines
# Processed 4282000 lines
# Processed 4283000 lines
# Processed 4284000 lines
# Processed 4285000 lines
# Processed 4286000 lines
# Processed 4287000 lines
# Processed 4288000 lines
# Processed 4289000 lines
# Processed 4290000 lines
# Processed 4291000 lines
# Processed 4292000 lines
# Processed 4293000 lines
# Processed 4294000 lines
# Processed 4295000 lines
# Processed 4296000 lines
# Processed 4297000 lines
# Processed 4298000 lines
# Processed 4299000 lines
# Processed 4300000 lines
# Processed 4301000 lines
# Processed 4302000 lines
# Processed 4303000 lines
# Processed 4304000 lines
# Processed 4305000 lines
# Processed 4306000 lines
# Processed 4307000 lines
# Processed 4308000 lines
# Processed 4309000 lines
# Processed 4310000 lines
# Processed 4311000 lines
# Processed 4312000 lines
# Processed 4313000 lines
# Processed 4314000 lines
# Processed 4315000 lines
# Processed 4316000 lines
# Processed 4317000 lines
# Processed 4318000 lines
# Processed 4319000 lines
# Processed 4320000 lines
# Processed 4321000 lines
# Processed 4322000 lines
# Processed 4323000 lines
# Processed 4324000 lines
# Processed 4325000 lines
# Processed 4326000 lines
# Processed 4327000 lines
# Processed 4328000 lines
# Processed 4329000 lines
# Processed 4330000 lines
# Processed 4331000 lines
# Processed 4332000 lines
# Processed 4333000 lines
# Processed 4334000 lines
# Processed 4335000 lines
# Processed 4336000 lines
# Processed 4337000 lines
# Processed 4338000 lines
# Processed 4339000 lines
# Processed 4340000 lines
# Processed 4341000 lines
# Processed 4342000 lines
# Processed 4343000 lines
# Processed 4344000 lines
# Processed 4345000 lines
# Processed 4346000 lines
# Processed 4347000 lines
# Processed 4348000 lines
# Processed 4349000 lines
# Processed 4350000 lines
# Processed 4351000 lines
# Processed 4352000 lines
# Processed 4353000 lines
# Processed 4354000 lines
# Processed 4355000 lines
# Processed 4356000 lines
# Processed 4357000 lines
# Processed 4358000 lines
# Processed 4359000 lines
# Processed 4360000 lines
# Processed 4361000 lines
# Processed 4362000 lines
# Processed 4363000 lines
# Processed 4364000 lines
# Processed 4365000 lines
# Processed 4366000 lines
# Processed 4367000 lines
# Processed 4368000 lines
# Processed 4369000 lines
# Processed 4370000 lines
# Processed 4371000 lines
# Processed 4372000 lines
# Processed 4373000 lines
# Processed 4374000 lines
# Processed 4375000 lines
# Processed 4376000 lines
# Processed 4377000 lines
# Processed 4378000 lines
# Processed 4379000 lines
# Processed 4380000 lines
# Processed 4381000 lines
# Processed 4382000 lines
# Processed 4383000 lines
# Processed 4384000 lines
# Processed 4385000 lines
# Processed 4386000 lines
# Processed 4387000 lines
# Processed 4388000 lines
# Processed 4389000 lines
# Processed 4390000 lines
# Processed 4391000 lines
# Processed 4392000 lines
# Processed 4393000 lines
# Processed 4394000 lines
# Processed 4395000 lines
# Processed 4396000 lines
# Processed 4397000 lines
# Processed 4398000 lines
# Processed 4399000 lines
# Processed 4400000 lines
# Processed 4401000 lines
# Processed 4402000 lines
# Processed 4403000 lines
# Processed 4404000 lines
# Processed 4405000 lines
# Processed 4406000 lines
# Processed 4407000 lines
# Processed 4408000 lines
# Processed 4409000 lines
# Processed 4410000 lines
# Processed 4411000 lines
# Processed 4412000 lines
# Processed 4413000 lines
# Processed 4414000 lines
# Processed 4415000 lines
# Processed 4416000 lines
# Processed 4417000 lines
# Processed 4418000 lines
# Processed 4419000 lines
# Processed 4420000 lines
# Processed 4421000 lines
# Processed 4422000 lines
# Processed 4423000 lines
# Processed 4424000 lines
# Processed 4425000 lines
# Processed 4426000 lines
# Processed 4427000 lines
# Processed 4428000 lines
# Processed 4429000 lines
# Processed 4430000 lines
# Processed 4431000 lines
# Processed 4432000 lines
# Processed 4433000 lines
# Processed 4434000 lines
# Processed 4435000 lines
# Processed 4436000 lines
# Processed 4437000 lines
# Processed 4438000 lines
# Processed 4439000 lines
# Processed 4440000 lines
# Processed 4441000 lines
# Processed 4442000 lines
# Processed 4443000 lines
# Processed 4444000 lines
# Processed 4445000 lines
# Processed 4446000 lines
# Processed 4447000 lines
# Processed 4448000 lines
# Processed 4449000 lines
# Processed 4450000 lines
# Processed 4451000 lines
# Processed 4452000 lines
# Processed 4453000 lines
# Processed 4454000 lines
# Processed 4455000 lines
# Processed 4456000 lines
# Processed 4457000 lines
# Processed 4458000 lines
# Processed 4459000 lines
# Processed 4460000 lines
# Processed 4461000 lines
# Processed 4462000 lines
# Processed 4463000 lines
# Processed 4464000 lines
# Processed 4465000 lines
# Processed 4466000 lines
# Processed 4467000 lines
# Processed 4468000 lines
# Processed 4469000 lines
# Processed 4470000 lines
# Processed 4471000 lines
# Processed 4472000 lines
# Processed 4473000 lines
# Processed 4474000 lines
# Processed 4475000 lines
# Processed 4476000 lines
# Processed 4477000 lines
# Processed 4478000 lines
# Processed 4479000 lines
# Processed 4480000 lines
# Processed 4481000 lines
# Processed 4482000 lines
# Processed 4483000 lines
# Processed 4484000 lines
# Processed 4485000 lines
# Processed 4486000 lines
# Processed 4487000 lines
# Processed 4488000 lines
# Processed 4489000 lines
# Processed 4490000 lines
# Processed 4491000 lines
# Processed 4492000 lines
# Processed 4493000 lines
# Processed 4494000 lines
# Processed 4495000 lines
# Processed 4496000 lines
# Processed 4497000 lines
# Processed 4498000 lines
# Processed 4499000 lines
# Processed 4500000 lines
# Processed 4501000 lines
# Processed 4502000 lines
# Processed 4503000 lines
# Processed 4504000 lines
# Processed 4505000 lines
# Processed 4506000 lines
# Processed 4507000 lines
# Processed 4508000 lines
# Processed 4509000 lines
# Processed 4510000 lines
# Processed 4511000 lines
# Processed 4512000 lines
# Processed 4513000 lines
# Processed 4514000 lines
# Processed 4515000 lines
# Processed 4516000 lines
# Processed 4517000 lines
# Processed 4518000 lines
# Processed 4519000 lines
# Processed 4520000 lines
# Processed 4521000 lines
# Processed 4522000 lines
# Processed 4523000 lines
# Processed 4524000 lines
# Processed 4525000 lines
# Processed 4526000 lines
# Processed 4527000 lines
# Processed 4528000 lines
# Processed 4529000 lines
# Processed 4530000 lines
# Processed 4531000 lines
# Processed 4532000 lines
# Processed 4533000 lines
# Processed 4534000 lines
# Processed 4535000 lines
# Processed 4536000 lines
# Processed 4537000 lines
# Processed 4538000 lines
# Processed 4539000 lines
# Processed 4540000 lines
# Processed 4541000 lines
# Processed 4542000 lines
# Processed 4543000 lines
# Processed 4544000 lines
# Processed 4545000 lines
# Processed 4546000 lines
# Processed 4547000 lines
# Processed 4548000 lines
# Processed 4549000 lines
# Processed 4550000 lines
# Processed 4551000 lines
# Processed 4552000 lines
# Processed 4553000 lines
# Processed 4554000 lines
# Processed 4555000 lines
# Processed 4556000 lines
# Processed 4557000 lines
# Processed 4558000 lines
# Processed 4559000 lines
# Processed 4560000 lines
# Processed 4561000 lines
# Processed 4562000 lines
# Processed 4563000 lines
# Processed 4564000 lines
# Processed 4565000 lines
# Processed 4566000 lines
# Processed 4567000 lines
# Processed 4568000 lines
# Processed 4569000 lines
# Processed 4570000 lines
# Processed 4571000 lines
# Processed 4572000 lines
# Processed 4573000 lines
# Processed 4574000 lines
# Processed 4575000 lines
# Processed 4576000 lines
# Processed 4577000 lines
# Processed 4578000 lines
# Processed 4579000 lines
# Processed 4580000 lines
# Processed 4581000 lines
# Processed 4582000 lines
# Processed 4583000 lines
# Processed 4584000 lines
# Processed 4585000 lines
# Processed 4586000 lines
# Processed 4587000 lines
# Processed 4588000 lines
# Processed 4589000 lines
# Processed 4590000 lines
# Processed 4591000 lines
# Processed 4592000 lines
# Processed 4593000 lines
# Processed 4594000 lines
# Processed 4595000 lines
# Processed 4596000 lines
# Processed 4597000 lines
# Processed 4598000 lines
# Processed 4599000 lines
# Processed 4600000 lines
# Processed 4601000 lines
# Processed 4602000 lines
# Processed 4603000 lines
# Processed 4604000 lines
# Processed 4605000 lines
# Processed 4606000 lines
# Processed 4607000 lines
# Processed 4608000 lines
# Processed 4609000 lines
# Processed 4610000 lines
# Processed 4611000 lines
# Processed 4612000 lines
# Processed 4613000 lines
# Processed 4614000 lines
# Processed 4615000 lines
# Processed 4616000 lines
# Processed 4617000 lines
# Processed 4618000 lines
# Processed 4619000 lines
# Processed 4620000 lines
# Processed 4621000 lines
# Processed 4622000 lines
# Processed 4623000 lines
# Processed 4624000 lines
# Processed 4625000 lines
# Processed 4626000 lines
# Processed 4627000 lines
# Processed 4628000 lines
# Processed 4629000 lines
# Processed 4630000 lines
# Processed 4631000 lines
# Processed 4632000 lines
# Processed 4633000 lines
# Processed 4634000 lines
# Processed 4635000 lines
# Processed 4636000 lines
# Processed 4637000 lines
# Processed 4638000 lines
# Processed 4639000 lines
# Processed 4640000 lines
# Processed 4641000 lines
# Processed 4642000 lines
# Processed 4643000 lines
# Processed 4644000 lines
# Processed 4645000 lines
# Processed 4646000 lines
# Processed 4647000 lines
# Processed 4648000 lines
# Processed 4649000 lines
# Processed 4650000 lines
# Processed 4651000 lines
# Processed 4652000 lines
# Processed 4653000 lines
# Processed 4654000 lines
# Processed 4655000 lines
# Processed 4656000 lines
# Processed 4657000 lines
# Processed 4658000 lines
# Processed 4659000 lines
# Processed 4660000 lines
# Processed 4661000 lines
# Processed 4662000 lines
# Processed 4663000 lines
# Processed 4664000 lines
# Processed 4665000 lines
# Processed 4666000 lines
# Processed 4667000 lines
# Processed 4668000 lines
# Processed 4669000 lines
# Processed 4670000 lines
# Processed 4671000 lines
# Processed 4672000 lines
# Processed 4673000 lines
# Processed 4674000 lines
# Processed 4675000 lines
# Processed 4676000 lines
# Processed 4677000 lines
# Processed 4678000 lines
# Processed 4679000 lines
# Processed 4680000 lines
# Processed 4681000 lines
# Processed 4682000 lines
# Processed 4683000 lines
# Processed 4684000 lines
# Processed 4685000 lines
# Processed 4686000 lines
# Processed 4687000 lines
# Processed 4688000 lines
# Processed 4689000 lines
# Processed 4690000 lines
# Processed 4691000 lines
# Processed 4692000 lines
# Processed 4693000 lines
# Processed 4694000 lines
# Processed 4695000 lines
# Processed 4696000 lines
# Processed 4697000 lines
# Processed 4698000 lines
# Processed 4699000 lines
# Processed 4700000 lines
# Processed 4701000 lines
# Processed 4702000 lines
# Processed 4703000 lines
# Processed 4704000 lines
# Processed 4705000 lines
# Processed 4706000 lines
# Processed 4707000 lines
# Processed 4708000 lines
# Processed 4709000 lines
# Processed 4710000 lines
# Processed 4711000 lines
# Processed 4712000 lines
# Processed 4713000 lines
# Processed 4714000 lines
# Processed 4715000 lines
# Processed 4716000 lines
# Processed 4717000 lines
# Processed 4718000 lines
# Processed 4719000 lines
# Processed 4720000 lines
# Processed 4721000 lines
# Processed 4722000 lines
# Processed 4723000 lines
# Processed 4724000 lines
# Processed 4725000 lines
# Processed 4726000 lines
# Processed 4727000 lines
# Processed 4728000 lines
# Processed 4729000 lines
# Processed 4730000 lines
# Processed 4731000 lines
# Processed 4732000 lines
# Processed 4733000 lines
# Processed 4734000 lines
# Processed 4735000 lines
# Processed 4736000 lines
# Processed 4737000 lines
# Processed 4738000 lines
# Processed 4739000 lines
# Processed 4740000 lines
# Processed 4741000 lines
# Processed 4742000 lines
# Processed 4743000 lines
# Processed 4744000 lines
# Processed 4745000 lines
# Processed 4746000 lines
# Processed 4747000 lines
# Processed 4748000 lines
# Processed 4749000 lines
# Processed 4750000 lines
# Processed 4751000 lines
# Processed 4752000 lines
# Processed 4753000 lines
# Processed 4754000 lines
# Processed 4755000 lines
# Processed 4756000 lines
# Processed 4757000 lines
# Processed 4758000 lines
# Processed 4759000 lines
# Processed 4760000 lines
# Processed 4761000 lines
# Processed 4762000 lines
# Processed 4763000 lines
# Processed 4764000 lines
# Processed 4765000 lines
# Processed 4766000 lines
# Processed 4767000 lines
# Processed 4768000 lines
# Processed 4769000 lines
# Processed 4770000 lines
# Processed 4771000 lines
# Processed 4772000 lines
# Processed 4773000 lines
# Processed 4774000 lines
# Processed 4775000 lines
# Processed 4776000 lines
# Processed 4777000 lines
# Processed 4778000 lines
# Processed 4779000 lines
# Processed 4780000 lines
# Processed 4781000 lines
# Processed 4782000 lines
# Processed 4783000 lines
# Processed 4784000 lines
# Processed 4785000 lines
# Processed 4786000 lines
# Processed 4787000 lines
# Processed 4788000 lines
# Processed 4789000 lines
# Processed 4790000 lines
# Processed 4791000 lines
# Processed 4792000 lines
# Processed 4793000 lines
# Processed 4794000 lines
# Processed 4795000 lines
# Processed 4796000 lines
# Processed 4797000 lines
# Processed 4798000 lines
# Processed 4799000 lines
# Processed 4800000 lines
# Processed 4801000 lines
# Processed 4802000 lines
# Processed 4803000 lines
# Processed 4804000 lines
# Processed 4805000 lines
# Processed 4806000 lines
# Processed 4807000 lines
# Processed 4808000 lines
# Processed 4809000 lines
# Processed 4810000 lines
# Processed 4811000 lines
# Processed 4812000 lines
# Processed 4813000 lines
# Processed 4814000 lines
# Processed 4815000 lines
# Processed 4816000 lines
# Processed 4817000 lines
# Processed 4818000 lines
# Processed 4819000 lines
# Processed 4820000 lines
# Processed 4821000 lines
# Processed 4822000 lines
# Processed 4823000 lines
# Processed 4824000 lines
# Processed 4825000 lines
# Processed 4826000 lines
# Processed 4827000 lines
# Processed 4828000 lines
# Processed 4829000 lines
# Processed 4830000 lines
# Processed 4831000 lines
# Processed 4832000 lines
# Processed 4833000 lines
# Processed 4834000 lines
# Processed 4835000 lines
# Processed 4836000 lines
# Processed 4837000 lines
# Processed 4838000 lines
# Processed 4839000 lines
# Processed 4840000 lines
# Processed 4841000 lines
# Processed 4842000 lines
# Processed 4843000 lines
# Processed 4844000 lines
# Processed 4845000 lines
# Processed 4846000 lines
# Processed 4847000 lines
# Processed 4848000 lines
# Processed 4849000 lines
# Processed 4850000 lines
# Processed 4851000 lines
# Processed 4852000 lines
# Processed 4853000 lines
# Processed 4854000 lines
# Processed 4855000 lines
# Processed 4856000 lines
# Processed 4857000 lines
# Processed 4858000 lines
# Processed 4859000 lines
# Processed 4860000 lines
# Processed 4861000 lines
# Processed 4862000 lines
# Processed 4863000 lines
# Processed 4864000 lines
# Processed 4865000 lines
# Processed 4866000 lines
# Processed 4867000 lines
# Processed 4868000 lines
# Processed 4869000 lines
# Processed 4870000 lines
# Processed 4871000 lines
# Processed 4872000 lines
# Processed 4873000 lines
# Processed 4874000 lines
# Processed 4875000 lines
# Processed 4876000 lines
# Processed 4877000 lines
# Processed 4878000 lines
# Processed 4879000 lines
# Processed 4880000 lines
# Processed 4881000 lines
# Processed 4882000 lines
# Processed 4883000 lines
# Processed 4884000 lines
# Processed 4885000 lines
# Processed 4886000 lines
# Processed 4887000 lines
# Processed 4888000 lines
# Processed 4889000 lines
# Processed 4890000 lines
# Processed 4891000 lines
# Processed 4892000 lines
# Processed 4893000 lines
# Processed 4894000 lines
# Processed 4895000 lines
# Processed 4896000 lines
# Processed 4897000 lines
# Processed 4898000 lines
# Processed 4899000 lines
# Processed 4900000 lines
# Processed 4901000 lines
# Processed 4902000 lines
# Processed 4903000 lines
# Processed 4904000 lines
# Processed 4905000 lines
# Processed 4906000 lines
# Processed 4907000 lines
# Processed 4908000 lines
# Processed 4909000 lines
# Processed 4910000 lines
# Processed 4911000 lines
# Processed 4912000 lines
# Processed 4913000 lines
# Processed 4914000 lines
# Processed 4915000 lines
# Processed 4916000 lines
# Processed 4917000 lines
# Processed 4918000 lines
# Processed 4919000 lines
# Processed 4920000 lines
# Processed 4921000 lines
# Processed 4922000 lines
# Processed 4923000 lines
# Processed 4924000 lines
# Processed 4925000 lines
# Processed 4926000 lines
# Processed 4927000 lines
# Processed 4928000 lines
# Processed 4929000 lines
# Processed 4930000 lines
# Processed 4931000 lines
# Processed 4932000 lines
# Processed 4933000 lines
# Processed 4934000 lines
# Processed 4935000 lines
# Processed 4936000 lines
# Processed 4937000 lines
# Processed 4938000 lines
# Processed 4939000 lines
# Processed 4940000 lines
# Processed 4941000 lines
# Processed 4942000 lines
# Processed 4943000 lines
# Processed 4944000 lines
# Processed 4945000 lines
# Processed 4946000 lines
# Processed 4947000 lines
# Processed 4948000 lines
# Processed 4949000 lines
# Processed 4950000 lines
# Processed 4951000 lines
# Processed 4952000 lines
# Processed 4953000 lines
# Processed 4954000 lines
# Processed 4955000 lines
# Processed 4956000 lines
# Processed 4957000 lines
# Processed 4958000 lines
# Processed 4959000 lines
# Processed 4960000 lines
# Processed 4961000 lines
# Processed 4962000 lines
# Processed 4963000 lines
# Processed 4964000 lines
# Processed 4965000 lines
# Processed 4966000 lines
# Processed 4967000 lines
# Processed 4968000 lines
# Processed 4969000 lines
# Processed 4970000 lines
# Processed 4971000 lines
# Processed 4972000 lines
# Processed 4973000 lines
# Processed 4974000 lines
# Processed 4975000 lines
# Processed 4976000 lines
# Processed 4977000 lines
# Processed 4978000 lines
# Processed 4979000 lines
# Processed 4980000 lines
# Processed 4981000 lines
# Processed 4982000 lines
# Processed 4983000 lines
# Processed 4984000 lines
# Processed 4985000 lines
# Processed 4986000 lines
# Processed 4987000 lines
# Processed 4988000 lines
# Processed 4989000 lines
# Processed 4990000 lines
# Processed 4991000 lines
# Processed 4992000 lines
# Processed 4993000 lines
# Processed 4994000 lines
# Processed 4995000 lines
# Processed 4996000 lines
# Processed 4997000 lines
# Processed 4998000 lines
# Processed 4999000 lines
# Processed 5000000 lines
# Processed 5001000 lines
# Processed 5002000 lines
# Processed 5003000 lines
# Processed 5004000 lines
# Processed 5005000 lines
# Processed 5006000 lines
# Processed 5007000 lines
# Processed 5008000 lines
# Processed 5009000 lines
# Processed 5010000 lines
# Processed 5011000 lines
# Processed 5012000 lines
# Processed 5013000 lines
# Processed 5014000 lines
# Processed 5015000 lines
# Processed 5016000 lines
# Processed 5017000 lines
# Processed 5018000 lines
# Processed 5019000 lines
# Processed 5020000 lines
# Processed 5021000 lines
# Processed 5022000 lines
# Processed 5023000 lines
# Processed 5024000 lines
# Processed 5025000 lines
# Processed 5026000 lines
# Processed 5027000 lines
# Processed 5028000 lines
# Processed 5029000 lines
# Processed 5030000 lines
# Processed 5031000 lines
# Processed 5032000 lines
# Processed 5033000 lines
# Processed 5034000 lines
# Processed 5035000 lines
# Processed 5036000 lines
# Processed 5037000 lines
# Processed 5038000 lines
# Processed 5039000 lines
# Processed 5040000 lines
# Processed 5041000 lines
# Processed 5042000 lines
# Processed 5043000 lines
# Processed 5044000 lines
# Processed 5045000 lines
# Processed 5046000 lines
# Processed 5047000 lines
# Processed 5048000 lines
# Processed 5049000 lines
# Processed 5050000 lines
# Processed 5051000 lines
# Processed 5052000 lines
# Processed 5053000 lines
# Processed 5054000 lines
# Processed 5055000 lines
# Processed 5056000 lines
# Processed 5057000 lines
# Processed 5058000 lines
# Processed 5059000 lines
# Processed 5060000 lines
# Processed 5061000 lines
# Processed 5062000 lines
# Processed 5063000 lines
# Processed 5064000 lines
# Processed 5065000 lines
# Processed 5066000 lines
# Processed 5067000 lines
# Processed 5068000 lines
# Processed 5069000 lines
# Processed 5070000 lines
# Processed 5071000 lines
# Processed 5072000 lines
# Processed 5073000 lines
# Processed 5074000 lines
# Processed 5075000 lines
# Processed 5076000 lines
# Processed 5077000 lines
# Processed 5078000 lines
# Processed 5079000 lines
# Processed 5080000 lines
# Processed 5081000 lines
# Processed 5082000 lines
# Processed 5083000 lines
# Processed 5084000 lines
# Processed 5085000 lines
# Processed 5086000 lines
# Processed 5087000 lines
# Processed 5088000 lines
# Processed 5089000 lines
# Processed 5090000 lines
# Processed 5091000 lines
# Processed 5092000 lines
# Processed 5093000 lines
# Processed 5094000 lines
# Processed 5095000 lines
# Processed 5096000 lines
# Processed 5097000 lines
# Processed 5098000 lines
# Processed 5099000 lines
# Processed 5100000 lines
# Processed 5101000 lines
# Processed 5102000 lines
# Processed 5103000 lines
# Processed 5104000 lines
# Processed 5105000 lines
# Processed 5106000 lines
# Processed 5107000 lines
# Processed 5108000 lines
# Processed 5109000 lines
# Processed 5110000 lines
# Processed 5111000 lines
# Processed 5112000 lines
# Processed 5113000 lines
# Processed 5114000 lines
# Processed 5115000 lines
# Processed 5116000 lines
# Processed 5117000 lines
# Processed 5118000 lines
# Processed 5119000 lines
# Processed 5120000 lines
# Processed 5121000 lines
# Processed 5122000 lines
# Processed 5123000 lines
# Processed 5124000 lines
# Processed 5125000 lines
# Processed 5126000 lines
# Processed 5127000 lines
# Processed 5128000 lines
# Processed 5129000 lines
# Processed 5130000 lines
# Processed 5131000 lines
# Processed 5132000 lines
# Processed 5133000 lines
# Processed 5134000 lines
# Processed 5135000 lines
# Processed 5136000 lines
# Processed 5137000 lines
# Processed 5138000 lines
# Processed 5139000 lines
# Processed 5140000 lines
# Processed 5141000 lines
# Processed 5142000 lines
# Processed 5143000 lines
# Processed 5144000 lines
# Processed 5145000 lines
# Processed 5146000 lines
# Processed 5147000 lines
# Processed 5148000 lines
# Processed 5149000 lines
# Processed 5150000 lines
# Processed 5151000 lines
# Processed 5152000 lines
# Processed 5153000 lines
# Processed 5154000 lines
# Processed 5155000 lines
# Processed 5156000 lines
# Processed 5157000 lines
# Processed 5158000 lines
# Processed 5159000 lines
# Processed 5160000 lines
# Processed 5161000 lines
# Processed 5162000 lines
# Processed 5163000 lines
# Processed 5164000 lines
# Processed 5165000 lines
# Processed 5166000 lines
# Processed 5167000 lines
# Processed 5168000 lines
# Processed 5169000 lines
# Processed 5170000 lines
# Processed 5171000 lines
# Processed 5172000 lines
# Processed 5173000 lines
# Processed 5174000 lines
# Processed 5175000 lines
# Processed 5176000 lines
# Processed 5177000 lines
# Processed 5178000 lines
# Processed 5179000 lines
# Processed 5180000 lines
# Processed 5181000 lines
# Processed 5182000 lines
# Processed 5183000 lines
# Processed 5184000 lines
# Processed 5185000 lines
# Processed 5186000 lines
# Processed 5187000 lines
# Processed 5188000 lines
# Processed 5189000 lines
# Processed 5190000 lines
# Processed 5191000 lines
# Processed 5192000 lines
# Processed 5193000 lines
# Processed 5194000 lines
# Processed 5195000 lines
# Processed 5196000 lines
# Processed 5197000 lines
# Processed 5198000 lines
# Processed 5199000 lines
# Processed 5200000 lines
# Processed 5201000 lines
# Processed 5202000 lines
# Processed 5203000 lines
# Processed 5204000 lines
# Processed 5205000 lines
# Processed 5206000 lines
# Processed 5207000 lines
# Processed 5208000 lines
# Processed 5209000 lines
# Processed 5210000 lines
# Processed 5211000 lines
# Processed 5212000 lines
# Processed 5213000 lines
# Processed 5214000 lines
# Processed 5215000 lines
# Processed 5216000 lines
# Processed 5217000 lines
# Processed 5218000 lines
# Processed 5219000 lines
# Processed 5220000 lines
# Processed 5221000 lines
# Processed 5222000 lines
# Processed 5223000 lines
# Processed 5224000 lines
# Processed 5225000 lines
# Processed 5226000 lines
# Processed 5227000 lines
# Processed 5228000 lines
# Processed 5229000 lines
# Processed 5230000 lines
# Processed 5231000 lines
# Processed 5232000 lines
# Processed 5233000 lines
# Processed 5234000 lines
# Processed 5235000 lines
# Processed 5236000 lines
# Processed 5237000 lines
# Processed 5238000 lines
# Processed 5239000 lines
# Processed 5240000 lines
# Processed 5241000 lines
# Processed 5242000 lines
# Processed 5243000 lines
# Processed 5244000 lines
# Processed 5245000 lines
# Processed 5246000 lines
# Processed 5247000 lines
# Processed 5248000 lines
# Processed 5249000 lines
# Processed 5250000 lines
# Processed 5251000 lines
# Processed 5252000 lines
# Processed 5253000 lines
# Processed 5254000 lines
# Processed 5255000 lines
# Processed 5256000 lines
# Processed 5257000 lines
# Processed 5258000 lines
# Processed 5259000 lines
# Processed 5260000 lines
# Processed 5261000 lines
# Processed 5262000 lines
# Processed 5263000 lines
# Processed 5264000 lines
# Processed 5265000 lines
# Processed 5266000 lines
# Processed 5267000 lines
# Processed 5268000 lines
# Processed 5269000 lines
# Processed 5270000 lines
# Processed 5271000 lines
# Processed 5272000 lines
# Processed 5273000 lines
# Processed 5274000 lines
# Processed 5275000 lines
# Processed 5276000 lines
# Processed 5277000 lines
# Processed 5278000 lines
# Processed 5279000 lines
# Processed 5280000 lines
# Processed 5281000 lines
# Processed 5282000 lines
# Processed 5283000 lines
# Processed 5284000 lines
# Processed 5285000 lines
# Processed 5286000 lines
# Processed 5287000 lines
# Processed 5288000 lines
# Processed 5289000 lines
# Processed 5290000 lines
# Processed 5291000 lines
# Processed 5292000 lines
# Processed 5293000 lines
# Processed 5294000 lines
# Processed 5295000 lines
# Processed 5296000 lines
# Processed 5297000 lines
# Processed 5298000 lines
# Processed 5299000 lines
# Processed 5300000 lines
# Processed 5301000 lines
# Processed 5302000 lines
# Processed 5303000 lines
# Processed 5304000 lines
# Processed 5305000 lines
# Processed 5306000 lines
# Processed 5307000 lines
# Processed 5308000 lines
# Processed 5309000 lines
# Processed 5310000 lines
# Processed 5311000 lines
# Processed 5312000 lines
# Processed 5313000 lines
# Processed 5314000 lines
# Processed 5315000 lines
# Processed 5316000 lines
# Processed 5317000 lines
# Processed 5318000 lines
# Processed 5319000 lines
# Processed 5320000 lines
# Processed 5321000 lines
# Processed 5322000 lines
# Processed 5323000 lines
# Processed 5324000 lines
# Processed 5325000 lines
# Processed 5326000 lines
# Processed 5327000 lines
# Processed 5328000 lines
# Processed 5329000 lines
# Processed 5330000 lines
# Processed 5331000 lines
# Processed 5332000 lines
# Processed 5333000 lines
# Processed 5334000 lines
# Processed 5335000 lines
# Processed 5336000 lines
# Processed 5337000 lines
# Processed 5338000 lines
# Processed 5339000 lines
# Processed 5340000 lines
# Processed 5341000 lines
# Processed 5342000 lines
# Processed 5343000 lines
# Processed 5344000 lines
# Processed 5345000 lines
# Processed 5346000 lines
# Processed 5347000 lines
# Processed 5348000 lines
# Processed 5349000 lines
# Processed 5350000 lines
# Processed 5351000 lines
# Processed 5352000 lines
# Processed 5353000 lines
# Processed 5354000 lines
# Processed 5355000 lines
# Processed 5356000 lines
# Processed 5357000 lines
# Processed 5358000 lines
# Processed 5359000 lines
# Processed 5360000 lines
# Processed 5361000 lines
# Processed 5362000 lines
# Processed 5363000 lines
# Processed 5364000 lines
# Processed 5365000 lines
# Processed 5366000 lines
# Processed 5367000 lines
# Processed 5368000 lines
# Processed 5369000 lines
# Processed 5370000 lines
# Processed 5371000 lines
# Processed 5372000 lines
# Processed 5373000 lines
# Processed 5374000 lines
# Processed 5375000 lines
# Processed 5376000 lines
# Processed 5377000 lines
# Processed 5378000 lines
# Processed 5379000 lines
# Processed 5380000 lines
# Processed 5381000 lines
# Processed 5382000 lines
# Processed 5383000 lines
# Processed 5384000 lines
# Processed 5385000 lines
# Processed 5386000 lines
# Processed 5387000 lines
# Processed 5388000 lines
# Processed 5389000 lines
# Processed 5390000 lines
# Processed 5391000 lines
# Processed 5392000 lines
# Processed 5393000 lines
# Processed 5394000 lines
# Processed 5395000 lines
# Processed 5396000 lines
# Processed 5397000 lines
# Processed 5398000 lines
# Processed 5399000 lines
# Processed 5400000 lines
# Processed 5401000 lines
# Processed 5402000 lines
# Processed 5403000 lines
# Processed 5404000 lines
# Processed 5405000 lines
# Processed 5406000 lines
# Processed 5407000 lines
# Processed 5408000 lines
# Processed 5409000 lines
# Processed 5410000 lines
# Processed 5411000 lines
# Processed 5412000 lines
# Processed 5413000 lines
# Processed 5414000 lines
# Processed 5415000 lines
# Processed 5416000 lines
# Processed 5417000 lines
# Processed 5418000 lines
# Processed 5419000 lines
# Processed 5420000 lines
# Processed 5421000 lines
# Processed 5422000 lines
# Processed 5423000 lines
# Processed 5424000 lines
# Processed 5425000 lines
# Processed 5426000 lines
# Processed 5427000 lines
# Processed 5428000 lines
# Processed 5429000 lines
# Processed 5430000 lines
# Processed 5431000 lines
# Processed 5432000 lines
# Processed 5433000 lines
# Processed 5434000 lines
# Processed 5435000 lines
# Processed 5436000 lines
# Processed 5437000 lines
# Processed 5438000 lines
# Processed 5439000 lines
# Processed 5440000 lines
# Processed 5441000 lines
# Processed 5442000 lines
# Processed 5443000 lines
# Processed 5444000 lines
# Processed 5445000 lines
# Processed 5446000 lines
# Processed 5447000 lines
# Processed 5448000 lines
# Processed 5449000 lines
# Processed 5450000 lines
# Processed 5451000 lines
# Processed 5452000 lines
# Processed 5453000 lines
# Processed 5454000 lines
# Processed 5455000 lines
# Processed 5456000 lines
# Processed 5457000 lines
# Processed 5458000 lines
# Processed 5459000 lines
# Processed 5460000 lines
# Processed 5461000 lines
# Processed 5462000 lines
# Processed 5463000 lines
# Processed 5464000 lines
# Processed 5465000 lines
# Processed 5466000 lines
# Processed 5467000 lines
# Processed 5468000 lines
# Processed 5469000 lines
# Processed 5470000 lines
# Processed 5471000 lines
# Processed 5472000 lines
# Processed 5473000 lines
# Processed 5474000 lines
# Processed 5475000 lines
# Processed 5476000 lines
# Processed 5477000 lines
# Processed 5478000 lines
# Processed 5479000 lines
# Processed 5480000 lines
# Processed 5481000 lines
# Processed 5482000 lines
# Processed 5483000 lines
# Processed 5484000 lines
# Processed 5485000 lines
# Processed 5486000 lines
# Processed 5487000 lines
# Processed 5488000 lines
# Processed 5489000 lines
# Processed 5490000 lines
# Processed 5491000 lines
# Processed 5492000 lines
# Processed 5493000 lines
# Processed 5494000 lines
# Processed 5495000 lines
# Processed 5496000 lines
# Processed 5497000 lines
# Processed 5498000 lines
# Processed 5499000 lines
# Processed 5500000 lines
# Processed 5501000 lines
# Processed 5502000 lines
# Processed 5503000 lines
# Processed 5504000 lines
# Processed 5505000 lines
# Processed 5506000 lines
# Processed 5507000 lines
# Processed 5508000 lines
# Processed 5509000 lines
# Processed 5510000 lines
# Processed 5511000 lines
# Processed 5512000 lines
# Processed 5513000 lines
# Processed 5514000 lines
# Processed 5515000 lines
# Processed 5516000 lines
# Processed 5517000 lines
# Processed 5518000 lines
# Processed 5519000 lines
# Processed 5520000 lines
# Processed 5521000 lines
# Processed 5522000 lines
# Processed 5523000 lines
# Processed 5524000 lines
# Processed 5525000 lines
# Processed 5526000 lines
# Processed 5527000 lines
# Processed 5528000 lines
# Processed 5529000 lines
# Processed 5530000 lines
# Processed 5531000 lines
# Processed 5532000 lines
# Processed 5533000 lines
# Processed 5534000 lines
# Processed 5535000 lines
# Processed 5536000 lines
# Processed 5537000 lines
# Processed 5538000 lines
# Processed 5539000 lines
# Processed 5540000 lines
# Processed 5541000 lines
# Processed 5542000 lines
# Processed 5543000 lines
# Processed 5544000 lines
# Processed 5545000 lines
# Processed 5546000 lines
# Processed 5547000 lines
# Processed 5548000 lines
# Processed 5549000 lines
# Processed 5550000 lines
# Processed 5551000 lines
# Processed 5552000 lines
# Processed 5553000 lines
# Processed 5554000 lines
# Processed 5555000 lines
# Processed 5556000 lines
# Processed 5557000 lines
# Processed 5558000 lines
# Processed 5559000 lines
# Processed 5560000 lines
# Processed 5561000 lines
# Processed 5562000 lines
# Processed 5563000 lines
# Processed 5564000 lines
# Processed 5565000 lines
# Processed 5566000 lines
# Processed 5567000 lines
# Processed 5568000 lines
# Processed 5569000 lines
# Processed 5570000 lines
# Processed 5571000 lines
# Processed 5572000 lines
# Processed 5573000 lines
# ...
# Processed 7919000 lines
# Processed 7920000 lines
# Processed 7921000 lines
# Processed 7922000 lines
# Processed 7923000 lines
# Processed 7924000 lines
# Processed 7925000 lines
# Processed 7926000 lines
# Processed 7927000 lines
# Processed 7928000 lines
# Processed 7929000 lines
# Processed 7930000 lines
# Processed 7931000 lines
# Processed 7932000 lines
# Processed 7933000 lines
# Processed 7934000 lines
# Processed 7935000 lines
# Processed 7936000 lines
# Processed 7937000 lines
# Processed 7938000 lines
# Processed 7939000 lines
# Processed 7940000 lines
# Processed 7941000 lines
# Processed 7942000 lines
# Processed 7943000 lines
# Processed 7944000 lines
# Processed 7945000 lines
# Processed 7946000 lines
# Processed 7947000 lines
# Processed 7948000 lines
# Processed 7949000 lines
# Processed 7950000 lines
# Processed 7951000 lines
# Processed 7952000 lines
# Processed 7953000 lines
# Processed 7954000 lines
# Processed 7955000 lines
# Processed 7956000 lines
# Processed 7957000 lines
# Processed 7958000 lines
# Processed 7959000 lines
# Processed 7960000 lines
# Processed 7961000 lines
# Processed 7962000 lines
# Processed 7963000 lines
# Processed 7964000 lines
# Processed 7965000 lines
# Processed 7966000 lines
# Processed 7967000 lines
# Processed 7968000 lines
# Processed 7969000 lines
# Processed 7970000 lines
# Processed 7971000 lines
# Processed 7972000 lines
# Processed 7973000 lines
# Processed 7974000 lines
# Processed 7975000 lines
# Processed 7976000 lines
# Processed 7977000 lines
# Processed 7978000 lines
# Processed 7979000 lines
# Processed 7980000 lines
# Processed 7981000 lines
# Processed 7982000 lines
# Processed 7983000 lines
# Processed 7984000 lines
# Processed 7985000 lines
# Processed 7986000 lines
# Processed 7987000 lines
# Processed 7988000 lines
# Processed 7989000 lines
# Processed 7990000 lines
# Processed 7991000 lines
# Processed 7992000 lines
# Processed 7993000 lines
# Processed 7994000 lines
# Processed 7995000 lines
# Processed 7996000 lines
# Processed 7997000 lines
# Processed 7998000 lines
# Processed 7999000 lines
# Processed 8000000 lines
# Processed 8001000 lines
# Processed 8002000 lines
# Processed 8003000 lines
# Processed 8004000 lines
# Processed 8005000 lines
# Processed 8006000 lines
# Processed 8007000 lines
# Processed 8008000 lines
# Processed 8009000 lines
# Processed 8010000 lines
# Processed 8011000 lines
# Processed 8012000 lines
# Processed 8013000 lines
# Processed 8014000 lines
# Processed 8015000 lines
# Processed 8016000 lines
# Processed 8017000 lines
# Processed 8018000 lines
# Processed 8019000 lines
# Processed 8020000 lines
# Processed 8021000 lines
# Processed 8022000 lines
# Processed 8023000 lines
# Processed 8024000 lines
# Processed 8025000 lines
# Processed 8026000 lines
# Processed 8027000 lines
# Processed 8028000 lines
# Processed 8029000 lines
# Processed 8030000 lines
# Processed 8031000 lines
# Processed 8032000 lines
# Processed 8033000 lines
# Processed 8034000 lines
# Processed 8035000 lines
# Processed 8036000 lines
# Processed 8037000 lines
# Processed 8038000 lines
# Processed 8039000 lines
# Processed 8040000 lines
# Processed 8041000 lines
# Processed 8042000 lines
# Processed 8043000 lines
# Processed 8044000 lines
# Processed 8045000 lines
# Processed 8046000 lines
# Processed 8047000 lines
# Processed 8048000 lines
# Processed 8049000 lines
# Processed 8050000 lines
# Processed 8051000 lines
# Processed 8052000 lines
# Processed 8053000 lines
# Processed 8054000 lines
# Processed 8055000 lines
# Processed 8056000 lines
# Processed 8057000 lines
# Processed 8058000 lines
# Processed 8059000 lines
# Processed 8060000 lines
# Processed 8061000 lines
# Processed 8062000 lines
# Processed 8063000 lines
# Processed 8064000 lines
# Processed 8065000 lines
# Processed 8066000 lines
# Processed 8067000 lines
# Processed 8068000 lines
# Processed 8069000 lines
# Processed 8070000 lines
# Processed 8071000 lines
# Processed 8072000 lines
# Processed 8073000 lines
# Processed 8074000 lines
# Processed 8075000 lines
# Processed 8076000 lines
# Processed 8077000 lines
# Processed 8078000 lines
# Processed 8079000 lines
# Processed 8080000 lines
# Processed 8081000 lines
# Processed 8082000 lines
# Processed 8083000 lines
# Processed 8084000 lines
# Processed 8085000 lines
# Processed 8086000 lines
# Processed 8087000 lines
# Processed 8088000 lines
# Processed 8089000 lines
# Processed 8090000 lines
# Processed 8091000 lines
# Processed 8092000 lines
# Processed 8093000 lines
# Processed 8094000 lines
# Processed 8095000 lines
# Processed 8096000 lines
# Processed 8097000 lines
# Processed 8098000 lines
# Processed 8099000 lines
# Processed 8100000 lines
# Processed 8101000 lines
# Processed 8102000 lines
# Processed 8103000 lines
# Processed 8104000 lines
# Processed 8105000 lines
# Processed 8106000 lines
# Processed 8107000 lines
# Processed 8108000 lines
# Processed 8109000 lines
# Processed 8110000 lines
# Processed 8111000 lines
# Processed 8112000 lines
# Processed 8113000 lines
# Processed 8114000 lines
# Processed 8115000 lines
# Processed 8116000 lines
# Processed 8117000 lines
# Processed 8118000 lines
# Processed 8119000 lines
# Processed 8120000 lines
# Processed 8121000 lines
# Processed 8122000 lines
# Processed 8123000 lines
# Processed 8124000 lines
# Processed 8125000 lines
# Processed 8126000 lines
# Processed 8127000 lines
# Processed 8128000 lines
# Processed 8129000 lines
# Processed 8130000 lines
# Processed 8131000 lines
# Processed 8132000 lines
# Processed 8133000 lines
# Processed 8134000 lines
# Processed 8135000 lines
# Processed 8136000 lines
# Processed 8137000 lines
# Processed 8138000 lines
# Processed 8139000 lines
# Processed 8140000 lines
# Processed 8141000 lines
# Processed 8142000 lines
# Processed 8143000 lines
# Processed 8144000 lines
# Processed 8145000 lines
# Processed 8146000 lines
# Processed 8147000 lines
# Processed 8148000 lines
# Processed 8149000 lines
# Processed 8150000 lines
# Processed 8151000 lines
# Processed 8152000 lines
# Processed 8153000 lines
# Processed 8154000 lines
# Processed 8155000 lines
# Processed 8156000 lines
# Processed 8157000 lines
# Processed 8158000 lines
# Processed 8159000 lines
# Processed 8160000 lines
# Processed 8161000 lines
# Processed 8162000 lines
# Processed 8163000 lines
# Processed 8164000 lines
# Processed 8165000 lines
# Processed 8166000 lines
# Processed 8167000 lines
# Processed 8168000 lines
# Processed 8169000 lines
# Processed 8170000 lines
# Processed 8171000 lines
# Processed 8172000 lines
# Processed 8173000 lines
# Processed 8174000 lines
# Processed 8175000 lines
# Processed 8176000 lines
# Processed 8177000 lines
# Processed 8178000 lines
# Processed 8179000 lines
# Processed 8180000 lines
# Processed 8181000 lines
# Processed 8182000 lines
# Processed 8183000 lines
# Processed 8184000 lines
# Processed 8185000 lines
# Processed 8186000 lines
# Processed 8187000 lines
# Processed 8188000 lines
# Processed 8189000 lines
# Processed 8190000 lines
# Processed 8191000 lines
# Processed 8192000 lines
# Processed 8193000 lines
# Processed 8194000 lines
# Processed 8195000 lines
# Processed 8196000 lines
# Processed 8197000 lines
# Processed 8198000 lines
# Processed 8199000 lines
# Processed 8200000 lines
# Processed 8201000 lines
# Processed 8202000 lines
# Processed 8203000 lines
# Processed 8204000 lines
# Processed 8205000 lines
# Processed 8206000 lines
# Processed 8207000 lines
# Processed 8208000 lines
# Processed 8209000 lines
# Processed 8210000 lines
# Processed 8211000 lines
# Processed 8212000 lines
# Processed 8213000 lines
# Processed 8214000 lines
# Processed 8215000 lines
# Processed 8216000 lines
# Processed 8217000 lines
# Processed 8218000 lines
# Processed 8219000 lines
# Processed 8220000 lines
# Processed 8221000 lines
# Processed 8222000 lines
# Processed 8223000 lines
# Processed 8224000 lines
# Processed 8225000 lines
# Processed 8226000 lines
# Processed 8227000 lines
# Processed 8228000 lines
# Processed 8229000 lines
# Processed 8230000 lines
# Processed 8231000 lines
# Processed 8232000 lines
# Processed 8233000 lines
# Processed 8234000 lines
# Processed 8235000 lines
# Processed 8236000 lines
# Processed 8237000 lines
# Processed 8238000 lines
# Processed 8239000 lines
# Processed 8240000 lines
# Processed 8241000 lines
# Processed 8242000 lines
# Processed 8243000 lines
# Processed 8244000 lines
# Processed 8245000 lines
# Processed 8246000 lines
# Processed 8247000 lines
# Processed 8248000 lines
# Processed 8249000 lines
# Processed 8250000 lines
# Processed 8251000 lines
# Processed 8252000 lines
# Processed 8253000 lines
# Processed 8254000 lines
# Processed 8255000 lines
# Processed 8256000 lines
# Processed 8257000 lines
# Processed 8258000 lines
# Processed 8259000 lines
# Processed 8260000 lines
# Processed 8261000 lines
# Processed 8262000 lines
# Processed 8263000 lines
# Processed 8264000 lines
# Processed 8265000 lines
# Processed 8266000 lines
# Processed 8267000 lines
# Processed 8268000 lines
# Processed 8269000 lines
# Processed 8270000 lines
# Processed 8271000 lines
# Processed 8272000 lines
# Processed 8273000 lines
# Processed 8274000 lines
# Processed 8275000 lines
# Processed 8276000 lines
# Processed 8277000 lines
# Processed 8278000 lines
# Processed 8279000 lines
# Processed 8280000 lines
# Processed 8281000 lines
# Processed 8282000 lines
# Processed 8283000 lines
# Processed 8284000 lines
# Processed 8285000 lines
# Processed 8286000 lines
# Processed 8287000 lines
# Processed 8288000 lines
# Processed 8289000 lines
# Processed 8290000 lines
# Processed 8291000 lines
# Processed 8292000 lines
# Processed 8293000 lines
# Processed 8294000 lines
# Processed 8295000 lines
# Processed 8296000 lines
# Processed 8297000 lines
# Processed 8298000 lines
# Processed 8299000 lines
# Processed 8300000 lines
# Processed 8301000 lines
# Processed 8302000 lines
# Processed 8303000 lines
# Processed 8304000 lines
# Processed 8305000 lines
# Processed 8306000 lines
# Processed 8307000 lines
# Processed 8308000 lines
# Processed 8309000 lines
# Processed 8310000 lines
# Processed 8311000 lines
# Processed 8312000 lines
# Processed 8313000 lines
# Processed 8314000 lines
# Processed 8315000 lines
# Processed 8316000 lines
# Processed 8317000 lines
# Processed 8318000 lines
# Processed 8319000 lines
# Processed 8320000 lines
# Processed 8321000 lines
# Processed 8322000 lines
# Processed 8323000 lines
# Processed 8324000 lines
# Processed 8325000 lines
# Processed 8326000 lines
# Processed 8327000 lines
# Processed 8328000 lines
# Processed 8329000 lines
# Processed 8330000 lines
# Processed 8331000 lines
# Processed 8332000 lines
# Processed 8333000 lines
# Processed 8334000 lines
# Processed 8335000 lines
# Processed 8336000 lines
# Processed 8337000 lines
# Processed 8338000 lines
# Processed 8339000 lines
# Processed 8340000 lines
# Processed 8341000 lines
# Processed 8342000 lines
# Processed 8343000 lines
# Processed 8344000 lines
# Processed 8345000 lines
# Processed 8346000 lines
# Processed 8347000 lines
# Processed 8348000 lines
# Processed 8349000 lines
# Processed 8350000 lines
# Processed 8351000 lines
# Processed 8352000 lines
# Processed 8353000 lines
# Processed 8354000 lines
# Processed 8355000 lines
# Processed 8356000 lines
# Processed 8357000 lines
# Processed 8358000 lines
# Processed 8359000 lines
# Processed 8360000 lines
# Processed 8361000 lines
# Processed 8362000 lines
# Processed 8363000 lines
# Processed 8364000 lines
# Processed 8365000 lines
# Processed 8366000 lines
# Processed 8367000 lines
# Processed 8368000 lines
# Processed 8369000 lines
# Processed 8370000 lines
# Processed 8371000 lines
# Processed 8372000 lines
# Processed 8373000 lines
# Processed 8374000 lines
# Processed 8375000 lines
# Processed 8376000 lines
# Processed 8377000 lines
# Processed 8378000 lines
# Processed 8379000 lines
# Processed 8380000 lines
# Processed 8381000 lines
# Processed 8382000 lines
# Processed 8383000 lines
# Processed 8384000 lines
# Processed 8385000 lines
# Processed 8386000 lines
# Processed 8387000 lines
# Processed 8388000 lines
# Processed 8389000 lines
# Processed 8390000 lines
# Processed 8391000 lines
# Processed 8392000 lines
# Processed 8393000 lines
# Processed 8394000 lines
# Processed 8395000 lines
# Processed 8396000 lines
# Processed 8397000 lines
# Processed 8398000 lines
# Processed 8399000 lines
# Processed 8400000 lines
# Processed 8401000 lines
# Processed 8402000 lines
# Processed 8403000 lines
# Processed 8404000 lines
# Processed 8405000 lines
# Processed 8406000 lines
# Processed 8407000 lines
# Processed 8408000 lines
# Processed 8409000 lines
# Processed 8410000 lines
# Processed 8411000 lines
# Processed 8412000 lines
# Processed 8413000 lines
# Processed 8414000 lines
# Processed 8415000 lines
# Processed 8416000 lines
# Processed 8417000 lines
# Processed 8418000 lines
# Processed 8419000 lines
# Processed 8420000 lines
# Processed 8421000 lines
# Processed 8422000 lines
# Processed 8423000 lines
# Processed 8424000 lines
# Processed 8425000 lines
# Processed 8426000 lines
# Processed 8427000 lines
# Processed 8428000 lines
# Processed 8429000 lines
# Processed 8430000 lines
# Processed 8431000 lines
# Processed 8432000 lines
# Processed 8433000 lines
# Processed 8434000 lines
# Processed 8435000 lines
# Processed 8436000 lines
# Processed 8437000 lines
# Processed 8438000 lines
# Processed 8439000 lines
# Processed 8440000 lines
# Processed 8441000 lines
# Processed 8442000 lines
# Processed 8443000 lines
# Processed 8444000 lines
# Processed 8445000 lines
# Processed 8446000 lines
# Processed 8447000 lines
# Processed 8448000 lines
# Processed 8449000 lines
# Processed 8450000 lines
# Processed 8451000 lines
# Processed 8452000 lines
# Processed 8453000 lines
# Processed 8454000 lines
# Processed 8455000 lines
# Processed 8456000 lines
# Processed 8457000 lines
# Processed 8458000 lines
# Processed 8459000 lines
# Processed 8460000 lines
# Processed 8461000 lines
# Processed 8462000 lines
# Processed 8463000 lines
# Processed 8464000 lines
# Processed 8465000 lines
# Processed 8466000 lines
# Processed 8467000 lines
# Processed 8468000 lines
# Processed 8469000 lines
# Processed 8470000 lines
# Processed 8471000 lines
# Processed 8472000 lines
# Processed 8473000 lines
# Processed 8474000 lines
# Processed 8475000 lines
# Processed 8476000 lines
# Processed 8477000 lines
# Processed 8478000 lines
# Processed 8479000 lines
# Processed 8480000 lines
# Processed 8481000 lines
# Processed 8482000 lines
# Processed 8483000 lines
# Processed 8484000 lines
# Processed 8485000 lines
# Processed 8486000 lines
# Processed 8487000 lines
# Processed 8488000 lines
# Processed 8489000 lines
# Processed 8490000 lines
# Processed 8491000 lines
# Processed 8492000 lines
# Processed 8493000 lines
# Processed 8494000 lines
# Processed 8495000 lines
# Processed 8496000 lines
# Processed 8497000 lines
# Processed 8498000 lines
# Processed 8499000 lines
# Processed 8500000 lines
# Processed 8501000 lines
# Processed 8502000 lines
# Processed 8503000 lines
# Processed 8504000 lines
# Processed 8505000 lines
# Processed 8506000 lines
# Processed 8507000 lines
# Processed 8508000 lines
# Processed 8509000 lines
# Processed 8510000 lines
# Processed 8511000 lines
# Processed 8512000 lines
# Processed 8513000 lines
# Processed 8514000 lines
# Processed 8515000 lines
# Processed 8516000 lines
# Processed 8517000 lines
# Processed 8518000 lines
# Processed 8519000 lines
# Processed 8520000 lines
# Processed 8521000 lines
# Processed 8522000 lines
# Processed 8523000 lines
# Processed 8524000 lines
# Processed 8525000 lines
# Processed 8526000 lines
# Processed 8527000 lines
# Processed 8528000 lines
# Processed 8529000 lines
# Processed 8530000 lines
# Processed 8531000 lines
# Processed 8532000 lines
# Processed 8533000 lines
# Processed 8534000 lines
# Processed 8535000 lines
# Processed 8536000 lines
# Processed 8537000 lines
# Processed 8538000 lines
# Processed 8539000 lines
# Processed 8540000 lines
# Processed 8541000 lines
# Processed 8542000 lines
# Processed 8543000 lines
# Processed 8544000 lines
# Processed 8545000 lines
# Processed 8546000 lines
# Processed 8547000 lines
# Processed 8548000 lines
# Processed 8549000 lines
# Processed 8550000 lines
# Processed 8551000 lines
# Processed 8552000 lines
# Processed 8553000 lines
# Processed 8554000 lines
# Processed 8555000 lines
# Initializing sparse PMI matrix (limiting to 1000000 rows)...
# Processing up to 1000000 rows from co-occurrence file in chunks...
# Processed 100000 lines...
# Processed 200000 lines...
# Processed 300000 lines...
# Processed 400000 lines...
# Processed 500000 lines...
# Processed 600000 lines...
# Processed 700000 lines...
# Processed 800000 lines...
# Processed 900000 lines...
# Processed 1000000 lines...
# Converting PMI matrix to CSR format...
# Saving PMI matrix to disk...
# PMI computation complete!
# Top synonyms for 'leukemia':
# [m]leukaemia unspecified, nos: 1.0000
# [m]leukaemia nos: 1.0000
# [m]leukemia nos (morphologic abnormality): 1.0000
# [m]leukemia nos: 1.0000
# [m]leukemias unspecified (morphologic abnormality): 1.0000

# %% [markdown]
# ## CharNGram - Surface

# %% [markdown]
# Now I am going to be trying to do the charnGram. Only need to do the cell below once. Make sure to download from the following link: https://github.com/hassyGo/charNgram2vec/releases

# %%
# !gzip -d "/content/gdrive/My Drive/CSE_6250_BD4H_Final_Project/jmt_pre-trained_embeddings.tar.gz"
# !tar -xvf "/content/gdrive/My Drive/CSE_6250_BD4H_Final_Project/jmt_pre-trained_embeddings.tar" "charNgram.txt" -C "/content/gdrive/My Drive/CSE_6250_BD4H_Final_Project/"

# %%
import numpy as np
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix, csr_matrix
from sparse_dot_topn import awesome_cossim_topn  # Install using: pip install sparse-dot-topn
from scipy.sparse import dok_matrix, csr_matrix

### 1️⃣ Load Mapping Files ###
def load_term_id_to_string(file_paths, include_concepts=True):
    """ Load multiple term ID to string mappings and merge them into a single dictionary. """
    term_id_map = {}
    concept_id_map = {}  # For concept mappings

    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            for line in f:
                try:
                    term_id, term_str = line.strip().split("\t")

                    # If it's a concept mapping file, store separately
                    if include_concepts and "concept" in file_path.lower():
                        concept_id_map[term_id] = term_str
                    else:
                        term_id_map[term_id] = term_str
                except ValueError:
                    continue  # Skip malformed lines

    return term_id_map, concept_id_map



### 5️⃣ Filter Synonyms Using Concept ID ###
def filter_synonyms_by_concept(synonyms, concept_id_map, target_word):
    """ Ensure synonyms belong to the same concept cluster. """
    target_concept = concept_id_map.get(target_word, None)
    if not target_concept:
        return synonyms  # No concept info available

    return [(word, score) for word, score in synonyms if concept_id_map.get(word) == target_concept]

def load_concept_to_term_map(file_path):
    """ Load concept-to-term mappings where multiple terms can map to the same concept. """
    concept_to_term_map = defaultdict(list)

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            try:
                term_id, concept_id = line.strip().split("\t")
                concept_to_term_map[concept_id].append(term_id)  # Store all terms for a concept
            except ValueError:
                continue  # Skip malformed lines

    return concept_to_term_map

def extract_char_ngrams(term, min_n=3, max_n=13):
    term = f"<{term}>"
    ngrams = []
    for n in range(min_n, max_n + 1):
        ngrams += [f"{n}gram-{term[i:i+n]}" for i in range(len(term)-n+1)]
    return ngrams


def load_char_ngram_embeddings(file_path):
    embedding_map = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 10:  # Skip headers or bad lines
                continue
            gram = parts[0]
            vec = np.array([float(x) for x in parts[1:]], dtype=np.float32)
            embedding_map[gram] = vec
    return embedding_map

def compute_term_embedding(term, ngram_embeds, min_n=1, max_n=13, dim=100):
    term = term.lower().strip()
    ngrams = extract_char_ngrams(term, min_n, max_n)
    vectors = [ngram_embeds[ng] for ng in ngrams if ng in ngram_embeds]
    if not vectors:
        return np.zeros(dim)
    return np.mean(vectors, axis=0)


def build_term_embeddings(term_list, ngram_embeds, dim=100):
    term_vectors = {}
    for term in term_list:
        term_vectors[term] = compute_term_embedding(term, ngram_embeds, dim=dim)
    return term_vectors

def find_surface_form_synonyms(term_vectors, target_term, ngram_embeddings, dim=100, top_n=5):
    if target_term in term_vectors:
        target_vec = term_vectors[target_term]
    else:
        print(f"'{target_term}' not in vocabulary — computing from n-grams.")
        target_vec = compute_term_embedding(target_term, ngram_embeddings, dim=dim)

    if np.linalg.norm(target_vec) == 0:
        print(f"Could not compute embedding for '{target_term}' (no matching n-grams).")
        return []

    target_vec = target_vec.reshape(1, -1)
    terms = list(term_vectors.keys())
    matrix = np.stack([term_vectors[t] for t in terms])
    sims = cosine_similarity(target_vec, matrix)[0]

    ranked = sorted(zip(terms, sims), key=lambda x: -x[1])
    return [(term, sim) for term, sim in ranked if term != target_term][:top_n]





if __name__ == "__main__":
    # File Paths
    mapping_files = [
        "1_term_ID_to_string.txt",
        "2a_concept_ID_to_string.txt"
    ]
    concept_map_file = "3_term_ID_to_concept_ID.txt"
    singleton_file = "singlets_concepts_perBin_1d.txt"
    cofreq_file = "cofreqs_concepts_perBin_1d.txt"
    charngram_embedding_file = 'charNgram.txt'

    # Load mappings
    term_id_map, concept_id_map = load_term_id_to_string(mapping_files)
    concept_to_term_map = load_concept_to_term_map(concept_map_file)

     # === Build Term List ===
    term_list = list(term_id_map.values())

    # === Load CharNGram Embeddings ===
    ngram_embeddings = load_char_ngram_embeddings(charngram_embedding_file)

    # === Compute Embeddings for All Terms ===
    print("Computing term embeddings...")
    term_vectors = build_term_embeddings(term_list, ngram_embeddings, dim=100)

    # === Find Synonyms ===
    target_word = "leukemia"
    synonyms = find_surface_form_synonyms(term_vectors, target_word, ngram_embeddings, top_n=10)

    print(f"Top CharNGram-based synonyms for '{target_word}':")
    for word, score in synonyms:
        print(f"{word}: {score:.4f}")
# Out:
# Computing term embeddings...
# Top CharNGram-based synonyms for 'leukemia':
# cns leukemia: 0.9925
# leukemias: 0.9921
# leukemia of cns: 0.9880
# leukemia nos: 0.9879
# [m]leukemia nos: 0.9855
# leukemias nec: 0.9854
# rat leukemia: 0.9842
# aleukemic leukemia: 0.9837
# leukemia aleukemic: 0.9837
# lgl leukemia: 0.9826

# %%
    # === Find Synonyms ===
    target_word = "leukemia"
    synonyms = find_surface_form_synonyms(term_vectors, target_word, ngram_embeddings, top_n=10)

    print(f"Top CharNGram-based synonyms for '{target_word}':")
    for word, score in synonyms:
        print(f"{word}: {score:.4f}")
# Out:
# Top CharNGram-based synonyms for 'leukemia':
# cns leukemia: 0.9925
# leukemias: 0.9921
# leukemia of cns: 0.9880
# leukemia nos: 0.9879
# [m]leukemia nos: 0.9855
# leukemias nec: 0.9854
# rat leukemia: 0.9842
# aleukemic leukemia: 0.9837
# leukemia aleukemic: 0.9837
# lgl leukemia: 0.9826

# %%
    # === Find Synonyms ===
    target_word = "cool"
    synonyms = find_surface_form_synonyms(term_vectors, target_word, ngram_embeddings, top_n=10)

    print(f"Top CharNGram-based synonyms for '{target_word}':")
    for word, score in synonyms:
        print(f"{word}: {score:.4f}")
# Out:
# 'cool' not in vocabulary — computing from n-grams.
# Top CharNGram-based synonyms for 'cool':
# cool1: 0.9936
# cool2: 0.9925
# coolers: 0.9478
# li(x)coo2: 0.9468
# coos: 0.9459
# pscoo: 0.9410
# coombs: 0.9404
# cool skin: 0.9395
# oil bleo: 0.9362
# dermacool: 0.9357

# %% [markdown]
# ## Context - word2vec

# %% [markdown]
# Downloade the word2vec GloVe embedding file here: https://www.kaggle.com/datasets/watts2/glove6b50dtxt

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 63.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 98.6 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 37.1 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
pip install --upgrade scipy numpy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Collecting scipy
#   Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.3 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 38.0 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 102.9 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# Successfully installed numpy-2.2.4 scipy-1.15.2

# %%
pip install --upgrade --force-reinstall gensim
# Out:
# Collecting gensim
#   Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.5 MB/s eta 0:00:00
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.1.0
#     Uninstalling smart-open-7.1.0:
#       Successfully uninstalled smart-open-7.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1 smart-open-7.1.0 wrapt-1.17.2

# %%
pip install numpy==1.24.4
# Out:
# Collecting numpy==1.24.4
#   Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 96.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# Successfully installed numpy-1.24.4

# %%
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
import os


### 1️⃣ Load Term ID to String Mapping ###
def load_term_id_to_string(file_paths):
    """Load multiple term ID to string mappings and merge them into a single dictionary."""
    term_id_map = {}
    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            for line in f:
                try:
                    term_id, term_str = line.strip().split("\t")
                    term_id_map[term_id] = term_str
                except ValueError:
                    continue  # Skip malformed lines
    return term_id_map



### 2️⃣ Convert and Load GloVe Vectors ###
def load_glove_model(glove_input_file, word2vec_output_file):
    # Convert GloVe to word2vec format if not already done
    if not os.path.exists(word2vec_output_file):
        print(f"Converting {glove_input_file} to word2vec format...")
        glove2word2vec(glove_input_file, word2vec_output_file)
        print("Conversion done.")
    print(f"Loading vectors from: {word2vec_output_file}")
    model = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)
    print("Model loaded.")
    return model


### 3️⃣ Find Semantic Synonyms ###
def find_word2vec_synonyms(model, target_word, top_n=10):
    if target_word not in model.key_to_index:
        print(f"'{target_word}' not in GloVe vocabulary.")
        return []
    similar = model.most_similar(target_word, topn=top_n)
    return similar



### 4️⃣ Main Execution ###
if __name__ == "__main__":
    # File paths
    mapping_files = [
        "1_term_ID_to_string.txt",
        "2a_concept_ID_to_string.txt"
    ]
    glove_input_file = "glove.6B.50d.txt"
    word2vec_output_file = "glove.6B.50d.word2vec.txt"



    # Load term mappings
term_id_map = load_term_id_to_string(mapping_files)
term_list = list(term_id_map.values())


    # Convert and load GloVe vectors
model = load_glove_model(glove_input_file, word2vec_output_file)


# Filter term list to those in the model's vocabulary
in_vocab_terms = [term for term in term_list if term in model.key_to_index]
print(f"Number of terms in both your list and the model's vocabulary: {len(in_vocab_terms)}")


# Find and print synonyms for a target word
target_words = ["leukemia", "cool"]
for target_word in target_words:
    print(f"\nTop GloVe-based semantic synonyms for '{target_word}':")
    synonyms = find_word2vec_synonyms(model, target_word, top_n=10)
    for word, score in synonyms:
        print(f"{word}: {score:.4f}")
# Out:
# Loading vectors from: glove.6B.50d.word2vec.txt
# Model loaded.
# Number of terms in both your list and the model's vocabulary: 25562
#
# Top GloVe-based semantic synonyms for 'leukemia':
# leukaemia: 0.8707
# myeloid: 0.8264
# lymphoma: 0.8256
# diagnosed: 0.8164
# alzheimer: 0.8011
# diabetes: 0.7896
# parkinson: 0.7881
# myelogenous: 0.7858
# cancer: 0.7851
# schizophrenia: 0.7781
#
# Top GloVe-based semantic synonyms for 'cool':
# hot: 0.8605
# warm: 0.8107
# cold: 0.8104
# bit: 0.7934
# dry: 0.7666
# cooler: 0.7619
# little: 0.7598
# mix: 0.7533
# soft: 0.7454
# bright: 0.7423

# %% [markdown]
# ## SurfCon Final

# %%
import numpy as np
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix, csr_matrix
from sparse_dot_topn import awesome_cossim_topn  # Install using: pip install sparse-dot-topn
from scipy.sparse import dok_matrix, csr_matrix

# Load Term and Concept Mapping Files
def load_term_id_to_string(file_paths, include_concepts=True):
    """ Load multiple term ID to string mappings and merge them into a single dictionary. """
    term_id_map = {}
    concept_id_map = {}  # For concept mappings

    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            for line in f:
                try:
                    term_id, term_str = line.strip().split("\t")

                    # If it's a concept mapping file, store separately
                    if include_concepts and "concept" in file_path.lower():
                        concept_id_map[term_id] = term_str
                    else:
                        term_id_map[term_id] = term_str
                except ValueError:
                    continue  # Skip malformed lines

    return term_id_map, concept_id_map


# Load Singleton Frequencies
def load_singleton_frequencies(file_path, concept_to_term_map, term_id_map, chunk_size=1000):
    """ Load singleton frequencies in chunks and map concept IDs to term strings """
    singleton_freq = {}

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for i, line in enumerate(f):
            concept_id, count = line.strip().split("\t")
            count = int(count)

            # Get term IDs associated with this concept
            term_ids = concept_to_term_map.get(concept_id, [f"UNK_{concept_id}"])

            # Convert term IDs to actual term names
            terms = [term_id_map.get(term_id, f"UNK_{term_id}") for term_id in term_ids]

            # Store frequencies for all mapped terms
            for term in terms:
                singleton_freq[term] = singleton_freq.get(term, 0) + count  # Sum counts if needed

            if (i + 1) % chunk_size == 0:  # Process in chunks
                print(f"Processed {i + 1} lines")
                # Optionally, write intermediate results to disk here to manage memory

    return singleton_freq

# Load Co-occurrence Frequencies
def load_cofreq_counts(file_path, concept_to_term_map, term_id_map, output_file="temp_cofreq.txt", chunk_size=1000):
    """ Process cofrequency counts in a memory-efficient way for up to chunk_size entries. """
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f, open(output_file, 'w', encoding='utf-8') as out_f:
        for i, line in enumerate(f):
            concept1_id, concept2_id, count = line.strip().split("\t")
            count = int(count)

            # Convert concept IDs into actual term names
            terms1 = [term_id_map.get(t, f"UNK_{t}") for t in concept_to_term_map.get(concept1_id, [concept1_id])]
            terms2 = [term_id_map.get(t, f"UNK_{t}") for t in concept_to_term_map.get(concept2_id, [concept2_id])]

            # Write mapped term pairs to file
            for term1 in terms1:
                for term2 in terms2:
                    if term1 != term2:  # Avoid self-pairs
                        out_f.write(f"{term1}\t{term2}\t{count}\n")

            if (i + 1) % chunk_size == 0:  # Process in chunks
                print(f"Processed {i + 1} lines")
                # Optionally, write intermediate results to disk here to manage memory

    return output_file  # Return the file path


import numpy as np
from scipy.sparse import dok_matrix, csr_matrix

# Compute NPMI Matrix
def compute_npmi(cofreq_file, singleton_freq, total_count, term_index, matrix_size, k=1, output_pmi="temp_pmi.npz", chunk_size=100000, max_rows=1000000):
    """
    Compute Normalized PMI (NPMI) using at most `max_rows` rows from co-occurrence file.
    Uses `dok_matrix` for fast updates, then converts to `csr_matrix`.
    """
    print(f"Initializing sparse PMI matrix (limiting to {max_rows} rows)...")
    pmi_matrix = dok_matrix((matrix_size, matrix_size), dtype=np.float32)

    print(f"Processing up to {max_rows} rows from co-occurrence file in chunks...")
    batch_data = []

    with open(cofreq_file, 'r', encoding='utf-8', errors='ignore') as f:
        for i, line in enumerate(f):
            if i >= max_rows:  # 🚀 Stop after 1 million rows
                break

            term1, term2, co_count = line.strip().split("\t")
            co_count = int(co_count)

            if term1 not in term_index or term2 not in term_index:
                continue  # Skip unknown terms

            i_idx, j_idx = term_index[term1], term_index[term2]
            p_x = singleton_freq.get(term1, 1) / total_count
            p_y = singleton_freq.get(term2, 1) / total_count
            p_xy = co_count / total_count

            # Compute PMI
            pmi = np.log2((p_xy + k) / (p_x * p_y + k))
            npmi = pmi / -np.log2(p_xy + k) if p_xy > 0 else 0

            batch_data.append((i_idx, j_idx, npmi))

            if len(batch_data) >= chunk_size:
                for row, col, value in batch_data:
                    pmi_matrix[row, col] = value
                    pmi_matrix[col, row] = value  # PMI is symmetric
                batch_data = []  # Reset batch

            if (i + 1) % chunk_size == 0:
                print(f"Processed {i + 1} lines...")

    # Final batch processing
    for row, col, value in batch_data:
        pmi_matrix[row, col] = value
        pmi_matrix[col, row] = value

    print("Converting PMI matrix to CSR format...")
    csr_pmi = pmi_matrix.tocsr()

    print("Saving PMI matrix to disk...")
    np.savez(output_pmi, data=csr_pmi.data, indices=csr_pmi.indices, indptr=csr_pmi.indptr, shape=csr_pmi.shape)

    print("PMI computation complete!")
    return output_pmi  # Return file path instead of keeping it in memory


# Find Synonyms Based on Contextual Similarity
def find_synonyms_fast(pmi_file, term_index, target_word, top_n=5):
    """ Efficient synonym retrieval using a stored PMI matrix. """
    if target_word not in term_index:
        print(f"Word '{target_word}' not found in vocabulary.")
        return []

    # Load sparse PMI matrix from file
    loaded = np.load(pmi_file)
    pmi_matrix = csr_matrix((loaded["data"], loaded["indices"], loaded["indptr"]), shape=loaded["shape"])

    words = list(term_index.keys())
    target_idx = term_index[target_word]

    # Compute sparse cosine similarity
    similarities = cosine_similarity(pmi_matrix[target_idx], pmi_matrix)[0]
    sorted_indices = np.argsort(similarities)[::-1]  # Descending order

    return [(words[i], similarities[i]) for i in sorted_indices if words[i] != target_word][:top_n]

# Filter Synonyms to Same Concept Cluster
def filter_synonyms_by_concept(synonyms, concept_id_map, target_word):
    """ Ensure synonyms belong to the same concept cluster. """
    target_concept = concept_id_map.get(target_word, None)
    if not target_concept:
        return synonyms  # No concept info available

    return [(word, score) for word, score in synonyms if concept_id_map.get(word) == target_concept]

# Load Concept to Term Map
def load_concept_to_term_map(file_path):
    """ Load concept-to-term mappings where multiple terms can map to the same concept. """
    concept_to_term_map = defaultdict(list)

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            try:
                term_id, concept_id = line.strip().split("\t")
                concept_to_term_map[concept_id].append(term_id)  # Store all terms for a concept
            except ValueError:
                continue  # Skip malformed lines

    return concept_to_term_map


# from CharNGram code

def load_concept_to_term_map(file_path):
    """ Load concept-to-term mappings where multiple terms can map to the same concept. """
    concept_to_term_map = defaultdict(list)

    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            try:
                term_id, concept_id = line.strip().split("\t")
                concept_to_term_map[concept_id].append(term_id)  # Store all terms for a concept
            except ValueError:
                continue  # Skip malformed lines

    return concept_to_term_map

# Extract Character n-grams from Term
def extract_char_ngrams(term, min_n=3, max_n=13):
    term = f"<{term}>"
    ngrams = []
    for n in range(min_n, max_n + 1):
        ngrams += [f"{n}gram-{term[i:i+n]}" for i in range(len(term)-n+1)]
    return ngrams

# Load Character n-gram Embeddings
def load_char_ngram_embeddings(file_path):
    embedding_map = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 10:  # Skip headers or bad lines
                continue
            gram = parts[0]
            vec = np.array([float(x) for x in parts[1:]], dtype=np.float32)
            embedding_map[gram] = vec
    return embedding_map

# Compute Embedding for a Single Term
def compute_term_embedding(term, ngram_embeds, min_n=1, max_n=13, dim=100):
    term = term.lower().strip()
    ngrams = extract_char_ngrams(term, min_n, max_n)
    vectors = [ngram_embeds[ng] for ng in ngrams if ng in ngram_embeds]
    if not vectors:
        return np.zeros(dim)
    return np.mean(vectors, axis=0)

# Build Embeddings for All Terms
def build_term_embeddings(term_list, ngram_embeds, dim=100):
    term_vectors = {}
    for term in term_list:
        term_vectors[term] = compute_term_embedding(term, ngram_embeds, dim=dim)
    return term_vectors

# Find Surface Form Synonyms
def find_surface_form_synonyms(term_vectors, target_term, ngram_embeddings, dim=100, top_n=5):
    if target_term in term_vectors:
        target_vec = term_vectors[target_term]
    else:
        print(f"'{target_term}' not in vocabulary — computing from n-grams.")
        target_vec = compute_term_embedding(target_term, ngram_embeddings, dim=dim)

    if np.linalg.norm(target_vec) == 0:
        print(f"Could not compute embedding for '{target_term}' (no matching n-grams).")
        return []

    target_vec = target_vec.reshape(1, -1)
    terms = list(term_vectors.keys())
    matrix = np.stack([term_vectors[t] for t in terms])
    sims = cosine_similarity(target_vec, matrix)[0]

    ranked = sorted(zip(terms, sims), key=lambda x: -x[1])
    return [(term, sim) for term, sim in ranked if term != target_term][:top_n]

# Hybrid code

# Normalize Scores
def normalize_scores(score_list):
    scores = np.array([score for _, score in score_list])
    if len(scores) == 0:
        return []
    min_val, max_val = np.min(scores), np.max(scores)
    norm = lambda s: (s - min_val) / (max_val - min_val) if max_val > min_val else 0.0
    return [(term, norm(score)) for term, score in score_list]

# Combine Surface and Contextual Scores
def combine_hybrid_scores(surface_scores, contextual_scores, alpha=0.5):
    surface_dict = dict(surface_scores)
    contextual_dict = dict(contextual_scores)
    combined = {}

    all_terms = set(surface_dict.keys()).union(contextual_dict.keys())
    for term in all_terms:
        s_score = surface_dict.get(term, 0.0)
        c_score = contextual_dict.get(term, 0.0)
        combined[term] = alpha * s_score + (1 - alpha) * c_score

    sorted_combined = sorted(combined.items(), key=lambda x: -x[1])
    return sorted_combined

# Main Execution Pipeline
if __name__ == "__main__":
    # File Paths
    mapping_files = [
        "1_term_ID_to_string.txt",
        "2a_concept_ID_to_string.txt"
    ]
    concept_map_file = "3_term_ID_to_concept_ID.txt"
    singleton_file = "singlets_concepts_perBin_1d.txt"
    cofreq_file = "cofreqs_concepts_perBin_1d.txt"

    # Load term and concept string mappings
    term_id_map, concept_id_map = load_term_id_to_string(mapping_files)
    concept_to_term_map = load_concept_to_term_map(concept_map_file)

    # Load singleton and co-occurrence frequencies
    singleton_freq = load_singleton_frequencies(singleton_file, concept_to_term_map, term_id_map)
    cofreq_output_file = load_cofreq_counts(cofreq_file, concept_to_term_map, term_id_map)

    # Calculate total frequency count and build term index
    total_count = sum(singleton_freq.values())
    term_index = {term: i for i, term in enumerate(singleton_freq.keys())}
    matrix_size = len(term_index)

    # Compute contextual PMI matrix and save to disk
    pmi_output_file = compute_npmi(cofreq_output_file, singleton_freq, total_count, term_index, matrix_size, max_rows=3000000000)

    # Surface Model (CharNGram) Setup
    charngram_embedding_file = 'charNgram.txt'
    term_list = list(term_id_map.values())

    #Load n-gram embeddings and build term vectors
    ngram_embeddings = load_char_ngram_embeddings(charngram_embedding_file)
    print("Computing term embeddings...")
    term_vectors = build_term_embeddings(term_list, ngram_embeddings, dim=100)


    # === Choose Target Word ===
    target_word = "leukemia"

    #Surface-form synonyms using CharNGram similarity
    print(f"\n🔍 Finding surface-form synonyms for: {target_word}")
    surface_synonyms = find_surface_form_synonyms(term_vectors, target_word, ngram_embeddings, dim=100, top_n=100)
    surface_synonyms = normalize_scores(surface_synonyms)

    # Contextual synonyms using NPMI-based similarity
    print(f"\n🔍 Finding contextual synonyms for: {target_word}")
    contextual_synonyms = find_synonyms_fast(pmi_output_file, term_index, target_word, top_n=100)
    contextual_synonyms = normalize_scores(contextual_synonyms)

    # Combine both types of synonyms using hybrid model
    print(f"\n🔀 Combining hybrid scores for: {target_word}")
    hybrid_synonyms = combine_hybrid_scores(surface_synonyms, contextual_synonyms, alpha=0.5)

    # Print top hybrid synonyms
    print(f"\n✅ Top Hybrid Synonyms for '{target_word}':")
    for term, score in hybrid_synonyms[:10]:
        print(f"{term}: {score:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed 206300000 lines...
# Processed 206400000 lines...
# Processed 206500000 lines...
# Processed 206600000 lines...
# Processed 206700000 lines...
# Processed 206800000 lines...
# Processed 206900000 lines...
# Processed 207000000 lines...
# Processed 207100000 lines...
# Processed 207200000 lines...
# Processed 207300000 lines...
# Processed 207400000 lines...
# Processed 207500000 lines...
# Processed 207600000 lines...
# Processed 207700000 lines...
# Processed 207800000 lines...
# Processed 207900000 lines...
# Processed 208000000 lines...
# Processed 208100000 lines...
# Processed 208200000 lines...
# Processed 208300000 lines...
# Processed 208400000 lines...
# Processed 208500000 lines...
# Processed 208600000 lines...
# Processed 208700000 lines...
# Processed 208800000 lines...
# Processed 208900000 lines...
# Processed 209000000 lines...
# Processed 209100000 lines...
# Processed 209200000 lines...
# Processed 209300000 lines...
# Processed 209400000 lines...
# Processed 209500000 lines...
# Processed 209600000 lines...
# Processed 209700000 lines...
# Processed 209800000 lines...
# Processed 209900000 lines...
# Processed 210000000 lines...
# Processed 210100000 lines...
# Processed 210200000 lines...
# Processed 210300000 lines...
# Processed 210400000 lines...
# Processed 210500000 lines...
# Processed 210600000 lines...
# Processed 210700000 lines...
# Processed 210800000 lines...
# Processed 210900000 lines...
# Processed 211000000 lines...
# Processed 211100000 lines...
# Processed 211200000 lines...
# Processed 211300000 lines...
# Processed 211400000 lines...
# Processed 211500000 lines...
# Processed 211600000 lines...
# Processed 211700000 lines...
# Processed 211800000 lines...
# Processed 211900000 lines...
# Processed 212000000 lines...
# Processed 212100000 lines...
# Processed 212200000 lines...
# Processed 212300000 lines...
# Processed 212400000 lines...
# Processed 212500000 lines...
# Processed 212600000 lines...
# Processed 212700000 lines...
# Processed 212800000 lines...
# Processed 212900000 lines...
# Processed 213000000 lines...
# Processed 213100000 lines...
# Processed 213200000 lines...
# Processed 213300000 lines...
# Processed 213400000 lines...
# Processed 213500000 lines...
# Processed 213600000 lines...
# Processed 213700000 lines...
# Processed 213800000 lines...
# Processed 213900000 lines...
# Processed 214000000 lines...
# Processed 214100000 lines...
# Processed 214200000 lines...
# Processed 214300000 lines...
# Processed 214400000 lines...
# Processed 214500000 lines...
# Processed 214600000 lines...
# Processed 214700000 lines...
# Processed 214800000 lines...
# Processed 214900000 lines...
# Processed 215000000 lines...
# Processed 215100000 lines...
# Processed 215200000 lines...
# Processed 215300000 lines...
# Processed 215400000 lines...
# Processed 215500000 lines...
# Processed 215600000 lines...
# Processed 215700000 lines...
# Processed 215800000 lines...
# Processed 215900000 lines...
# Processed 216000000 lines...
# Processed 216100000 lines...
# Processed 216200000 lines...
# Processed 216300000 lines...
# Processed 216400000 lines...
# Processed 216500000 lines...
# Processed 216600000 lines...
# Processed 216700000 lines...
# Processed 216800000 lines...
# Processed 216900000 lines...
# Processed 217000000 lines...
# Processed 217100000 lines...
# Processed 217200000 lines...
# Processed 217300000 lines...
# Processed 217400000 lines...
# Processed 217500000 lines...
# Processed 217600000 lines...
# Processed 217700000 lines...
# Processed 217800000 lines...
# Processed 217900000 lines...
# Processed 218000000 lines...
# Processed 218100000 lines...
# Processed 218200000 lines...
# Processed 218300000 lines...
# Processed 218400000 lines...
# Processed 218500000 lines...
# Processed 218600000 lines...
# Processed 218700000 lines...
# Processed 218800000 lines...
# Processed 218900000 lines...
# Processed 219000000 lines...
# Processed 219100000 lines...
# Processed 219200000 lines...
# Processed 219300000 lines...
# Processed 219400000 lines...
# Processed 219500000 lines...
# Processed 219600000 lines...
# Processed 219700000 lines...
# Processed 219800000 lines...
# Processed 219900000 lines...
# Processed 220000000 lines...
# Processed 220100000 lines...
# Processed 220200000 lines...
# Processed 220300000 lines...
# Processed 220400000 lines...
# Processed 220500000 lines...
# Processed 220600000 lines...
# Processed 220700000 lines...
# Processed 220800000 lines...
# Processed 220900000 lines...
# Processed 221000000 lines...
# Processed 221100000 lines...
# Processed 221200000 lines...
# Processed 221300000 lines...
# Processed 221400000 lines...
# Processed 221500000 lines...
# Processed 221600000 lines...
# Processed 221700000 lines...
# Processed 221800000 lines...
# Processed 221900000 lines...
# Processed 222000000 lines...
# Processed 222100000 lines...
# Processed 222200000 lines...
# Processed 222300000 lines...
# Processed 222400000 lines...
# Processed 222500000 lines...
# Processed 222600000 lines...
# Processed 222700000 lines...
# Processed 222800000 lines...
# Processed 222900000 lines...
# Processed 223000000 lines...
# Processed 223100000 lines...
# Processed 223200000 lines...
# Processed 223300000 lines...
# Processed 223400000 lines...
# Processed 223500000 lines...
# Processed 223600000 lines...
# Processed 223700000 lines...
# Processed 223800000 lines...
# Processed 223900000 lines...
# Processed 224000000 lines...
# Processed 224100000 lines...
# Processed 224200000 lines...
# Processed 224300000 lines...
# Processed 224400000 lines...
# Processed 224500000 lines...
# Processed 224600000 lines...
# Processed 224700000 lines...
# Processed 224800000 lines...
# Processed 224900000 lines...
# Processed 225000000 lines...
# Processed 225100000 lines...
# Processed 225200000 lines...
# Processed 225300000 lines...
# Processed 225400000 lines...
# Processed 225500000 lines...
# Processed 225600000 lines...
# Processed 225700000 lines...
# Processed 225800000 lines...
# Processed 225900000 lines...
# Processed 226000000 lines...
# Processed 226100000 lines...
# Processed 226200000 lines...
# Processed 226300000 lines...
# Processed 226400000 lines...
# Processed 226500000 lines...
# Processed 226600000 lines...
# Processed 226700000 lines...
# Processed 226800000 lines...
# Processed 226900000 lines...
# Processed 227000000 lines...
# Processed 227100000 lines...
# Processed 227200000 lines...
# Processed 227300000 lines...
# Processed 227400000 lines...
# Processed 227500000 lines...
# Processed 227600000 lines...
# Processed 227700000 lines...
# Processed 227800000 lines...
# Processed 227900000 lines...
# Processed 228000000 lines...
# Processed 228100000 lines...
# Processed 228200000 lines...
# Processed 228300000 lines...
# Processed 228400000 lines...
# Processed 228500000 lines...
# Processed 228600000 lines...
# Processed 228700000 lines...
# Processed 228800000 lines...
# Processed 228900000 lines...
# Processed 229000000 lines...
# Processed 229100000 lines...
# Processed 229200000 lines...
# Processed 229300000 lines...
# Processed 229400000 lines...
# Processed 229500000 lines...
# Processed 229600000 lines...
# Processed 229700000 lines...
# Processed 229800000 lines...
# Processed 229900000 lines...
# Processed 230000000 lines...
# Processed 230100000 lines...
# Processed 230200000 lines...
# Processed 230300000 lines...
# Processed 230400000 lines...
# Processed 230500000 lines...
# Processed 230600000 lines...
# Processed 230700000 lines...
# Processed 230800000 lines...
# Processed 230900000 lines...
# Processed 231000000 lines...
# Processed 231100000 lines...
# Processed 231200000 lines...
# Processed 231300000 lines...
# Processed 231400000 lines...
# Processed 231500000 lines...
# Processed 231600000 lines...
# Processed 231700000 lines...
# Processed 231800000 lines...
# Processed 231900000 lines...
# Processed 232000000 lines...
# Processed 232100000 lines...
# Processed 232200000 lines...
# Processed 232300000 lines...
# Processed 232400000 lines...
# Processed 232500000 lines...
# Processed 232600000 lines...
# Processed 232700000 lines...
# Processed 232800000 lines...
# Processed 232900000 lines...
# Processed 233000000 lines...
# Processed 233100000 lines...
# Processed 233200000 lines...
# Processed 233300000 lines...
# Processed 233400000 lines...
# Processed 233500000 lines...
# Processed 233600000 lines...
# Processed 233700000 lines...
# Processed 233800000 lines...
# Processed 233900000 lines...
# Processed 234000000 lines...
# Processed 234100000 lines...
# Processed 234200000 lines...
# Processed 234300000 lines...
# Processed 234400000 lines...
# Processed 234500000 lines...
# Processed 234600000 lines...
# Processed 234700000 lines...
# Processed 234800000 lines...
# Processed 234900000 lines...
# Processed 235000000 lines...
# Processed 235100000 lines...
# Processed 235200000 lines...
# Processed 235300000 lines...
# Processed 235400000 lines...
# Processed 235500000 lines...
# Processed 235600000 lines...
# Processed 235700000 lines...
# Processed 235800000 lines...
# Processed 235900000 lines...
# Processed 236000000 lines...
# Processed 236100000 lines...
# Processed 236200000 lines...
# Processed 236300000 lines...
# Processed 236400000 lines...
# Processed 236500000 lines...
# Processed 236600000 lines...
# Processed 236700000 lines...
# Processed 236800000 lines...
# Processed 236900000 lines...
# Processed 237000000 lines...
# Processed 237100000 lines...
# Processed 237200000 lines...
# Processed 237300000 lines...
# Processed 237400000 lines...
# Processed 237500000 lines...
# Processed 237600000 lines...
# Processed 237700000 lines...
# Processed 237800000 lines...
# Processed 237900000 lines...
# Processed 238000000 lines...
# Processed 238100000 lines...
# Processed 238200000 lines...
# Processed 238300000 lines...
# Processed 238400000 lines...
# Processed 238500000 lines...
# Processed 238600000 lines...
# Processed 238700000 lines...
# Processed 238800000 lines...
# Processed 238900000 lines...
# Processed 239000000 lines...
# Processed 239100000 lines...
# Processed 239200000 lines...
# Processed 239300000 lines...
# Processed 239400000 lines...
# Processed 239500000 lines...
# Processed 239600000 lines...
# Processed 239700000 lines...
# Processed 239800000 lines...
# Processed 239900000 lines...
# Processed 240000000 lines...
# Processed 240100000 lines...
# Processed 240200000 lines...
# Processed 240300000 lines...
# Processed 240400000 lines...
# Processed 240500000 lines...
# Processed 240600000 lines...
# Processed 240700000 lines...
# Processed 240800000 lines...
# Processed 240900000 lines...
# Processed 241000000 lines...
# Processed 241100000 lines...
# Processed 241200000 lines...
# Processed 241300000 lines...
# Processed 241400000 lines...
# Processed 241500000 lines...
# Processed 241600000 lines...
# Processed 241700000 lines...
# Processed 241800000 lines...
# Processed 241900000 lines...
# Processed 242000000 lines...
# Processed 242100000 lines...
# Processed 242200000 lines...
# Processed 242300000 lines...
# Processed 242400000 lines...
# Processed 242500000 lines...
# Processed 242600000 lines...
# Processed 242700000 lines...
# Processed 242800000 lines...
# Processed 242900000 lines...
# Processed 243000000 lines...
# Processed 243100000 lines...
# Processed 243200000 lines...
# Processed 243300000 lines...
# Processed 243400000 lines...
# Processed 243500000 lines...
# Processed 243600000 lines...
# Processed 243700000 lines...
# Processed 243800000 lines...
# Processed 243900000 lines...
# Processed 244000000 lines...
# Processed 244100000 lines...
# Processed 244200000 lines...
# Processed 244300000 lines...
# Processed 244400000 lines...
# Processed 244500000 lines...
# Processed 244600000 lines...
# Processed 244700000 lines...
# Processed 244800000 lines...
# Processed 244900000 lines...
# Processed 245000000 lines...
# Processed 245100000 lines...
# Processed 245200000 lines...
# Processed 245300000 lines...
# Processed 245400000 lines...
# Processed 245500000 lines...
# Processed 245600000 lines...
# Processed 245700000 lines...
# Processed 245800000 lines...
# Processed 245900000 lines...
# Processed 246000000 lines...
# Processed 246100000 lines...
# Processed 246200000 lines...
# Processed 246300000 lines...
# Processed 246400000 lines...
# Processed 246500000 lines...
# Processed 246600000 lines...
# Processed 246700000 lines...
# Processed 246800000 lines...
# Processed 246900000 lines...
# Processed 247000000 lines...
# Processed 247100000 lines...
# Processed 247200000 lines...
# Processed 247300000 lines...
# Processed 247400000 lines...
# Processed 247500000 lines...
# Processed 247600000 lines...
# Processed 247700000 lines...
# Processed 247800000 lines...
# Processed 247900000 lines...
# Processed 248000000 lines...
# Processed 248100000 lines...
# Processed 248200000 lines...
# Processed 248300000 lines...
# Processed 248400000 lines...
# Processed 248500000 lines...
# Processed 248600000 lines...
# Processed 248700000 lines...
# Processed 248800000 lines...
# Processed 248900000 lines...
# Processed 249000000 lines...
# Processed 249100000 lines...
# Processed 249200000 lines...
# Processed 249300000 lines...
# Processed 249400000 lines...
# Processed 249500000 lines...
# Processed 249600000 lines...
# Processed 249700000 lines...
# Processed 249800000 lines...
# Processed 249900000 lines...
# Processed 250000000 lines...
# Processed 250100000 lines...
# Processed 250200000 lines...
# Processed 250300000 lines...
# Processed 250400000 lines...
# Processed 250500000 lines...
# Processed 250600000 lines...
# Processed 250700000 lines...
# Processed 250800000 lines...
# Processed 250900000 lines...
# Processed 251000000 lines...
# Processed 251100000 lines...
# Processed 251200000 lines...
# Processed 251300000 lines...
# Processed 251400000 lines...
# Processed 251500000 lines...
# Processed 251600000 lines...
# Processed 251700000 lines...
# Processed 251800000 lines...
# Processed 251900000 lines...
# Processed 252000000 lines...
# Processed 252100000 lines...
# Processed 252200000 lines...
# Processed 252300000 lines...
# Processed 252400000 lines...
# Processed 252500000 lines...
# Processed 252600000 lines...
# Processed 252700000 lines...
# Processed 252800000 lines...
# Processed 252900000 lines...
# Processed 253000000 lines...
# Processed 253100000 lines...
# Processed 253200000 lines...
# Processed 253300000 lines...
# Processed 253400000 lines...
# Processed 253500000 lines...
# Processed 253600000 lines...
# Processed 253700000 lines...
# Processed 253800000 lines...
# Processed 253900000 lines...
# Processed 254000000 lines...
# Processed 254100000 lines...
# Processed 254200000 lines...
# Processed 254300000 lines...
# Processed 254400000 lines...
# Processed 254500000 lines...
# Processed 254600000 lines...
# Processed 254700000 lines...
# Processed 254800000 lines...
# Processed 254900000 lines...
# Processed 255000000 lines...
# Processed 255100000 lines...
# Processed 255200000 lines...
# Processed 255300000 lines...
# Processed 255400000 lines...
# Processed 255500000 lines...
# Processed 255600000 lines...
# Processed 255700000 lines...
# Processed 255800000 lines...
# Processed 255900000 lines...
# Processed 256000000 lines...
# Processed 256100000 lines...
# Processed 256200000 lines...
# Processed 256300000 lines...
# Processed 256400000 lines...
# Processed 256500000 lines...
# Processed 256600000 lines...
# Processed 256700000 lines...
# Processed 256800000 lines...
# Processed 256900000 lines...
# Processed 257000000 lines...
# Processed 257100000 lines...
# Processed 257200000 lines...
# Processed 257300000 lines...
# Processed 257400000 lines...
# Processed 257500000 lines...
# Processed 257600000 lines...
# Processed 257700000 lines...
# Processed 257800000 lines...
# Processed 257900000 lines...
# Processed 258000000 lines...
# Processed 258100000 lines...
# Processed 258200000 lines...
# Processed 258300000 lines...
# Processed 258400000 lines...
# Processed 258500000 lines...
# Processed 258600000 lines...
# Processed 258700000 lines...
# Processed 258800000 lines...
# Processed 258900000 lines...
# Processed 259000000 lines...
# Processed 259100000 lines...
# Processed 259200000 lines...
# Processed 259300000 lines...
# Processed 259400000 lines...
# Processed 259500000 lines...
# Processed 259600000 lines...
# Processed 259700000 lines...
# Processed 259800000 lines...
# Processed 259900000 lines...
# Processed 260000000 lines...
# Processed 260100000 lines...
# Processed 260200000 lines...
# Processed 260300000 lines...
# Processed 260400000 lines...
# Processed 260500000 lines...
# Processed 260600000 lines...
# Processed 260700000 lines...
# Processed 260800000 lines...
# Processed 260900000 lines...
# Processed 261000000 lines...
# Processed 261100000 lines...
# Processed 261200000 lines...
# Processed 261300000 lines...
# Processed 261400000 lines...
# Processed 261500000 lines...
# Processed 261600000 lines...
# Processed 261700000 lines...
# Processed 261800000 lines...
# Processed 261900000 lines...
# Processed 262000000 lines...
# Processed 262100000 lines...
# Processed 262200000 lines...
# Processed 262300000 lines...
# Processed 262400000 lines...
# Processed 262500000 lines...
# Processed 262600000 lines...
# Processed 262700000 lines...
# Processed 262800000 lines...
# Processed 262900000 lines...
# Processed 263000000 lines...
# Processed 263100000 lines...
# Processed 263200000 lines...
# Processed 263300000 lines...
# Processed 263400000 lines...
# Processed 263500000 lines...
# Processed 263600000 lines...
# Processed 263700000 lines...
# Processed 263800000 lines...
# Processed 263900000 lines...
# Processed 264000000 lines...
# Processed 264100000 lines...
# Processed 264200000 lines...
# Processed 264300000 lines...
# Processed 264400000 lines...
# Processed 264500000 lines...
# Processed 264600000 lines...
# Processed 264700000 lines...
# Processed 264800000 lines...
# Processed 264900000 lines...
# Processed 265000000 lines...
# Processed 265100000 lines...
# Processed 265200000 lines...
# Processed 265300000 lines...
# Processed 265400000 lines...
# Processed 265500000 lines...
# Processed 265600000 lines...
# Processed 265700000 lines...
# Processed 265800000 lines...
# Processed 265900000 lines...
# Processed 266000000 lines...
# Processed 266100000 lines...
# Processed 266200000 lines...
# Processed 266300000 lines...
# Processed 266400000 lines...
# Processed 266500000 lines...
# Processed 266600000 lines...
# Processed 266700000 lines...
# Processed 266800000 lines...
# Processed 266900000 lines...
# Processed 267000000 lines...
# Processed 267100000 lines...
# Processed 267200000 lines...
# Processed 267300000 lines...
# Processed 267400000 lines...
# Processed 267500000 lines...
# Processed 267600000 lines...
# Processed 267700000 lines...
# Processed 267800000 lines...
# Processed 267900000 lines...
# Processed 268000000 lines...
# Processed 268100000 lines...
# Processed 268200000 lines...
# Processed 268300000 lines...
# Processed 268400000 lines...
# Processed 268500000 lines...
# Processed 268600000 lines...
# Processed 268700000 lines...
# Processed 268800000 lines...
# Processed 268900000 lines...
# Processed 269000000 lines...
# Processed 269100000 lines...
# Processed 269200000 lines...
# Processed 269300000 lines...
# Processed 269400000 lines...
# Processed 269500000 lines...
# Processed 269600000 lines...
# Processed 269700000 lines...
# Processed 269800000 lines...
# Processed 269900000 lines...
# Processed 270000000 lines...
# Processed 270100000 lines...
# Processed 270200000 lines...
# Processed 270300000 lines...
# Processed 270400000 lines...
# Processed 270500000 lines...
# Processed 270600000 lines...
# Processed 270700000 lines...
# Processed 270800000 lines...
# Processed 270900000 lines...
# Processed 271000000 lines...
# Processed 271100000 lines...
# Processed 271200000 lines...
# Processed 271300000 lines...
# Processed 271400000 lines...
# Processed 271500000 lines...
# Processed 271600000 lines...
# Processed 271700000 lines...
# Processed 271800000 lines...
# Processed 271900000 lines...
# Processed 272000000 lines...
# Processed 272100000 lines...
# Processed 272200000 lines...
# Processed 272300000 lines...
# Processed 272400000 lines...
# Processed 272500000 lines...
# Processed 272600000 lines...
# Processed 272700000 lines...
# Processed 272800000 lines...
# Processed 272900000 lines...
# Processed 273000000 lines...
# Processed 273100000 lines...
# Processed 273200000 lines...
# Processed 273300000 lines...
# Processed 273400000 lines...
# Processed 273500000 lines...
# Processed 273600000 lines...
# Processed 273700000 lines...
# Processed 273800000 lines...
# Processed 273900000 lines...
# Processed 274000000 lines...
# Processed 274100000 lines...
# Processed 274200000 lines...
# Processed 274300000 lines...
# Processed 274400000 lines...
# Processed 274500000 lines...
# Processed 274600000 lines...
# Processed 274700000 lines...
# Processed 274800000 lines...
# Processed 274900000 lines...
# Processed 275000000 lines...
# Processed 275100000 lines...
# Processed 275200000 lines...
# Processed 275300000 lines...
# Processed 275400000 lines...
# Processed 275500000 lines...
# Processed 275600000 lines...
# Processed 275700000 lines...
# Processed 275800000 lines...
# Processed 275900000 lines...
# Processed 276000000 lines...
# Processed 276100000 lines...
# Processed 276200000 lines...
# Processed 276300000 lines...
# Processed 276400000 lines...
# Processed 276500000 lines...
# Processed 276600000 lines...
# Processed 276700000 lines...
# Processed 276800000 lines...
# Processed 276900000 lines...
# Processed 277000000 lines...
# Processed 277100000 lines...
# Processed 277200000 lines...
# Processed 277300000 lines...
# Processed 277400000 lines...
# Processed 277500000 lines...
# Processed 277600000 lines...
# Processed 277700000 lines...
# Processed 277800000 lines...
# Processed 277900000 lines...
# Processed 278000000 lines...
# Processed 278100000 lines...
# Processed 278200000 lines...
# Processed 278300000 lines...
# Processed 278400000 lines...
# Processed 278500000 lines...
# Processed 278600000 lines...
# Processed 278700000 lines...
# Processed 278800000 lines...
# Processed 278900000 lines...
# Processed 279000000 lines...
# Processed 279100000 lines...
# Processed 279200000 lines...
# Processed 279300000 lines...
# Processed 279400000 lines...
# Processed 279500000 lines...
# Processed 279600000 lines...
# Processed 279700000 lines...
# Processed 279800000 lines...
# Processed 279900000 lines...
# Processed 280000000 lines...
# Processed 280100000 lines...
# Processed 280200000 lines...
# Processed 280300000 lines...
# Processed 280400000 lines...
# Processed 280500000 lines...
# Processed 280600000 lines...
# Processed 280700000 lines...
# Processed 280800000 lines...
# Processed 280900000 lines...
# Processed 281000000 lines...
# Processed 281100000 lines...
# Processed 281200000 lines...
# Processed 281300000 lines...
# Processed 281400000 lines...
# Processed 281500000 lines...
# Processed 281600000 lines...
# Processed 281700000 lines...
# Processed 281800000 lines...
# Processed 281900000 lines...
# Processed 282000000 lines...
# Processed 282100000 lines...
# Processed 282200000 lines...
# Processed 282300000 lines...
# Processed 282400000 lines...
# Processed 282500000 lines...
# Processed 282600000 lines...
# Processed 282700000 lines...
# Processed 282800000 lines...
# Processed 282900000 lines...
# Processed 283000000 lines...
# Processed 283100000 lines...
# Processed 283200000 lines...
# Processed 283300000 lines...
# Processed 283400000 lines...
# Processed 283500000 lines...
# Processed 283600000 lines...
# Processed 283700000 lines...
# Processed 283800000 lines...
# Processed 283900000 lines...
# Processed 284000000 lines...
# Processed 284100000 lines...
# Processed 284200000 lines...
# Processed 284300000 lines...
# Processed 284400000 lines...
# Processed 284500000 lines...
# Processed 284600000 lines...
# Processed 284700000 lines...
# Processed 284800000 lines...
# Processed 284900000 lines...
# Processed 285000000 lines...
# Processed 285100000 lines...
# Processed 285200000 lines...
# Processed 285300000 lines...
# Processed 285400000 lines...
# Processed 285500000 lines...
# Processed 285600000 lines...
# Processed 285700000 lines...
# Processed 285800000 lines...
# Processed 285900000 lines...
# Processed 286000000 lines...
# Processed 286100000 lines...
# Processed 286200000 lines...
# Processed 286300000 lines...
# Processed 286400000 lines...
# Processed 286500000 lines...
# Processed 286600000 lines...
# Processed 286700000 lines...
# Processed 286800000 lines...
# Processed 286900000 lines...
# Processed 287000000 lines...
# Processed 287100000 lines...
# Processed 287200000 lines...
# Processed 287300000 lines...
# Processed 287400000 lines...
# Processed 287500000 lines...
# Processed 287600000 lines...
# Processed 287700000 lines...
# Processed 287800000 lines...
# Processed 287900000 lines...
# Processed 288000000 lines...
# Processed 288100000 lines...
# Processed 288200000 lines...
# Processed 288300000 lines...
# Processed 288400000 lines...
# Processed 288500000 lines...
# Processed 288600000 lines...
# Processed 288700000 lines...
# Processed 288800000 lines...
# Processed 288900000 lines...
# Processed 289000000 lines...
# Processed 289100000 lines...
# Processed 289200000 lines...
# Processed 289300000 lines...
# Processed 289400000 lines...
# Processed 289500000 lines...
# Processed 289600000 lines...
# Processed 289700000 lines...
# Processed 289800000 lines...
# Processed 289900000 lines...
# Processed 290000000 lines...
# Processed 290100000 lines...
# Processed 290200000 lines...
# Processed 290300000 lines...
# Processed 290400000 lines...
# Processed 290500000 lines...
# Processed 290600000 lines...
# Processed 290700000 lines...
# Processed 290800000 lines...
# Processed 290900000 lines...
# Processed 291000000 lines...
# Processed 291100000 lines...
# Processed 291200000 lines...
# Processed 291300000 lines...
# Processed 291400000 lines...
# Processed 291500000 lines...
# Processed 291600000 lines...
# Processed 291700000 lines...
# Processed 291800000 lines...
# Processed 291900000 lines...
# Processed 292000000 lines...
# Processed 292100000 lines...
# Processed 292200000 lines...
# Processed 292300000 lines...
# Processed 292400000 lines...
# Processed 292500000 lines...
# Processed 292600000 lines...
# Processed 292700000 lines...
# Processed 292800000 lines...
# Processed 292900000 lines...
# Processed 293000000 lines...
# Processed 293100000 lines...
# Processed 293200000 lines...
# Processed 293300000 lines...
# Processed 293400000 lines...
# Processed 293500000 lines...
# Processed 293600000 lines...
# Processed 293700000 lines...
# Processed 293800000 lines...
# Processed 293900000 lines...
# Processed 294000000 lines...
# Processed 294100000 lines...
# Processed 294200000 lines...
# Processed 294300000 lines...
# Processed 294400000 lines...
# Processed 294500000 lines...
# Processed 294600000 lines...
# Processed 294700000 lines...
# Processed 294800000 lines...
# Processed 294900000 lines...
# Processed 295000000 lines...
# Processed 295100000 lines...
# Processed 295200000 lines...
# Processed 295300000 lines...
# Processed 295400000 lines...
# Processed 295500000 lines...
# Processed 295600000 lines...
# Processed 295700000 lines...
# Processed 295800000 lines...
# Processed 295900000 lines...
# Processed 296000000 lines...
# Processed 296100000 lines...
# Processed 296200000 lines...
# Processed 296300000 lines...
# Processed 296400000 lines...
# Processed 296500000 lines...
# Processed 296600000 lines...
# Processed 296700000 lines...
# Processed 296800000 lines...
# Processed 296900000 lines...
# Processed 297000000 lines...
# Processed 297100000 lines...
# Processed 297200000 lines...
# Processed 297300000 lines...
# Processed 297400000 lines...
# Processed 297500000 lines...
# Processed 297600000 lines...
# Processed 297700000 lines...
# Processed 297800000 lines...
# Processed 297900000 lines...
# Processed 298000000 lines...
# Processed 298100000 lines...
# Processed 298200000 lines...
# Processed 298300000 lines...
# Processed 298400000 lines...
# Processed 298500000 lines...
# Processed 298600000 lines...
# Processed 298700000 lines...
# Processed 298800000 lines...
# Processed 298900000 lines...
# Processed 299000000 lines...
# Processed 299100000 lines...
# Processed 299200000 lines...
# Processed 299300000 lines...
# Processed 299400000 lines...
# Processed 299500000 lines...
# Processed 299600000 lines...
# Processed 299700000 lines...
# Processed 299800000 lines...
# Processed 299900000 lines...
# Processed 300000000 lines...
# Processed 300100000 lines...
# Processed 300200000 lines...
# Processed 300300000 lines...
# Processed 300400000 lines...
# Processed 300500000 lines...
# Processed 300600000 lines...
# Processed 300700000 lines...
# Processed 300800000 lines...
# Processed 300900000 lines...
# Processed 301000000 lines...
# Processed 301100000 lines...
# Processed 301200000 lines...
# Processed 301300000 lines...
# Processed 301400000 lines...
# Processed 301500000 lines...
# Processed 301600000 lines...
# Processed 301700000 lines...
# Processed 301800000 lines...
# Processed 301900000 lines...
# Processed 302000000 lines...
# Processed 302100000 lines...
# Processed 302200000 lines...
# Processed 302300000 lines...
# Processed 302400000 lines...
# Processed 302500000 lines...
# Processed 302600000 lines...
# Processed 302700000 lines...
# Processed 302800000 lines...
# Processed 302900000 lines...
# Processed 303000000 lines...
# Processed 303100000 lines...
# Processed 303200000 lines...
# Processed 303300000 lines...
# Processed 303400000 lines...
# Processed 303500000 lines...
# Processed 303600000 lines...
# Processed 303700000 lines...
# Processed 303800000 lines...
# Processed 303900000 lines...
# Processed 304000000 lines...
# Processed 304100000 lines...
# Processed 304200000 lines...
# Processed 304300000 lines...
# Processed 304400000 lines...
# Processed 304500000 lines...
# Processed 304600000 lines...
# Processed 304700000 lines...
# Processed 304800000 lines...
# Processed 304900000 lines...
# Processed 305000000 lines...
# Processed 305100000 lines...
# Processed 305200000 lines...
# Processed 305300000 lines...
# Processed 305400000 lines...
# Processed 305500000 lines...
# Processed 305600000 lines...
# Processed 305700000 lines...
# Processed 305800000 lines...
# Processed 305900000 lines...
# Processed 306000000 lines...
# Processed 306100000 lines...
# Processed 306200000 lines...
# Processed 306300000 lines...
# Processed 306400000 lines...
# Processed 306500000 lines...
# Processed 306600000 lines...
# Processed 306700000 lines...
# Processed 306800000 lines...
# Processed 306900000 lines...
# Processed 307000000 lines...
# Processed 307100000 lines...
# Processed 307200000 lines...
# Processed 307300000 lines...
# Processed 307400000 lines...
# Processed 307500000 lines...
# Processed 307600000 lines...
# Processed 307700000 lines...
# Processed 307800000 lines...
# Processed 307900000 lines...
# Processed 308000000 lines...
# Processed 308100000 lines...
# Processed 308200000 lines...
# Processed 308300000 lines...
# Processed 308400000 lines...
# Processed 308500000 lines...
# Processed 308600000 lines...
# Processed 308700000 lines...
# Processed 308800000 lines...
# Processed 308900000 lines...
# Processed 309000000 lines...
# Processed 309100000 lines...
# Processed 309200000 lines...
# Processed 309300000 lines...
# Processed 309400000 lines...
# Processed 309500000 lines...
# Processed 309600000 lines...
# Processed 309700000 lines...
# Processed 309800000 lines...
# Processed 309900000 lines...
# Processed 310000000 lines...
# Processed 310100000 lines...
# Processed 310200000 lines...
# Processed 310300000 lines...
# Processed 310400000 lines...
# Processed 310500000 lines...
# Processed 310600000 lines...
# Processed 310700000 lines...
# Processed 310800000 lines...
# Processed 310900000 lines...
# Processed 311000000 lines...
# Processed 311100000 lines...
# Processed 311200000 lines...
# Processed 311300000 lines...
# Processed 311400000 lines...
# Processed 311500000 lines...
# Processed 311600000 lines...
# Processed 311700000 lines...
# Processed 311800000 lines...
# Processed 311900000 lines...
# Processed 312000000 lines...
# Processed 312100000 lines...
# Processed 312200000 lines...
# Processed 312300000 lines...
# Processed 312400000 lines...
# Processed 312500000 lines...
# Processed 312600000 lines...
# Processed 312700000 lines...
# Processed 312800000 lines...
# Processed 312900000 lines...
# Processed 313000000 lines...
# Processed 313100000 lines...
# Processed 313200000 lines...
# Processed 313300000 lines...
# Processed 313400000 lines...
# Processed 313500000 lines...
# Processed 313600000 lines...
# Processed 313700000 lines...
# Processed 313800000 lines...
# Processed 313900000 lines...
# Processed 314000000 lines...
# Processed 314100000 lines...
# Processed 314200000 lines...
# Processed 314300000 lines...
# Processed 314400000 lines...
# Processed 314500000 lines...
# Processed 314600000 lines...
# Processed 314700000 lines...
# Processed 314800000 lines...
# Processed 314900000 lines...
# Processed 315000000 lines...
# Processed 315100000 lines...
# Processed 315200000 lines...
# Processed 315300000 lines...
# Processed 315400000 lines...
# Processed 315500000 lines...
# Processed 315600000 lines...
# Processed 315700000 lines...
# Processed 315800000 lines...
# Processed 315900000 lines...
# Processed 316000000 lines...
# Processed 316100000 lines...
# Processed 316200000 lines...
# Processed 316300000 lines...
# Processed 316400000 lines...
# Processed 316500000 lines...
# Processed 316600000 lines...
# Processed 316700000 lines...
# Processed 316800000 lines...
# Processed 316900000 lines...
# Processed 317000000 lines...
# Processed 317100000 lines...
# Processed 317200000 lines...
# Processed 317300000 lines...
# Processed 317400000 lines...
# Processed 317500000 lines...
# Processed 317600000 lines...
# Processed 317700000 lines...
# Processed 317800000 lines...
# Processed 317900000 lines...
# Processed 318000000 lines...
# Processed 318100000 lines...
# Processed 318200000 lines...
# Processed 318300000 lines...
# Processed 318400000 lines...
# Processed 318500000 lines...
# Processed 318600000 lines...
# Processed 318700000 lines...
# Processed 318800000 lines...
# Processed 318900000 lines...
# Processed 319000000 lines...
# Processed 319100000 lines...
# Processed 319200000 lines...
# Processed 319300000 lines...
# Processed 319400000 lines...
# Processed 319500000 lines...
# Processed 319600000 lines...
# Processed 319700000 lines...
# Processed 319800000 lines...
# Processed 319900000 lines...
# Processed 320000000 lines...
# Processed 320100000 lines...
# Processed 320200000 lines...
# Processed 320300000 lines...
# Processed 320400000 lines...
# Processed 320500000 lines...
# Processed 320600000 lines...
# Processed 320700000 lines...
# Processed 320800000 lines...
# Processed 320900000 lines...
# Processed 321000000 lines...
# Processed 321100000 lines...
# Processed 321200000 lines...
# Processed 321300000 lines...
# Processed 321400000 lines...
# Processed 321500000 lines...
# Processed 321600000 lines...
# Processed 321700000 lines...
# Processed 321800000 lines...
# Processed 321900000 lines...
# Processed 322000000 lines...
# Processed 322100000 lines...
# Processed 322200000 lines...
# Processed 322300000 lines...
# Processed 322400000 lines...
# Processed 322500000 lines...
# Processed 322600000 lines...
# Processed 322700000 lines...
# Processed 322800000 lines...
# Processed 322900000 lines...
# Processed 323000000 lines...
# Processed 323100000 lines...
# Processed 323200000 lines...
# Processed 323300000 lines...
# Processed 323400000 lines...
# Processed 323500000 lines...
# Processed 323600000 lines...
# Processed 323700000 lines...
# Processed 323800000 lines...
# Processed 323900000 lines...
# Processed 324000000 lines...
# Processed 324100000 lines...
# Processed 324200000 lines...
# Processed 324300000 lines...
# Processed 324400000 lines...
# Processed 324500000 lines...
# Processed 324600000 lines...
# Processed 324700000 lines...
# Processed 324800000 lines...
# Processed 324900000 lines...
# Processed 325000000 lines...
# Processed 325100000 lines...
# Processed 325200000 lines...
# Processed 325300000 lines...
# Processed 325400000 lines...
# Processed 325500000 lines...
# Processed 325600000 lines...
# Processed 325700000 lines...
# Processed 325800000 lines...
# Processed 325900000 lines...
# Processed 326000000 lines...
# Processed 326100000 lines...
# Processed 326200000 lines...
# Processed 326300000 lines...
# Processed 326400000 lines...
# Processed 326500000 lines...
# Processed 326600000 lines...
# Processed 326700000 lines...
# Processed 326800000 lines...
# Processed 326900000 lines...
# Processed 327000000 lines...
# Processed 327100000 lines...
# Processed 327200000 lines...
# Processed 327300000 lines...
# Processed 327400000 lines...
# Processed 327500000 lines...
# Processed 327600000 lines...
# Processed 327700000 lines...
# Processed 327800000 lines...
# Processed 327900000 lines...
# Processed 328000000 lines...
# Processed 328100000 lines...
# Processed 328200000 lines...
# Processed 328300000 lines...
# Processed 328400000 lines...
# Processed 328500000 lines...
# Processed 328600000 lines...
# Processed 328700000 lines...
# Processed 328800000 lines...
# Processed 328900000 lines...
# Processed 329000000 lines...
# Processed 329100000 lines...
# Processed 329200000 lines...
# Processed 329300000 lines...
# Processed 329400000 lines...
# Processed 329500000 lines...
# Processed 329600000 lines...
# Processed 329700000 lines...
# Processed 329800000 lines...
# Processed 329900000 lines...
# Processed 330000000 lines...
# Processed 330100000 lines...
# Processed 330200000 lines...
# Processed 330300000 lines...
# Processed 330400000 lines...
# Processed 330500000 lines...
# Processed 330600000 lines...
# Processed 330700000 lines...
# Processed 330800000 lines...
# Processed 330900000 lines...
# Processed 331000000 lines...
# Processed 331100000 lines...
# Processed 331200000 lines...
# Processed 331300000 lines...
# Processed 331400000 lines...
# Processed 331500000 lines...
# Processed 331600000 lines...
# Processed 331700000 lines...
# Processed 331800000 lines...
# Processed 331900000 lines...
# Processed 332000000 lines...
# Processed 332100000 lines...
# Processed 332200000 lines...
# Processed 332300000 lines...
# Processed 332400000 lines...
# Processed 332500000 lines...
# Processed 332600000 lines...
# Processed 332700000 lines...
# Processed 332800000 lines...
# Processed 332900000 lines...
# Processed 333000000 lines...
# Processed 333100000 lines...
# Processed 333200000 lines...
# Processed 333300000 lines...
# Processed 333400000 lines...
# Processed 333500000 lines...
# Processed 333600000 lines...
# Processed 333700000 lines...
# Processed 333800000 lines...
# Processed 333900000 lines...
# Processed 334000000 lines...
# Processed 334100000 lines...
# Processed 334200000 lines...
# Processed 334300000 lines...
# Processed 334400000 lines...
# Processed 334500000 lines...
# Processed 334600000 lines...
# Processed 334700000 lines...
# Processed 334800000 lines...
# Processed 334900000 lines...
# Processed 335000000 lines...
# Processed 335100000 lines...
# Processed 335200000 lines...
# Processed 335300000 lines...
# Processed 335400000 lines...
# Processed 335500000 lines...
# Processed 335600000 lines...
# Processed 335700000 lines...
# Processed 335800000 lines...
# Processed 335900000 lines...
# Processed 336000000 lines...
# Processed 336100000 lines...
# Processed 336200000 lines...
# Processed 336300000 lines...
# Processed 336400000 lines...
# Processed 336500000 lines...
# Processed 336600000 lines...
# Processed 336700000 lines...
# Processed 336800000 lines...
# Processed 336900000 lines...
# Processed 337000000 lines...
# Processed 337100000 lines...
# Processed 337200000 lines...
# Processed 337300000 lines...
# Processed 337400000 lines...
# Processed 337500000 lines...
# Processed 337600000 lines...
# Processed 337700000 lines...
# Processed 337800000 lines...
# Processed 337900000 lines...
# Processed 338000000 lines...
# Processed 338100000 lines...
# Processed 338200000 lines...
# Processed 338300000 lines...
# Processed 338400000 lines...
# Processed 338500000 lines...
# Processed 338600000 lines...
# Processed 338700000 lines...
# Processed 338800000 lines...
# Processed 338900000 lines...
# Processed 339000000 lines...
# Processed 339100000 lines...
# Processed 339200000 lines...
# Processed 339300000 lines...
# Processed 339400000 lines...
# Processed 339500000 lines...
# Processed 339600000 lines...
# Processed 339700000 lines...
# Processed 339800000 lines...
# Processed 339900000 lines...
# Processed 340000000 lines...
# Processed 340100000 lines...
# Processed 340200000 lines...
# Processed 340300000 lines...
# Processed 340400000 lines...
# Processed 340500000 lines...
# Processed 340600000 lines...
# Processed 340700000 lines...
# Processed 340800000 lines...
# Processed 340900000 lines...
# Processed 341000000 lines...
# Processed 341100000 lines...
# Processed 341200000 lines...
# Processed 341300000 lines...
# Processed 341400000 lines...
# Processed 341500000 lines...
# Processed 341600000 lines...
# Processed 341700000 lines...
# Processed 341800000 lines...
# Processed 341900000 lines...
# Processed 342000000 lines...
# Processed 342100000 lines...
# Processed 342200000 lines...
# Processed 342300000 lines...
# Processed 342400000 lines...
# Processed 342500000 lines...
# Processed 342600000 lines...
# Processed 342700000 lines...
# Processed 342800000 lines...
# Processed 342900000 lines...
# Processed 343000000 lines...
# Processed 343100000 lines...
# Processed 343200000 lines...
# Processed 343300000 lines...
# Processed 343400000 lines...
# Processed 343500000 lines...
# Processed 343600000 lines...
# Processed 343700000 lines...
# Processed 343800000 lines...
# Processed 343900000 lines...
# Processed 344000000 lines...
# Processed 344100000 lines...
# Processed 344200000 lines...
# Processed 344300000 lines...
# Processed 344400000 lines...
# Processed 344500000 lines...
# Processed 344600000 lines...
# Processed 344700000 lines...
# Processed 344800000 lines...
# Processed 344900000 lines...
# Processed 345000000 lines...
# Processed 345100000 lines...
# Processed 345200000 lines...
# Processed 345300000 lines...
# Processed 345400000 lines...
# Processed 345500000 lines...
# Processed 345600000 lines...
# Processed 345700000 lines...
# Processed 345800000 lines...
# Processed 345900000 lines...
# Processed 346000000 lines...
# Processed 346100000 lines...
# Processed 346200000 lines...
# Processed 346300000 lines...
# Processed 346400000 lines...
# Processed 346500000 lines...
# Processed 346600000 lines...
# Processed 346700000 lines...
# Processed 346800000 lines...
# Processed 346900000 lines...
# Processed 347000000 lines...
# Processed 347100000 lines...
# Processed 347200000 lines...
# Processed 347300000 lines...
# Processed 347400000 lines...
# Processed 347500000 lines...
# Processed 347600000 lines...
# Processed 347700000 lines...
# Processed 347800000 lines...
# Processed 347900000 lines...
# Processed 348000000 lines...
# Processed 348100000 lines...
# Processed 348200000 lines...
# Processed 348300000 lines...
# Processed 348400000 lines...
# Processed 348500000 lines...
# Processed 348600000 lines...
# Processed 348700000 lines...
# Processed 348800000 lines...
# Processed 348900000 lines...
# Processed 349000000 lines...
# Processed 349100000 lines...
# Processed 349200000 lines...
# Processed 349300000 lines...
# Processed 349400000 lines...
# Processed 349500000 lines...
# Processed 349600000 lines...
# Processed 349700000 lines...
# Processed 349800000 lines...
# Processed 349900000 lines...
# Processed 350000000 lines...
# Processed 350100000 lines...
# Processed 350200000 lines...
# Processed 350300000 lines...
# Processed 350400000 lines...
# Processed 350500000 lines...
# Processed 350600000 lines...
# Processed 350700000 lines...
# Processed 350800000 lines...
# Processed 350900000 lines...
# Processed 351000000 lines...
# Processed 351100000 lines...
# Processed 351200000 lines...
# Processed 351300000 lines...
# Processed 351400000 lines...
# Processed 351500000 lines...
# Processed 351600000 lines...
# Processed 351700000 lines...
# Processed 351800000 lines...
# Processed 351900000 lines...
# Processed 352000000 lines...
# Processed 352100000 lines...
# Processed 352200000 lines...
# Processed 352300000 lines...
# Processed 352400000 lines...
# Processed 352500000 lines...
# Processed 352600000 lines...
# Processed 352700000 lines...
# Processed 352800000 lines...
# Processed 352900000 lines...
# Processed 353000000 lines...
# Processed 353100000 lines...
# Processed 353200000 lines...
# Processed 353300000 lines...
# Processed 353400000 lines...
# Processed 353500000 lines...
# Processed 353600000 lines...
# Processed 353700000 lines...
# Processed 353800000 lines...
# Processed 353900000 lines...
# Processed 354000000 lines...
# Processed 354100000 lines...
# Processed 354200000 lines...
# Processed 354300000 lines...
# Processed 354400000 lines...
# Processed 354500000 lines...
# Processed 354600000 lines...
# Processed 354700000 lines...
# Processed 354800000 lines...
# Processed 354900000 lines...
# Processed 355000000 lines...
# Processed 355100000 lines...
# Processed 355200000 lines...
# Processed 355300000 lines...
# Processed 355400000 lines...
# Processed 355500000 lines...
# Processed 355600000 lines...
# Processed 355700000 lines...
# Processed 355800000 lines...
# Processed 355900000 lines...
# Processed 356000000 lines...
# Processed 356100000 lines...
# Processed 356200000 lines...
# Processed 356300000 lines...
# Processed 356400000 lines...
# Processed 356500000 lines...
# Processed 356600000 lines...
# Processed 356700000 lines...
# Processed 356800000 lines...
# Processed 356900000 lines...
# Processed 357000000 lines...
# Processed 357100000 lines...
# Processed 357200000 lines...
# Processed 357300000 lines...
# Processed 357400000 lines...
# Processed 357500000 lines...
# Processed 357600000 lines...
# Processed 357700000 lines...
# Processed 357800000 lines...
# Processed 357900000 lines...
# Processed 358000000 lines...
# Processed 358100000 lines...
# Processed 358200000 lines...
# Processed 358300000 lines...
# Processed 358400000 lines...
# Processed 358500000 lines...
# Processed 358600000 lines...
# Processed 358700000 lines...
# Processed 358800000 lines...
# Processed 358900000 lines...
# Processed 359000000 lines...
# Processed 359100000 lines...
# Processed 359200000 lines...
# Processed 359300000 lines...
# Processed 359400000 lines...
# Processed 359500000 lines...
# Processed 359600000 lines...
# Processed 359700000 lines...
# Processed 359800000 lines...
# Processed 359900000 lines...
# Processed 360000000 lines...
# Processed 360100000 lines...
# Processed 360200000 lines...
# Processed 360300000 lines...
# Processed 360400000 lines...
# Processed 360500000 lines...
# Processed 360600000 lines...
# Processed 360700000 lines...
# Processed 360800000 lines...
# Processed 360900000 lines...
# Processed 361000000 lines...
# Processed 361100000 lines...
# Processed 361200000 lines...
# Processed 361300000 lines...
# Processed 361400000 lines...
# Processed 361500000 lines...
# Processed 361600000 lines...
# Processed 361700000 lines...
# Processed 361800000 lines...
# Processed 361900000 lines...
# Processed 362000000 lines...
# Processed 362100000 lines...
# Processed 362200000 lines...
# Processed 362300000 lines...
# Processed 362400000 lines...
# Processed 362500000 lines...
# Processed 362600000 lines...
# Processed 362700000 lines...
# Processed 362800000 lines...
# Processed 362900000 lines...
# Processed 363000000 lines...
# Processed 363100000 lines...
# Processed 363200000 lines...
# Processed 363300000 lines...
# Processed 363400000 lines...
# Processed 363500000 lines...
# Processed 363600000 lines...
# Processed 363700000 lines...
# Processed 363800000 lines...
# Processed 363900000 lines...
# Processed 364000000 lines...
# Processed 364100000 lines...
# Processed 364200000 lines...
# Processed 364300000 lines...
# Processed 364400000 lines...
# Processed 364500000 lines...
# Processed 364600000 lines...
# Processed 364700000 lines...
# Processed 364800000 lines...
# Processed 364900000 lines...
# Processed 365000000 lines...
# Processed 365100000 lines...
# Processed 365200000 lines...
# Processed 365300000 lines...
# Processed 365400000 lines...
# Processed 365500000 lines...
# Processed 365600000 lines...
# Processed 365700000 lines...
# Processed 365800000 lines...
# Processed 365900000 lines...
# Processed 366000000 lines...
# Processed 366100000 lines...
# Processed 366200000 lines...
# Processed 366300000 lines...
# Processed 366400000 lines...
# Processed 366500000 lines...
# Processed 366600000 lines...
# Processed 366700000 lines...
# Processed 366800000 lines...
# Processed 366900000 lines...
# Processed 367000000 lines...
# Processed 367100000 lines...
# Processed 367200000 lines...
# Processed 367300000 lines...
# Processed 367400000 lines...
# Processed 367500000 lines...
# Processed 367600000 lines...
# Processed 367700000 lines...
# Processed 367800000 lines...
# Processed 367900000 lines...
# Processed 368000000 lines...
# Processed 368100000 lines...
# Processed 368200000 lines...
# Processed 368300000 lines...
# Processed 368400000 lines...
# Processed 368500000 lines...
# Processed 368600000 lines...
# Processed 368700000 lines...
# Processed 368800000 lines...
# Processed 368900000 lines...
# Processed 369000000 lines...
# Processed 369100000 lines...
# Processed 369200000 lines...
# Processed 369300000 lines...
# Processed 369400000 lines...
# Processed 369500000 lines...
# Processed 369600000 lines...
# Processed 369700000 lines...
# Processed 369800000 lines...
# Processed 369900000 lines...
# Processed 370000000 lines...
# Processed 370100000 lines...
# Processed 370200000 lines...
# Processed 370300000 lines...
# Processed 370400000 lines...
# Processed 370500000 lines...
# Processed 370600000 lines...
# Processed 370700000 lines...
# Processed 370800000 lines...
# Processed 370900000 lines...
# Processed 371000000 lines...
# Processed 371100000 lines...
# Processed 371200000 lines...
# Processed 371300000 lines...
# Processed 371400000 lines...
# Processed 371500000 lines...
# ...
# Processed 650800000 lines...
# Processed 650900000 lines...
# Processed 651000000 lines...
# Processed 651100000 lines...
# Processed 651200000 lines...
# Processed 651300000 lines...
# Processed 651400000 lines...
# Processed 651500000 lines...
# Processed 651600000 lines...
# Processed 651700000 lines...
# Processed 651800000 lines...
# Processed 651900000 lines...
# Processed 652000000 lines...
# Processed 652100000 lines...
# Processed 652200000 lines...
# Processed 652300000 lines...
# Processed 652400000 lines...
# Processed 652500000 lines...
# Processed 652600000 lines...
# Processed 652700000 lines...
# Processed 652800000 lines...
# Processed 652900000 lines...
# Processed 653000000 lines...
# Processed 653100000 lines...
# Processed 653200000 lines...
# Processed 653300000 lines...
# Processed 653400000 lines...
# Processed 653500000 lines...
# Processed 653600000 lines...
# Processed 653700000 lines...
# Processed 653800000 lines...
# Processed 653900000 lines...
# Processed 654000000 lines...
# Processed 654100000 lines...
# Processed 654200000 lines...
# Processed 654300000 lines...
# Processed 654400000 lines...
# Processed 654500000 lines...
# Processed 654600000 lines...
# Processed 654700000 lines...
# Processed 654800000 lines...
# Processed 654900000 lines...
# Processed 655000000 lines...
# Processed 655100000 lines...
# Processed 655200000 lines...
# Processed 655300000 lines...
# Processed 655400000 lines...
# Processed 655500000 lines...
# Processed 655600000 lines...
# Processed 655700000 lines...
# Processed 655800000 lines...
# Processed 655900000 lines...
# Processed 656000000 lines...
# Processed 656100000 lines...
# Processed 656200000 lines...
# Processed 656300000 lines...
# Processed 656400000 lines...
# Processed 656500000 lines...
# Processed 656600000 lines...
# Processed 656700000 lines...
# Processed 656800000 lines...
# Processed 656900000 lines...
# Processed 657000000 lines...
# Processed 657100000 lines...
# Processed 657200000 lines...
# Processed 657300000 lines...
# Processed 657400000 lines...
# Processed 657500000 lines...
# Processed 657600000 lines...
# Processed 657700000 lines...
# Processed 657800000 lines...
# Processed 657900000 lines...
# Processed 658000000 lines...
# Processed 658100000 lines...
# Processed 658200000 lines...
# Processed 658300000 lines...
# Processed 658400000 lines...
# Processed 658500000 lines...
# Processed 658600000 lines...
# Processed 658700000 lines...
# Processed 658800000 lines...
# Processed 658900000 lines...
# Processed 659000000 lines...
# Processed 659100000 lines...
# Processed 659200000 lines...
# Processed 659300000 lines...
# Processed 659400000 lines...
# Processed 659500000 lines...
# Processed 659600000 lines...
# Processed 659700000 lines...
# Processed 659800000 lines...
# Processed 659900000 lines...
# Processed 660000000 lines...
# Processed 660100000 lines...
# Processed 660200000 lines...
# Processed 660300000 lines...
# Processed 660400000 lines...
# Processed 660500000 lines...
# Processed 660600000 lines...
# Processed 660700000 lines...
# Processed 660800000 lines...
# Processed 660900000 lines...
# Processed 661000000 lines...
# Processed 661100000 lines...
# Processed 661200000 lines...
# Processed 661300000 lines...
# Processed 661400000 lines...
# Processed 661500000 lines...
# Processed 661600000 lines...
# Processed 661700000 lines...
# Processed 661800000 lines...
# Processed 661900000 lines...
# Processed 662000000 lines...
# Processed 662100000 lines...
# Processed 662200000 lines...
# Processed 662300000 lines...
# Processed 662400000 lines...
# Processed 662500000 lines...
# Processed 662600000 lines...
# Processed 662700000 lines...
# Processed 662800000 lines...
# Processed 662900000 lines...
# Processed 663000000 lines...
# Processed 663100000 lines...
# Processed 663200000 lines...
# Processed 663300000 lines...
# Processed 663400000 lines...
# Processed 663500000 lines...
# Processed 663600000 lines...
# Processed 663700000 lines...
# Processed 663800000 lines...
# Processed 663900000 lines...
# Processed 664000000 lines...
# Processed 664100000 lines...
# Processed 664200000 lines...
# Processed 664300000 lines...
# Processed 664400000 lines...
# Processed 664500000 lines...
# Processed 664600000 lines...
# Processed 664700000 lines...
# Processed 664800000 lines...
# Processed 664900000 lines...
# Processed 665000000 lines...
# Processed 665100000 lines...
# Processed 665200000 lines...
# Processed 665300000 lines...
# Processed 665400000 lines...
# Processed 665500000 lines...
# Processed 665600000 lines...
# Processed 665700000 lines...
# Processed 665800000 lines...
# Processed 665900000 lines...
# Processed 666000000 lines...
# Processed 666100000 lines...
# Processed 666200000 lines...
# Processed 666300000 lines...
# Processed 666400000 lines...
# Processed 666500000 lines...
# Processed 666600000 lines...
# Processed 666700000 lines...
# Processed 666800000 lines...
# Processed 666900000 lines...
# Processed 667000000 lines...
# Processed 667100000 lines...
# Processed 667200000 lines...
# Processed 667300000 lines...
# Processed 667400000 lines...
# Processed 667500000 lines...
# Processed 667600000 lines...
# Processed 667700000 lines...
# Processed 667800000 lines...
# Processed 667900000 lines...
# Processed 668000000 lines...
# Processed 668100000 lines...
# Processed 668200000 lines...
# Processed 668300000 lines...
# Processed 668400000 lines...
# Processed 668500000 lines...
# Processed 668600000 lines...
# Processed 668700000 lines...
# Processed 668800000 lines...
# Processed 668900000 lines...
# Processed 669000000 lines...
# Processed 669100000 lines...
# Processed 669200000 lines...
# Processed 669300000 lines...
# Processed 669400000 lines...
# Processed 669500000 lines...
# Processed 669600000 lines...
# Processed 669700000 lines...
# Processed 669800000 lines...
# Processed 669900000 lines...
# Processed 670000000 lines...
# Processed 670100000 lines...
# Processed 670200000 lines...
# Processed 670300000 lines...
# Processed 670400000 lines...
# Processed 670500000 lines...
# Processed 670600000 lines...
# Processed 670700000 lines...
# Processed 670800000 lines...
# Processed 670900000 lines...
# Processed 671000000 lines...
# Processed 671100000 lines...
# Processed 671200000 lines...
# Processed 671300000 lines...
# Processed 671400000 lines...
# Processed 671500000 lines...
# Processed 671600000 lines...
# Processed 671700000 lines...
# Processed 671800000 lines...
# Processed 671900000 lines...
# Processed 672000000 lines...
# Processed 672100000 lines...
# Processed 672200000 lines...
# Processed 672300000 lines...
# Processed 672400000 lines...
# Processed 672500000 lines...
# Processed 672600000 lines...
# Processed 672700000 lines...
# Processed 672800000 lines...
# Processed 672900000 lines...
# Processed 673000000 lines...
# Processed 673100000 lines...
# Processed 673200000 lines...
# Processed 673300000 lines...
# Processed 673400000 lines...
# Processed 673500000 lines...
# Processed 673600000 lines...
# Processed 673700000 lines...
# Processed 673800000 lines...
# Processed 673900000 lines...
# Processed 674000000 lines...
# Processed 674100000 lines...
# Processed 674200000 lines...
# Processed 674300000 lines...
# Processed 674400000 lines...
# Processed 674500000 lines...
# Processed 674600000 lines...
# Processed 674700000 lines...
# Processed 674800000 lines...
# Processed 674900000 lines...
# Processed 675000000 lines...
# Processed 675100000 lines...
# Processed 675200000 lines...
# Processed 675300000 lines...
# Processed 675400000 lines...
# Processed 675500000 lines...
# Processed 675600000 lines...
# Processed 675700000 lines...
# Processed 675800000 lines...
# Processed 675900000 lines...
# Processed 676000000 lines...
# Processed 676100000 lines...
# Processed 676200000 lines...
# Processed 676300000 lines...
# Processed 676400000 lines...
# Processed 676500000 lines...
# Processed 676600000 lines...
# Processed 676700000 lines...
# Processed 676800000 lines...
# Processed 676900000 lines...
# Processed 677000000 lines...
# Processed 677100000 lines...
# Processed 677200000 lines...
# Processed 677300000 lines...
# Processed 677400000 lines...
# Processed 677500000 lines...
# Processed 677600000 lines...
# Processed 677700000 lines...
# Processed 677800000 lines...
# Processed 677900000 lines...
# Processed 678000000 lines...
# Processed 678100000 lines...
# Processed 678200000 lines...
# Processed 678300000 lines...
# Processed 678400000 lines...
# Processed 678500000 lines...
# Processed 678600000 lines...
# Processed 678700000 lines...
# Processed 678800000 lines...
# Processed 678900000 lines...
# Processed 679000000 lines...
# Processed 679100000 lines...
# Processed 679200000 lines...
# Processed 679300000 lines...
# Processed 679400000 lines...
# Processed 679500000 lines...
# Processed 679600000 lines...
# Processed 679700000 lines...
# Processed 679800000 lines...
# Processed 679900000 lines...
# Processed 680000000 lines...
# Processed 680100000 lines...
# Processed 680200000 lines...
# Processed 680300000 lines...
# Processed 680400000 lines...
# Processed 680500000 lines...
# Processed 680600000 lines...
# Processed 680700000 lines...
# Processed 680800000 lines...
# Processed 680900000 lines...
# Processed 681000000 lines...
# Processed 681100000 lines...
# Processed 681200000 lines...
# Processed 681300000 lines...
# Processed 681400000 lines...
# Processed 681500000 lines...
# Processed 681600000 lines...
# Processed 681700000 lines...
# Processed 681800000 lines...
# Processed 681900000 lines...
# Processed 682000000 lines...
# Processed 682100000 lines...
# Processed 682200000 lines...
# Processed 682300000 lines...
# Processed 682400000 lines...
# Processed 682500000 lines...
# Processed 682600000 lines...
# Processed 682700000 lines...
# Processed 682800000 lines...
# Processed 682900000 lines...
# Processed 683000000 lines...
# Processed 683100000 lines...
# Processed 683200000 lines...
# Processed 683300000 lines...
# Processed 683400000 lines...
# Processed 683500000 lines...
# Processed 683600000 lines...
# Processed 683700000 lines...
# Processed 683800000 lines...
# Processed 683900000 lines...
# Processed 684000000 lines...
# Processed 684100000 lines...
# Processed 684200000 lines...
# Processed 684300000 lines...
# Processed 684400000 lines...
# Processed 684500000 lines...
# Processed 684600000 lines...
# Processed 684700000 lines...
# Processed 684800000 lines...
# Processed 684900000 lines...
# Processed 685000000 lines...
# Processed 685100000 lines...
# Processed 685200000 lines...
# Processed 685300000 lines...
# Processed 685400000 lines...
# Processed 685500000 lines...
# Processed 685600000 lines...
# Processed 685700000 lines...
# Processed 685800000 lines...
# Processed 685900000 lines...
# Processed 686000000 lines...
# Processed 686100000 lines...
# Processed 686200000 lines...
# Processed 686300000 lines...
# Processed 686400000 lines...
# Processed 686500000 lines...
# Processed 686600000 lines...
# Processed 686700000 lines...
# Processed 686800000 lines...
# Processed 686900000 lines...
# Processed 687000000 lines...
# Processed 687100000 lines...
# Processed 687200000 lines...
# Processed 687300000 lines...
# Processed 687400000 lines...
# Processed 687500000 lines...
# Processed 687600000 lines...
# Processed 687700000 lines...
# Processed 687800000 lines...
# Processed 687900000 lines...
# Processed 688000000 lines...
# Processed 688100000 lines...
# Processed 688200000 lines...
# Processed 688300000 lines...
# Processed 688400000 lines...
# Processed 688500000 lines...
# Processed 688600000 lines...
# Processed 688700000 lines...
# Processed 688800000 lines...
# Processed 688900000 lines...
# Processed 689000000 lines...
# Processed 689100000 lines...
# Processed 689200000 lines...
# Processed 689300000 lines...
# Processed 689400000 lines...
# Processed 689500000 lines...
# Processed 689600000 lines...
# Processed 689700000 lines...
# Processed 689800000 lines...
# Processed 689900000 lines...
# Processed 690000000 lines...
# Processed 690100000 lines...
# Processed 690200000 lines...
# Processed 690300000 lines...
# Processed 690400000 lines...
# Processed 690500000 lines...
# Processed 690600000 lines...
# Processed 690700000 lines...
# Processed 690800000 lines...
# Processed 690900000 lines...
# Processed 691000000 lines...
# Processed 691100000 lines...
# Processed 691200000 lines...
# Processed 691300000 lines...
# Processed 691400000 lines...
# Processed 691500000 lines...
# Processed 691600000 lines...
# Processed 691700000 lines...
# Processed 691800000 lines...
# Processed 691900000 lines...
# Processed 692000000 lines...
# Processed 692100000 lines...
# Processed 692200000 lines...
# Processed 692300000 lines...
# Processed 692400000 lines...
# Processed 692500000 lines...
# Processed 692600000 lines...
# Processed 692700000 lines...
# Processed 692800000 lines...
# Processed 692900000 lines...
# Processed 693000000 lines...
# Processed 693100000 lines...
# Processed 693200000 lines...
# Processed 693300000 lines...
# Processed 693400000 lines...
# Processed 693500000 lines...
# Processed 693600000 lines...
# Processed 693700000 lines...
# Processed 693800000 lines...
# Processed 693900000 lines...
# Processed 694000000 lines...
# Processed 694100000 lines...
# Processed 694200000 lines...
# Processed 694300000 lines...
# Processed 694400000 lines...
# Processed 694500000 lines...
# Processed 694600000 lines...
# Processed 694700000 lines...
# Processed 694800000 lines...
# Processed 694900000 lines...
# Processed 695000000 lines...
# Processed 695100000 lines...
# Processed 695200000 lines...
# Processed 695300000 lines...
# Processed 695400000 lines...
# Processed 695500000 lines...
# Processed 695600000 lines...
# Processed 695700000 lines...
# Processed 695800000 lines...
# Processed 695900000 lines...
# Processed 696000000 lines...
# Processed 696100000 lines...
# Processed 696200000 lines...
# Processed 696300000 lines...
# Processed 696400000 lines...
# Processed 696500000 lines...
# Processed 696600000 lines...
# Processed 696700000 lines...
# Processed 696800000 lines...
# Processed 696900000 lines...
# Processed 697000000 lines...
# Processed 697100000 lines...
# Processed 697200000 lines...
# Processed 697300000 lines...
# Processed 697400000 lines...
# Processed 697500000 lines...
# Processed 697600000 lines...
# Processed 697700000 lines...
# Processed 697800000 lines...
# Processed 697900000 lines...
# Processed 698000000 lines...
# Processed 698100000 lines...
# Processed 698200000 lines...
# Processed 698300000 lines...
# Processed 698400000 lines...
# Processed 698500000 lines...
# Processed 698600000 lines...
# Processed 698700000 lines...
# Processed 698800000 lines...
# Processed 698900000 lines...
# Processed 699000000 lines...
# Processed 699100000 lines...
# Processed 699200000 lines...
# Processed 699300000 lines...
# Processed 699400000 lines...
# Processed 699500000 lines...
# Processed 699600000 lines...
# Processed 699700000 lines...
# Processed 699800000 lines...
# Processed 699900000 lines...
# Processed 700000000 lines...
# Processed 700100000 lines...
# Processed 700200000 lines...
# Processed 700300000 lines...
# Processed 700400000 lines...
# Processed 700500000 lines...
# Processed 700600000 lines...
# Processed 700700000 lines...
# Processed 700800000 lines...
# Processed 700900000 lines...
# Processed 701000000 lines...
# Processed 701100000 lines...
# Processed 701200000 lines...
# Processed 701300000 lines...
# Processed 701400000 lines...
# Processed 701500000 lines...
# Processed 701600000 lines...
# Processed 701700000 lines...
# Processed 701800000 lines...
# Processed 701900000 lines...
# Processed 702000000 lines...
# Processed 702100000 lines...
# Processed 702200000 lines...
# Processed 702300000 lines...
# Processed 702400000 lines...
# Processed 702500000 lines...
# Processed 702600000 lines...
# Processed 702700000 lines...
# Processed 702800000 lines...
# Processed 702900000 lines...
# Processed 703000000 lines...
# Processed 703100000 lines...
# Processed 703200000 lines...
# Processed 703300000 lines...
# Processed 703400000 lines...
# Processed 703500000 lines...
# Processed 703600000 lines...
# Processed 703700000 lines...
# Processed 703800000 lines...
# Processed 703900000 lines...
# Processed 704000000 lines...
# Converting PMI matrix to CSR format...
# Saving PMI matrix to disk...
# PMI computation complete!
# Computing term embeddings...
#
# 🔍 Finding surface-form synonyms for: leukemia
#
# 🔍 Finding contextual synonyms for: leukemia
#
# 🔀 Combining hybrid scores for: leukemia
#
# ✅ Top Hybrid Synonyms for 'leukemia':
# leukemias: 0.9938
# leukemia nos: 0.9224
# [m]leukemia nos: 0.8830
# aleukemic leukemia [obs]: 0.7736
# leukemia, nos: 0.7193
# leukaemia: 0.7178
# leukaemia nos: 0.6269
# [m]leukaemia nos: 0.6169
# leukaemias: 0.5789
# aleukaemic leukaemia [obs]: 0.5410

# %% [markdown]
# ### MAP for all terms (not split out for IV and OOV Terms)

# %% [markdown]
# Now, we need to download the UMLS file here https://www.nlm.nih.gov/research/umls/licensedcontent/umlsknowledgesources.html (you have to make sure that you get approval to download the file)

# %%
# !unzip umls-2024AB-mrconso.zip -d umls_extracted
# Out:
# Archive:  umls-2024AB-mrconso.zip
#   inflating: umls_extracted/2024AB/META/MRCONSO.RRF

# %%
import numpy as np
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
import random

# === Load UMLS Synonym Clusters ===
# This function loads UMLS concept clusters from MRCONSO.RRF, filtering by language and source vocabulary (SAB).
# Returns a dictionary: CUI -> set of terms.
def load_umls_synonym_clusters(mrconso_path, lang="ENG", sab_filter=None):
    concept_to_terms = defaultdict(set)
    with open(mrconso_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            parts = line.strip().split('|')
            cui = parts[0]
            lang_code = parts[1]
            sab = parts[11]
            term = parts[14].lower()
            if lang_code != lang:
                continue
            if sab_filter and sab not in sab_filter:
                continue
            concept_to_terms[cui].add(term)
    return concept_to_terms


# === Sample Negative Candidates for Evaluation ===
# Randomly sample negative (non-synonym) candidates, avoiding positives and the true synonym.
def sample_negative_candidates(true_synonym, all_terms, positives, sample_size=100):
    blacklist = set(positives + [true_synonym])
    candidates = [term for term in all_terms if term not in blacklist]
    return random.sample(candidates, sample_size) if len(candidates) >= sample_size else candidates

# === Calculate Average Precision for One Query ===
# Given a ranked list of candidates and known relevant terms, compute average precision.
def average_precision(ranked_terms, relevant_terms):
    hits = 0
    sum_precisions = 0.0
    for i, term in enumerate(ranked_terms):
        if term in relevant_terms:
            hits += 1
            sum_precisions += hits / (i + 1)
    return sum_precisions / len(relevant_terms) if relevant_terms else 0.0

# === MAP Evaluation Using Random Candidate Pools ===
# This function samples query-synonym pairs from gold clusters, evaluates model performance using random negatives,
# and computes the Mean Average Precision (MAP) score over many queries.
def evaluate_map_random_negatives(gold_clusters, model_func, all_terms, sample_size=100, top_k=101, num_queries=1000):
    queries = []
    for terms in gold_clusters.values():
        terms = list(terms)
        if len(terms) < 2:
            continue
        for i in range(len(terms)):
            for j in range(i + 1, len(terms)):
                queries.append((terms[i], terms[j], terms))

    random.shuffle(queries)
    queries = queries[:num_queries]

    map_total = 0.0
    for query_term, true_synonym, all_positives in queries:
        negatives = sample_negative_candidates(true_synonym, all_terms, all_positives, sample_size)
        candidate_pool = [true_synonym] + negatives
        random.shuffle(candidate_pool)
        scores = model_func(query_term, candidate_pool)
        ranked = [term for term, _ in sorted(scores.items(), key=lambda x: -x[1])]
        ap = average_precision(ranked, [true_synonym])
        map_total += ap

    return map_total / len(queries) if queries else 0.0


# === Surface Model Scorer (CharNGram-based Embeddings) ===
# Given a query term and a list of candidates, computes cosine similarity between their CharNGram embeddings.
def surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding):
    def score_fn(query, candidates):
        scores = {}
        query_vec = term_vectors.get(query, compute_term_embedding(query, ngram_embeddings))
        if np.linalg.norm(query_vec) == 0:
            return {c: 0.0 for c in candidates}
        query_vec = query_vec.reshape(1, -1)
        for c in candidates:
            vec = term_vectors.get(c, compute_term_embedding(c, ngram_embeddings))
            scores[c] = cosine_similarity(query_vec, vec.reshape(1, -1))[0][0] if np.linalg.norm(vec) > 0 else 0.0
        return scores
    return score_fn

# === Contextual Model Scorer (NPMI-based) ===
# Loads a precomputed NPMI matrix and uses it to compute similarity between terms based on their contextual PMI vectors.
def npmi_model_scoring(pmi_file, term_index):
    loaded = np.load(pmi_file)
    pmi_matrix = csr_matrix((loaded["data"], loaded["indices"], loaded["indptr"]), shape=loaded["shape"])
    vocab = list(term_index.keys())

    def score_fn(query, candidates):
        if query not in term_index:
            return {c: 0.0 for c in candidates}
        idx = term_index[query]
        vec = pmi_matrix[idx]
        sims = cosine_similarity(vec, pmi_matrix)[0]
        return {c: sims[term_index[c]] if c in term_index else 0.0 for c in candidates}
    return score_fn

# === Compute Average Word2Vec Vector for Multi-word Terms ===
# For a given term, returns the average of its component token embeddings (if any exist in the model).
def get_avg_vector(term, model):
    tokens = term.lower().split()
    vectors = [model[word] for word in tokens if word in model.key_to_index]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)


# === Contextual Model Scorer (Word2Vec-based) ===
# Computes cosine similarity between average Word2Vec embeddings for query and candidate terms.
def context_model_word2vec_fn(w2v_model):
    def scorer(query, candidates):
        scores = {}
        query_vec = get_avg_vector(query, w2v_model)
        if np.linalg.norm(query_vec) == 0:
            return {c: 0.0 for c in candidates}
        query_vec = query_vec.reshape(1, -1)
        for c in candidates:
            c_vec = get_avg_vector(c, w2v_model)
            if np.linalg.norm(c_vec) == 0:
                scores[c] = 0.0
            else:
                scores[c] = cosine_similarity(query_vec, c_vec.reshape(1, -1))[0][0]
        return scores
    return scorer


# === Normalize Dictionary of Scores ===
# Scales all scores into [0, 1] range based on min-max normalization.
def normalize_scores(score_dict):
    scores = np.array(list(score_dict.values()))
    if len(scores) == 0:
        return {}
    min_val, max_val = np.min(scores), np.max(scores)
    norm = lambda s: (s - min_val) / (max_val - min_val) if max_val > min_val else 0.0
    return {term: norm(score) for term, score in score_dict.items()}

# === Combine Surface and Context Scores into Hybrid Score ===
# Combines normalized surface-form and contextual scores via a weighted average using `alpha`.
def combine_hybrid_scores_dict(surface_dict, context_dict, alpha=0.5):
    all_terms = set(surface_dict.keys()).union(context_dict.keys())
    combined = {}
    for term in all_terms:
        s_score = surface_dict.get(term, 0.0)
        c_score = context_dict.get(term, 0.0)
        combined[term] = alpha * s_score + (1 - alpha) * c_score
    return combined

# === Hybrid Model Scorer (Surface + NPMI) ===
# Builds a scoring function that combines CharNGram similarity and NPMI-based contextual similarity.
def hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding, alpha=0.5):
    surface_fn = surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding)
    context_fn = npmi_model_scoring(pmi_file, term_index)

    def score_fn(query, candidates):
        s_scores = surface_fn(query, candidates)
        c_scores = context_fn(query, candidates)
        norm_s = normalize_scores(s_scores)
        norm_c = normalize_scores(c_scores)
        return combine_hybrid_scores_dict(norm_s, norm_c, alpha)
    return score_fn



# === Main MAP Evaluation Pipeline ===
# This function loads UMLS synonym clusters, sets up scoring functions for all models (surface, context, hybrid),
# evaluates their MAP performance on a subset of queries, and prints the final results.
def run_umls_map_evaluation_with_npmi(mrconso_path, term_list, term_vectors, ngram_embeddings,
                                      pmi_file, term_index, compute_term_embedding, w2v_model,
                                      num_queries=1000):
    print("\n📦 Loading UMLS Synonym Clusters...")
    clusters = load_umls_synonym_clusters(mrconso_path, sab_filter={"MSH", "SNOMEDCT_US"})
    print("✅ UMLS concepts loaded:", len(clusters))

    print("\n📊 Preparing model functions for scoring...")
    surface_fn = surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding)
    context_fn = context_model_word2vec_fn(w2v_model)
    hybrid_fn = hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding, alpha=0.5)

    print("\n🚀 Running MAP evaluation (Random Candidate Selection)...")
    map_surface = evaluate_map_random_negatives(clusters, surface_fn, term_list, num_queries=num_queries)
    map_context = evaluate_map_random_negatives(clusters, context_fn, term_list, num_queries=num_queries)
    map_hybrid = evaluate_map_random_negatives(clusters, hybrid_fn, term_list, num_queries=num_queries)

    print("\n📈 Evaluation Results (MAP):")
    print(f"Surface (CharNGram): {map_surface:.4f}")
    print(f"Context (Word2Vec):      {map_context:.4f}")
    print(f"Hybrid (Char+NPMI):  {map_hybrid:.4f}")

# %%
mrconso_path="umls_extracted/2024AB/META/MRCONSO.RRF"
run_umls_map_evaluation_with_npmi(
    mrconso_path=mrconso_path,
    term_list=term_list,
    term_vectors=term_vectors,
    ngram_embeddings=ngram_embeddings,
    pmi_file=pmi_output_file,
    term_index=term_index,
    compute_term_embedding=compute_term_embedding,
    w2v_model=model,
    num_queries=1000
)
# Out:
# 📦 Loading UMLS Synonym Clusters...
# ✅ UMLS concepts loaded: 866217
#
# 📊 Preparing model functions for scoring...
#
# 🚀 Running MAP evaluation (Random Candidate Selection)...
#
# 📈 Evaluation Results (MAP):
# Surface (CharNGram): 0.7471
# Context (Word2Vec):      0.6376
# Hybrid (Char+NPMI):  0.7719

# %% [markdown]
# ### MAP split out for IV and OOV terms

# %%
import numpy as np
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
import random

# === Load UMLS Synonym Clusters ===
# Parses the MRCONSO.RRF file to load clusters of synonymous terms (CUI -> set of terms),
# filtered by language and optionally source vocabularies (SABs).
def load_umls_synonym_clusters(mrconso_path, lang="ENG", sab_filter=None):
    concept_to_terms = defaultdict(set)
    with open(mrconso_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            parts = line.strip().split('|')
            cui = parts[0]
            lang_code = parts[1]
            sab = parts[11]
            term = parts[14].lower()
            if lang_code != lang:
                continue
            if sab_filter and sab not in sab_filter:
                continue
            concept_to_terms[cui].add(term)
    return concept_to_terms


# === MAP Evaluation with IV/OOV Term Breakdown ===
# Randomly samples non-synonym terms (negatives) for candidate selection during MAP evaluation.
def sample_negative_candidates(true_synonym, all_terms, positives, sample_size=100):
    blacklist = set(positives + [true_synonym])
    candidates = [term for term in all_terms if term not in blacklist]
    return random.sample(candidates, sample_size) if len(candidates) >= sample_size else candidates

# Computes average precision for a single ranked result list and a set of known relevant items.
def average_precision(ranked_terms, relevant_terms):
    hits = 0
    sum_precisions = 0.0
    for i, term in enumerate(ranked_terms):
        if term in relevant_terms:
            hits += 1
            sum_precisions += hits / (i + 1)
    return sum_precisions / len(relevant_terms) if relevant_terms else 0.0

# Evaluates MAP by distinguishing between in-vocabulary (IV) and out-of-vocabulary (OOV) terms.
# Splits query evaluation results based on vocab_checker function and returns MAP and counts for IV/OOV.
def evaluate_map_by_vocab_status(gold_clusters, model_func, all_terms, sample_size=100, top_k=101, num_queries=1000, vocab_checker=None):
    queries = []
    for terms in gold_clusters.values():
        terms = list(terms)
        if len(terms) < 2:
            continue
        for i in range(len(terms)):
            for j in range(i + 1, len(terms)):
                queries.append((terms[i], terms[j], terms))

    random.shuffle(queries)
    queries = queries[:num_queries]

    map_total_iv, map_total_oov = 0.0, 0.0
    count_iv, count_oov = 0, 0

    for query_term, true_synonym, all_positives in queries:
        is_iv = vocab_checker(query_term) and vocab_checker(true_synonym)
        negatives = sample_negative_candidates(true_synonym, all_terms, all_positives, sample_size)
        candidate_pool = [true_synonym] + negatives
        random.shuffle(candidate_pool)

        scores = model_func(query_term, candidate_pool)
        ranked = [term for term, _ in sorted(scores.items(), key=lambda x: -x[1])]
        ap = average_precision(ranked, [true_synonym])

        if is_iv:
            map_total_iv += ap
            count_iv += 1
        else:
            map_total_oov += ap
            count_oov += 1

    map_iv = map_total_iv / count_iv if count_iv > 0 else 0.0
    map_oov = map_total_oov / count_oov if count_oov > 0 else 0.0
    return map_iv, map_oov, count_iv, count_oov


# === Vocabulary Checkers ===
# Checks if a term is in the CharNGram model’s vocabulary by checking existing embeddings or computing one.
def is_in_vocab_charn(term, term_vectors, ngram_embeddings, compute_term_embedding):
    vec = term_vectors.get(term)
    if vec is not None:
        return True
    vec = compute_term_embedding(term, ngram_embeddings)
    return np.linalg.norm(vec) > 0

# Checks if a term (or one of its tokens) exists in the Word2Vec model’s vocabulary.
def is_in_vocab_w2v(term, w2v_model):
    tokens = term.lower().split()
    return any(token in w2v_model.key_to_index for token in tokens)

# Checks if a term exists in the NPMI term index.
def is_in_vocab_npmi(term, term_index):
    return term in term_index


# === Model Scorers ===
# Computes cosine similarity scores between query and candidate terms using surface-form CharNGram embeddings.
def surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding):
    def score_fn(query, candidates):
        scores = {}
        query_vec = term_vectors.get(query, compute_term_embedding(query, ngram_embeddings))
        if np.linalg.norm(query_vec) == 0:
            return {c: 0.0 for c in candidates}
        query_vec = query_vec.reshape(1, -1)
        for c in candidates:
            vec = term_vectors.get(c, compute_term_embedding(c, ngram_embeddings))
            scores[c] = cosine_similarity(query_vec, vec.reshape(1, -1))[0][0] if np.linalg.norm(vec) > 0 else 0.0
        return scores
    return score_fn

# Computes average vector from Word2Vec model for a potentially multi-token term.
def get_avg_vector(term, model):
    tokens = term.lower().split()
    vectors = [model[word] for word in tokens if word in model.key_to_index]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# Computes similarity using Word2Vec embeddings for both query and candidate terms.
def context_model_word2vec_fn(w2v_model):
    def scorer(query, candidates):
        scores = {}
        query_vec = get_avg_vector(query, w2v_model)
        if np.linalg.norm(query_vec) == 0:
            return {c: 0.0 for c in candidates}
        query_vec = query_vec.reshape(1, -1)
        for c in candidates:
            c_vec = get_avg_vector(c, w2v_model)
            if np.linalg.norm(c_vec) == 0:
                scores[c] = 0.0
            else:
                scores[c] = cosine_similarity(query_vec, c_vec.reshape(1, -1))[0][0]
        return scores
    return scorer

# Computes similarity using a precomputed NPMI matrix loaded from disk.
def npmi_model_scoring(pmi_file, term_index):
    loaded = np.load(pmi_file)
    pmi_matrix = csr_matrix((loaded["data"], loaded["indices"], loaded["indptr"]), shape=loaded["shape"])
    def score_fn(query, candidates):
        if query not in term_index:
            return {c: 0.0 for c in candidates}
        idx = term_index[query]
        vec = pmi_matrix[idx]
        sims = cosine_similarity(vec, pmi_matrix)[0]
        return {c: sims[term_index[c]] if c in term_index else 0.0 for c in candidates}
    return score_fn

# Normalizes scores to [0, 1] range using min-max normalization.
def normalize_scores(score_dict):
    scores = np.array(list(score_dict.values()))
    if len(scores) == 0:
        return {}
    min_val, max_val = np.min(scores), np.max(scores)
    norm = lambda s: (s - min_val) / (max_val - min_val) if max_val > min_val else 0.0
    return {term: norm(score) for term, score in score_dict.items()}

# Combines scores from two sources (e.g., surface and context models) with a weight alpha.
def combine_hybrid_scores_dict(surface_dict, context_dict, alpha=0.5):
    all_terms = set(surface_dict.keys()).union(context_dict.keys())
    return {term: alpha * surface_dict.get(term, 0.0) + (1 - alpha) * context_dict.get(term, 0.0)
            for term in all_terms}

# Constructs a hybrid model that combines CharNGram and NPMI-based similarity.
# Scores are normalized and blended with weight alpha.
def hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding, alpha=0.5):
    surface_fn = surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding)
    context_fn = npmi_model_scoring(pmi_file, term_index)
    def score_fn(query, candidates):
        s_scores = surface_fn(query, candidates)
        c_scores = context_fn(query, candidates)
        return combine_hybrid_scores_dict(normalize_scores(s_scores), normalize_scores(c_scores), alpha)
    return score_fn



# === Main Evaluation Pipeline with IV/OOV Reporting ===
# Loads clusters, prepares scoring functions for CharNGram, Word2Vec, and Hybrid models.
# Evaluates each model separately, splitting results by whether the terms are IV or OOV.
def run_umls_map_evaluation_with_vocab_splits(mrconso_path, term_list, term_vectors, ngram_embeddings,
                                              pmi_file, term_index, compute_term_embedding, w2v_model,
                                              num_queries=1000):
    print("\n📦 Loading UMLS Synonym Clusters...")
    clusters = load_umls_synonym_clusters(mrconso_path, sab_filter={"MSH", "SNOMEDCT_US"})
    print("✅ UMLS concepts loaded:", len(clusters))

    print("\n📊 Preparing model functions...")
    surface_fn = surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding)
    context_fn = context_model_word2vec_fn(w2v_model)
    hybrid_fn = hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding)

    print("\n🚀 Evaluating CharNGram...")
    map_iv_s, map_oov_s, c_iv_s, c_oov_s = evaluate_map_by_vocab_status(
        clusters, surface_fn, term_list, num_queries=num_queries,
        vocab_checker=lambda t: is_in_vocab_charn(t, term_vectors, ngram_embeddings, compute_term_embedding)
    )

    print("\n🚀 Evaluating Word2Vec...")
    map_iv_c, map_oov_c, c_iv_c, c_oov_c = evaluate_map_by_vocab_status(
        clusters, context_fn, term_list, num_queries=num_queries,
        vocab_checker=lambda t: is_in_vocab_w2v(t, w2v_model)
    )

    print("\n🚀 Evaluating Hybrid...")
    map_iv_h, map_oov_h, c_iv_h, c_oov_h = evaluate_map_by_vocab_status(
        clusters, hybrid_fn, term_list, num_queries=num_queries,
        vocab_checker=lambda t: is_in_vocab_charn(t, term_vectors, ngram_embeddings, compute_term_embedding)
                                 and is_in_vocab_npmi(t, term_index)
    )

    print("\n📈 Evaluation Results (MAP):")
    print(f"🔹 CharNGram:  IV={map_iv_s:.4f} ({c_iv_s}), OOV={map_oov_s:.4f} ({c_oov_s})")
    print(f"🔹 Word2Vec:   IV={map_iv_c:.4f} ({c_iv_c}), OOV={map_oov_c:.4f} ({c_oov_c})")
    print(f"🔹 Hybrid:     IV={map_iv_h:.4f} ({c_iv_h}), OOV={map_oov_h:.4f} ({c_oov_h})")

# %%
mrconso_path="umls_extracted/2024AB/META/MRCONSO.RRF"
run_umls_map_evaluation_with_vocab_splits(
    mrconso_path=mrconso_path,
    term_list=term_list,
    term_vectors=term_vectors,
    ngram_embeddings=ngram_embeddings,
    pmi_file=pmi_output_file,
    term_index=term_index,
    compute_term_embedding=compute_term_embedding,
    w2v_model=model,
    num_queries=1000
)
# Out:
# 📦 Loading UMLS Synonym Clusters...
# ✅ UMLS concepts loaded: 866217
#
# 📊 Preparing model functions...
#
# 🚀 Evaluating CharNGram...
#
# 🚀 Evaluating Word2Vec...
#
# 🚀 Evaluating Hybrid...

# %% [markdown]
# ### Model tests on random words

# %%
pip install nltk

# %%
import random
import nltk
from nltk.corpus import words
nltk.download('words')

# === 1. Get Random Non-Medical English Words ===
# Returns a list of `num_words` English words that are not present in the given term list (e.g., medical terms).
# Used to simulate out-of-domain query terms for model evaluation.
def get_non_umls_english_words(term_list, num_words=1000):
    english_vocab = set(w.lower() for w in words.words() if w.isalpha() and len(w) > 2)
    medical_vocab = set(t.lower() for t in term_list)
    non_medical_words = list(english_vocab - medical_vocab)
    random.seed(42)
    return random.sample(non_medical_words, min(num_words, len(non_medical_words)))


# === 2. Evaluate Model on Random Non-Medical Query Terms ===
# For a list of random query terms, applies the model to a fixed candidate pool and prints top-K results for each query.
# Only the first 10 queries are printed for brevity.
def test_model_on_random_queries(random_terms, model_func, candidate_pool, top_k=5, model_name=""):
    print(f"\n📊 Evaluating {model_name} on {len(random_terms)} non-medical queries...\n")
    for i, query_term in enumerate(random_terms[:10]):  # Just show first 10 queries
        scores = model_func(query_term, candidate_pool)
        ranked = sorted(scores.items(), key=lambda x: -x[1])[:top_k]
        print(f"\n🔍 Query [{i+1}]: {query_term}")
        for rank, (term, score) in enumerate(ranked, start=1):
            print(f"  {rank}. {term} ({score:.4f})")

# === 3. Surface Model Wrapper (CharNGram) ===
# Computes similarity between query and candidates using character n-gram embeddings.
# Falls back on computing term embedding if not found in the cached vectors.
def surface_model_fn(term_vectors, ngram_embeddings):
    def scorer(query, candidates):
        scores = {}
        q_vec = compute_term_embedding(query, ngram_embeddings, dim=100)
        if np.linalg.norm(q_vec) == 0:
            return {c: 0.0 for c in candidates}
        for c in candidates:
            c_vec = term_vectors.get(c)
            if c_vec is None:
                c_vec = compute_term_embedding(c, ngram_embeddings, dim=100)
            sim = cosine_similarity(q_vec.reshape(1, -1), c_vec.reshape(1, -1))[0][0]
            scores[c] = sim
        return scores
    return scorer


# === Get Average Word2Vec Vector ===
# Splits a term into tokens and returns the average of Word2Vec vectors for known tokens.
def get_avg_vector(term, model):
    tokens = term.lower().split()
    vectors = [model[word] for word in tokens if word in model.key_to_index]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# === Contextual Model Wrapper (Word2Vec) ===
# Scores query and candidate terms based on cosine similarity between their average Word2Vec vectors.
def context_model_word2vec_fn(w2v_model):
    def scorer(query, candidates):
        scores = {}
        query_vec = get_avg_vector(query, w2v_model)
        if np.linalg.norm(query_vec) == 0:
            return {c: 0.0 for c in candidates}
        query_vec = query_vec.reshape(1, -1)
        for c in candidates:
            c_vec = get_avg_vector(c, w2v_model)
            if np.linalg.norm(c_vec) == 0:
                scores[c] = 0.0
            else:
                scores[c] = cosine_similarity(query_vec, c_vec.reshape(1, -1))[0][0]
        return scores
    return scorer


# === NPMI Contextual Model Scorer ===
# Loads the precomputed sparse PMI matrix and scores query vs. candidates using cosine similarity of row vectors.
def npmi_model_scoring(pmi_file, term_index):
    loaded = np.load(pmi_file)
    pmi_matrix = csr_matrix((loaded["data"], loaded["indices"], loaded["indptr"]), shape=loaded["shape"])
    def score_fn(query, candidates):
        if query not in term_index:
            return {c: 0.0 for c in candidates}
        idx = term_index[query]
        vec = pmi_matrix[idx]
        sims = cosine_similarity(vec, pmi_matrix)[0]
        return {c: sims[term_index[c]] if c in term_index else 0.0 for c in candidates}
    return score_fn


# === Normalize Scores Dictionary ===
# Scales all scores in a dictionary to the [0, 1] range using min-max normalization.
def normalize_scores(score_dict):
    scores = np.array(list(score_dict.values()))
    if len(scores) == 0:
        return {}
    min_val, max_val = np.min(scores), np.max(scores)
    norm = lambda s: (s - min_val) / (max_val - min_val) if max_val > min_val else 0.0
    return {term: norm(score) for term, score in score_dict.items()}


# === Combine Surface and Context Scores ===
# Blends two score dictionaries using weight alpha to create a hybrid score for each candidate.
def combine_hybrid_scores_dict(surface_dict, context_dict, alpha=0.5):
    all_terms = set(surface_dict.keys()).union(context_dict.keys())
    return {term: alpha * surface_dict.get(term, 0.0) + (1 - alpha) * context_dict.get(term, 0.0)
            for term in all_terms}

# === Hybrid Model Wrapper (CharNGram + NPMI) ===
# Combines normalized surface (CharNGram) and contextual (NPMI) scores using weighted average.
def hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding, alpha=0.5):
    surface_fn = surface_model_scoring(term_vectors, ngram_embeddings, compute_term_embedding)
    context_fn = npmi_model_scoring(pmi_file, term_index)
    def score_fn(query, candidates):
        s_scores = surface_fn(query, candidates)
        c_scores = context_fn(query, candidates)
        return combine_hybrid_scores_dict(normalize_scores(s_scores), normalize_scores(c_scores), alpha)
    return score_fn

# === Run Full Non-Medical Evaluation Pipeline ===
# Selects non-medical words, builds model scorers, and evaluates performance using each model type (surface, context, hybrid).
def run_non_medical_query_test(term_list, term_vectors, ngram_embeddings, w2v_model, pmi_file, term_index):
    print("\n📦 Getting 1,000 non-medical query terms...")
    non_medical_queries = get_non_umls_english_words(term_list, num_words=1000)
    candidate_pool = random.sample(term_list, 500)

    surface_fn = surface_model_fn(term_vectors, ngram_embeddings)
    context_fn = context_model_word2vec_fn(w2v_model)
    hybrid_fn = hybrid_model_npmi_scoring(term_vectors, ngram_embeddings, pmi_file, term_index, compute_term_embedding)

    evaluate_non_medical_queries_summary(non_medical_queries, surface_fn, candidate_pool, model_name="Surface")
    evaluate_non_medical_queries_summary(non_medical_queries, context_fn, candidate_pool, model_name="Context (Word2Vec)")
    evaluate_non_medical_queries_summary(non_medical_queries, hybrid_fn, candidate_pool, model_name="Hybrid")

# %%
# === Evaluate Model on Non-Medical Queries and Summarize Results ===
# For a list of non-medical (out-of-domain) query terms, this function:
# 1. Applies the given model to score each query against a candidate pool.
# 2. Records the top-1 score for each query.
# 3. Counts how often the top prediction exceeds a specified confidence threshold (i.e., high-confidence false positive).
# 4. Computes and prints summary statistics: average top-1 score and FP rate.
# Returns the average top-1 score and the false positive rate (FP@1).
def evaluate_non_medical_queries_summary(query_terms, model_func, candidate_pool, top_k=1, score_threshold=0.5, model_name=""):
    print(f"\n📊 Evaluating {model_name} on {len(query_terms)} non-medical queries...")

    top1_scores = []
    high_conf_fp_count = 0

    for query_term in query_terms:
        scores = model_func(query_term, candidate_pool)
        ranked = sorted(scores.items(), key=lambda x: -x[1])[:top_k]

        if not ranked:
            continue

        top_score = ranked[0][1]
        top1_scores.append(top_score)

        if top_score >= score_threshold:
            high_conf_fp_count += 1

    num_queries = len(top1_scores)
    avg_top1_score = np.mean(top1_scores)
    fp_rate = high_conf_fp_count / num_queries if num_queries else 0.0

    print(f"🔹 Avg Top-1 Score:         {avg_top1_score:.4f}")
    print(f"🔹 High-Confidence FP@1:   {fp_rate:.4f} (score ≥ {score_threshold})")

    return avg_top1_score, fp_rate

# %%
run_non_medical_query_test(term_list, term_vectors, ngram_embeddings, model, pmi_output_file, term_index)
